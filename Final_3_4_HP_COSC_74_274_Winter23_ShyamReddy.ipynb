# %% [markdown]
# # Hyper parameter training for part 4

# %%
import seaborn as sns
import pandas as pd
import autograd.numpy as np
from autograd import grad
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
# cutoff
cutoff = 4

# %%
# import data
train_data = pd.read_csv('Training.csv')

train_data.describe(include='all')
# Out:
#              overall verified  reviewTime                        reviewerID  \
# count   29189.000000    29189       29189                             29189
# unique           NaN        2        4866                             27588
# top              NaN     True  01 3, 2017  AA7918E9410D650A076221C7B2934A09
# freq             NaN    22996          40                                32
# mean        2.971907      NaN         NaN                               NaN
# std         1.410878      NaN         NaN                               NaN
# min         1.000000      NaN         NaN                               NaN
# 25%         2.000000      NaN         NaN                               NaN
# 50%         3.000000      NaN         NaN                               NaN
# 75%         4.000000      NaN         NaN                               NaN
# max         5.000000      NaN         NaN                               NaN
#
#                                     asin                      reviewerName  \
# count                              29189                             29185
# unique                             24102                             23305
# top     6E46168E5DFA83876F2E968A187B9F7A  760C63E8E5E8DC3FAA01878D37BA5678
# freq                                  36                              1049
# mean                                 NaN                               NaN
# std                                  NaN                               NaN
# min                                  NaN                               NaN
# 25%                                  NaN                               NaN
# 50%                                  NaN                               NaN
# 75%                                  NaN                               NaN
# max                                  NaN                               NaN
#
#          reviewText     summary  unixReviewTime         vote  \
# count         29189       29184    2.918900e+04  6047.000000
# unique        28807       21768             NaN          NaN
# top     works great  Five Stars             NaN          NaN
# freq             25        1476             NaN          NaN
# mean            NaN         NaN    1.409661e+09     7.295353
# std             NaN         NaN    1.115099e+08    18.749460
# min             NaN         NaN    8.947584e+08     2.000000
# 25%             NaN         NaN    1.390781e+09     2.000000
# 50%             NaN         NaN    1.439770e+09     4.000000
# 75%             NaN         NaN    1.476317e+09     7.000000
# max             NaN         NaN    1.537488e+09   682.000000
#
#                                                     image  \
# count                                                 600
# unique                                                600
# top     ['https://images-na.ssl-images-amazon.com/imag...
# freq                                                    1
# mean                                                  NaN
# std                                                   NaN
# min                                                   NaN
# 25%                                                   NaN
# 50%                                                   NaN
# 75%                                                   NaN
# max                                                   NaN
#
#                            style category
# count                      15365    29189
# unique                      6104        6
# top     {'Format:': ' Audio CD'}      CDs
# freq                        4296     4912
# mean                         NaN      NaN
# std                          NaN      NaN
# min                          NaN      NaN
# 25%                          NaN      NaN
# 50%                          NaN      NaN
# 75%                          NaN      NaN
# max                          NaN      NaN

# %%
import re

# Preprocessing data

# Stop words
GENERIC_STOP_WORDS = ['ourselves', 'hers', 'between', 'yourself', 'but', 'again', 'there', 'about', 'once', 'during', 'out', 'very', 'having', 'with', 'they', 'own', 'an', 'be', 'some', 'for', 'do', 'its', 'yours', 'such', 'into', 'of', 'most', 'itself', 'other', 'off', 'is', 's', 'am', 'or', 'who', 'as', 'from', 'him', 'each', 'the', 'themselves', 'until', 'below', 'are', 'we', 'these', 'your', 'his', 'through', 'don', 'nor', 'me', 'were', 'her', 'more', 'himself', 'this', 'down', 'should', 'our', 'their', 'while',
                      'above', 'both', 'up', 'to', 'ours', 'had', 'she', 'all', 'when', 'at', 'any', 'before', 'them', 'same', 'and', 'been', 'have', 'in', 'will', 'on', 'does', 'yourselves', 'then', 'that', 'because', 'what', 'over', 'why', 'so', 'can', 'did', 'now', 'under', 'he', 'you', 'herself', 'has', 'just', 'where', 'too', 'only', 'myself', 'which', 'those', 'i', 'after', 'few', 'whom', 't', 'being', 'if', 'theirs', 'my', 'against', 'a', 'by', 'doing', 'it', 'how', 'further', 'was', 'here', 'than', 'as']
STOP_WORDS_SUMMARY = ['hyundai', 'eyed', '4yo', 'cycling', '2x', 'excellence', 'excelent', 'exquisite', '2wd', 'awsome', 'awhile', 'awaited', 'owe', 'twisted', 'swimming', 'rvs', 'overlooked', 'sunshade', 'purchases', 'subaru', 'buick', 'audi', 'quads', 'tuner', 'tune', 'gutter', 'junior', 'musical', 'guitars', 'funk', 'humor', 'bueno', 'sunday', 'buzz', 'dude', 'hurrah', 'guessing', 'junkie', 'jug', 'rum', 'rubbed', 'nutritious', 'muffins', 'turmeric', 'hunters', 'supposedly', 'ounces', 'turbo', 'suffer', 'supplies', 'cutie', 'puppets', 'cuddly', 'gt', 'utilitarian', 'attaches', 'stroke', 'starters', 'standards', '6th', 'stretching', 'stream', 'bt', 'stout', 'strategy',
                      'isuzu', 'tsx', 'usefull', 'usa', 'ass', 'bs', 'crew', 'trd', 'drilling', 'transmission', 'draw', 'brother', 'traction', 'prevents', 'orignal', 'fraction', 'prius', 'groove', 'proud', 'grace', 'brilliance', 'brigade', 'orchestration', 'treasure', 'previously', 'irons', 'franklin', 'programs', 'frustration', 'protein', 'artisan', 'crumbled', 'grains', 'grapefruit', 'drinkers', 'crisp', 'breads', 'brewing', 'creme', 'branded', 'wrapped', 'armorsuit', 'orientation', 'preference', 'tray', 'prints', 'vr', 'armour', 'dragonfly', 'dryer', 'breyer', 'dresses', 'promo', 'transformers', 'spread', 'appetite', 'ipod', 'spices', 'spanish', 'operates', 'speeds', 'iphone4']
STOP_WORDS_REVIEW_TEXT = []


# edit summary content
def edit_summary(content):

    # step 1 - convert the text to only lower case
    content = content.lower()

    # step 2 - remove unwanted and unicode characters
    content = re.sub(
        r"(@\[A-Za-z0-9]+)|([^0-9A-Za-z \t])|(\w+:\/\/\S+)|^rt|http.+?", "", content)

    # step 3 - remove stop words
    stopwords = GENERIC_STOP_WORDS

    filtered_words = [
        word for word in content.split() if word not in stopwords]
    text = " ".join(filtered_words)

    return text


# edit review text content
def edit_review_text(content):

    # step 1 - convert the text to only lower case
    content = content.lower()

    # step 2 - remove unwanted and unicode characters
    content = re.sub(
        r"(@\[A-Za-z0-9]+)|([^0-9A-Za-z \t])|(\w+:\/\/\S+)|^rt|http.+?", "", content)

    # step 3 - remove stop words
    stopwords = GENERIC_STOP_WORDS

    filtered_words = [
        word for word in content.split() if word not in stopwords]
    text = " ".join(filtered_words)

    return text


# create categories for vote label
def assign_vote_label(i):
    if i <= 2.0:
        return 'low'
    if i > 2.0 and i <= 10.0:
        return 'medium'
    if i > 10.0 and i <= 50.0:
        return 'good'
    if i > 50.0:
        return 'high'


# preprocess
def preprocess(data):

    # filter out only important columns
    X_cols = ['reviewText', 'summary', 'verified', 'vote', 'category']

    # editing text of "reviewText" & "summary"
    data['reviewText'] = data['reviewText'].astype(str).apply(
        edit_review_text)
    data['summary'] = data['summary'].astype(str).apply(edit_summary)

    # editing vote - assigning NAN values to 0
    data['vote'] = data['vote'].fillna(0)
    data['vote'] = data['vote'].apply(lambda x: assign_vote_label(x))

    X = train_data[X_cols]

    return X

# %%
# creating X and y data

# creating y labels less than cutoff to be 0 and 1 otherwise
y = train_data['overall'].apply(lambda x: 0 if x <= cutoff else 1)

# create features data
X = preprocess(train_data)

# %%
from sklearn.model_selection import train_test_split

# train test split function
X_train, X_test, y_train, y_test = train_test_split(X, y,
                                                    test_size=0.20, random_state = 101)

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline
from sklearn.model_selection import GridSearchCV, RandomizedSearchCV, cross_val_score
from sklearn.preprocessing import OrdinalEncoder
from sklearn.metrics import confusion_matrix, roc_curve, roc_auc_score, f1_score, accuracy_score
from sklearn.exceptions import ConvergenceWarning
import warnings

# ignore warnings
warnings.filterwarnings("ignore", category=ConvergenceWarning)

# define the column transformer to apply TfidfVectorizer & encoder to multiple columns
ct = ColumnTransformer(
    [("vect_summary", TfidfVectorizer(), 'summary'),
     ("vect_reviewText", TfidfVectorizer(), 'reviewText'),
     ("encd_verified", OrdinalEncoder(dtype=int), ['verified']),
     ("encd_category", OrdinalEncoder(dtype=int), ['category']),
     ("encd_votes", OrdinalEncoder(dtype=int), ['vote'])
     ])

# For results
model_arr, auc_arr, f1_arr, accuracy_arr = [], [], [], []

# %% [markdown]
# # Logistic Regression

# %%
from sklearn.linear_model import LogisticRegression

pipe = Pipeline([
    ("transformer", ct),
    ("classifier", LogisticRegression())
])

params = {
    "transformer__vect_summary__ngram_range": [(1, 2)],
    "transformer__vect_reviewText__ngram_range": [(1, 2)],
    "transformer__vect_summary__max_features": [10000, 32000],
    "transformer__vect_reviewText__max_features": [5000, 10000],
    "classifier__solver": ['liblinear'],
    "classifier__C": [0.1, 1.0, 5.0, 10.0],
    "classifier__max_iter": [100, 500, 1000]
}


# perform grid search cross-validation to find the best hyperparameters
grid_log = GridSearchCV(pipe, params, cv=5, scoring='f1_macro', verbose=10)

grid_log.fit(X_train, y_train)
print("-----------------------------------------------------------------------------------------------------------------------------------")
print("Best: %f using %s" % (grid_log.best_score_, grid_log.best_params_))

# predict
y_pred_log = grid_log.best_estimator_.predict(X_test)

# f1 score
fscore = f1_score(y_test, y_pred_log, average='macro')
print("f1_score: ", fscore)
f1_arr.append(fscore)

# accuracy
accur = accuracy_score(y_test, y_pred_log)
accuracy_arr.append(accur)
print("accuracy: ", accur)

# auc score
aucscore = roc_auc_score(y_test, y_pred_log)
print("auc score: ", aucscore)
auc_arr.append(aucscore)

# confusion matrix
cm_log = confusion_matrix(y_test, y_pred_log)
tn, fp, fn, tp = cm_log.ravel()
fpr = fp / (fp + tn)
tpr = tp / (tp + fn)
sns.heatmap(cm_log, annot=True, fmt='d', cmap='Blues',
            xticklabels=['Predicted Negative', 'Predicted Positive'],
            yticklabels=['Actual Negative\nFPR={:.2f}'.format(fpr), 'Actual Positive\nTPR={:.2f}'.format(tpr)])
plt.title("Confusion Matrix")
plt.show()

# ROC curve
y_pred_prob_log = grid_log.predict_proba(X_test)
fpr, tpr, threshold = roc_curve(y_test, y_pred_prob_log[:,1])
sns.lineplot(x=fpr, y=tpr,label="AUC="+str(aucscore))
plt.plot([0, 1], [0, 1], color='navy', lw=2, linestyle='--')
plt.xlabel("FPR")
plt.ylabel("TPR")
plt.title("ROC Curve")
plt.show()

model_arr.append("Logistic Regression")

# Best: 0.808420 using {'classifier__C': 5.0, 'classifier__max_iter': 100, 'classifier__solver': 'liblinear', 'transformer__vect_reviewText__max_features': 5000, 'transformer__vect_reviewText__ngram_range': (1, 2), 'transformer__vect_summary__max_features': 40000, 'transformer__vect_summary__ngram_range': (1, 2)}
# Out:
# Fitting 5 folds for each of 48 candidates, totalling 240 fits
# [CV 1/5; 1/48] START classifier__C=0.1, classifier__max_iter=100, classifier__solver=liblinear, transformer__vect_reviewText__max_features=5000, transformer__vect_reviewText__ngram_range=(1, 2), transformer__vect_summary__max_features=10000, transformer__vect_summary__ngram_range=(1, 2)
# [CV 1/5; 1/48] END classifier__C=0.1, classifier__max_iter=100, classifier__solver=liblinear, transformer__vect_reviewText__max_features=5000, transformer__vect_reviewText__ngram_range=(1, 2), transformer__vect_summary__max_features=10000, transformer__vect_summary__ngram_range=(1, 2);, score=0.715 total time=   5.3s
# [CV 2/5; 1/48] START classifier__C=0.1, classifier__max_iter=100, classifier__solver=liblinear, transformer__vect_reviewText__max_features=5000, transformer__vect_reviewText__ngram_range=(1, 2), transformer__vect_summary__max_features=10000, transformer__vect_summary__ngram_range=(1, 2)
# [CV 2/5; 1/48] END classifier__C=0.1, classifier__max_iter=100, classifier__solver=liblinear, transformer__vect_reviewText__max_features=5000, transformer__vect_reviewText__ngram_range=(1, 2), transformer__vect_summary__max_features=10000, transformer__vect_summary__ngram_range=(1, 2);, score=0.708 total time=   6.3s
# [CV 3/5; 1/48] START classifier__C=0.1, classifier__max_iter=100, classifier__solver=liblinear, transformer__vect_reviewText__max_features=5000, transformer__vect_reviewText__ngram_range=(1, 2), transformer__vect_summary__max_features=10000, transformer__vect_summary__ngram_range=(1, 2)
# [CV 3/5; 1/48] END classifier__C=0.1, classifier__max_iter=100, classifier__solver=liblinear, transformer__vect_reviewText__max_features=5000, transformer__vect_reviewText__ngram_range=(1, 2), transformer__vect_summary__max_features=10000, transformer__vect_summary__ngram_range=(1, 2);, score=0.716 total time=   6.6s
# [CV 4/5; 1/48] START classifier__C=0.1, classifier__max_iter=100, classifier__solver=liblinear, transformer__vect_reviewText__max_features=5000, transformer__vect_reviewText__ngram_range=(1, 2), transformer__vect_summary__max_features=10000, transformer__vect_summary__ngram_range=(1, 2)
# [CV 4/5; 1/48] END classifier__C=0.1, classifier__max_iter=100, classifier__solver=liblinear, transformer__vect_reviewText__max_features=5000, transformer__vect_reviewText__ngram_range=(1, 2), transformer__vect_summary__max_features=10000, transformer__vect_summary__ngram_range=(1, 2);, score=0.730 total time=   4.8s
# [CV 5/5; 1/48] START classifier__C=0.1, classifier__max_iter=100, classifier__solver=liblinear, transformer__vect_reviewText__max_features=5000, transformer__vect_reviewText__ngram_range=(1, 2), transformer__vect_summary__max_features=10000, transformer__vect_summary__ngram_range=(1, 2)
# [CV 5/5; 1/48] END classifier__C=0.1, classifier__max_iter=100, classifier__solver=liblinear, transformer__vect_reviewText__max_features=5000, transformer__vect_reviewText__ngram_range=(1, 2), transformer__vect_summary__max_features=10000, transformer__vect_summary__ngram_range=(1, 2);, score=0.710 total time=   7.9s
# [CV 1/5; 2/48] START classifier__C=0.1, classifier__max_iter=100, classifier__solver=liblinear, transformer__vect_reviewText__max_features=5000, transformer__vect_reviewText__ngram_range=(1, 2), transformer__vect_summary__max_features=32000, transformer__vect_summary__ngram_range=(1, 2)
# [CV 1/5; 2/48] END classifier__C=0.1, classifier__max_iter=100, classifier__solver=liblinear, transformer__vect_reviewText__max_features=5000, transformer__vect_reviewText__ngram_range=(1, 2), transformer__vect_summary__max_features=32000, transformer__vect_summary__ngram_range=(1, 2);, score=0.712 total time=   8.3s
# [CV 2/5; 2/48] START classifier__C=0.1, classifier__max_iter=100, classifier__solver=liblinear, transformer__vect_reviewText__max_features=5000, transformer__vect_reviewText__ngram_range=(1, 2), transformer__vect_summary__max_features=32000, transformer__vect_summary__ngram_range=(1, 2)
# [CV 2/5; 2/48] END classifier__C=0.1, classifier__max_iter=100, classifier__solver=liblinear, transformer__vect_reviewText__max_features=5000, transformer__vect_reviewText__ngram_range=(1, 2), transformer__vect_summary__max_features=32000, transformer__vect_summary__ngram_range=(1, 2);, score=0.703 total time=   4.8s
# [CV 3/5; 2/48] START classifier__C=0.1, classifier__max_iter=100, classifier__solver=liblinear, transformer__vect_reviewText__max_features=5000, transformer__vect_reviewText__ngram_range=(1, 2), transformer__vect_summary__max_features=32000, transformer__vect_summary__ngram_range=(1, 2)
# [CV 3/5; 2/48] END classifier__C=0.1, classifier__max_iter=100, classifier__solver=liblinear, transformer__vect_reviewText__max_features=5000, transformer__vect_reviewText__ngram_range=(1, 2), transformer__vect_summary__max_features=32000, transformer__vect_summary__ngram_range=(1, 2);, score=0.718 total time=   7.8s
# [CV 4/5; 2/48] START classifier__C=0.1, classifier__max_iter=100, classifier__solver=liblinear, transformer__vect_reviewText__max_features=5000, transformer__vect_reviewText__ngram_range=(1, 2), transformer__vect_summary__max_features=32000, transformer__vect_summary__ngram_range=(1, 2)
# [CV 4/5; 2/48] END classifier__C=0.1, classifier__max_iter=100, classifier__solver=liblinear, transformer__vect_reviewText__max_features=5000, transformer__vect_reviewText__ngram_range=(1, 2), transformer__vect_summary__max_features=32000, transformer__vect_summary__ngram_range=(1, 2);, score=0.728 total time=   6.3s
# [CV 5/5; 2/48] START classifier__C=0.1, classifier__max_iter=100, classifier__solver=liblinear, transformer__vect_reviewText__max_features=5000, transformer__vect_reviewText__ngram_range=(1, 2), transformer__vect_summary__max_features=32000, transformer__vect_summary__ngram_range=(1, 2)
# [CV 5/5; 2/48] END classifier__C=0.1, classifier__max_iter=100, classifier__solver=liblinear, transformer__vect_reviewText__max_features=5000, transformer__vect_reviewText__ngram_range=(1, 2), transformer__vect_summary__max_features=32000, transformer__vect_summary__ngram_range=(1, 2);, score=0.709 total time=   7.1s
# [CV 1/5; 3/48] START classifier__C=0.1, classifier__max_iter=100, classifier__solver=liblinear, transformer__vect_reviewText__max_features=10000, transformer__vect_reviewText__ngram_range=(1, 2), transformer__vect_summary__max_features=10000, transformer__vect_summary__ngram_range=(1, 2)
# [CV 1/5; 3/48] END classifier__C=0.1, classifier__max_iter=100, classifier__solver=liblinear, transformer__vect_reviewText__max_features=10000, transformer__vect_reviewText__ngram_range=(1, 2), transformer__vect_summary__max_features=10000, transformer__vect_summary__ngram_range=(1, 2);, score=0.709 total time=  10.1s
# [CV 2/5; 3/48] START classifier__C=0.1, classifier__max_iter=100, classifier__solver=liblinear, transformer__vect_reviewText__max_features=10000, transformer__vect_reviewText__ngram_range=(1, 2), transformer__vect_summary__max_features=10000, transformer__vect_summary__ngram_range=(1, 2)
# [CV 2/5; 3/48] END classifier__C=0.1, classifier__max_iter=100, classifier__solver=liblinear, transformer__vect_reviewText__max_features=10000, transformer__vect_reviewText__ngram_range=(1, 2), transformer__vect_summary__max_features=10000, transformer__vect_summary__ngram_range=(1, 2);, score=0.704 total time=   8.1s
# [CV 3/5; 3/48] START classifier__C=0.1, classifier__max_iter=100, classifier__solver=liblinear, transformer__vect_reviewText__max_features=10000, transformer__vect_reviewText__ngram_range=(1, 2), transformer__vect_summary__max_features=10000, transformer__vect_summary__ngram_range=(1, 2)
# [CV 3/5; 3/48] END classifier__C=0.1, classifier__max_iter=100, classifier__solver=liblinear, transformer__vect_reviewText__max_features=10000, transformer__vect_reviewText__ngram_range=(1, 2), transformer__vect_summary__max_features=10000, transformer__vect_summary__ngram_range=(1, 2);, score=0.714 total time=   6.2s
# [CV 4/5; 3/48] START classifier__C=0.1, classifier__max_iter=100, classifier__solver=liblinear, transformer__vect_reviewText__max_features=10000, transformer__vect_reviewText__ngram_range=(1, 2), transformer__vect_summary__max_features=10000, transformer__vect_summary__ngram_range=(1, 2)
# [CV 4/5; 3/48] END classifier__C=0.1, classifier__max_iter=100, classifier__solver=liblinear, transformer__vect_reviewText__max_features=10000, transformer__vect_reviewText__ngram_range=(1, 2), transformer__vect_summary__max_features=10000, transformer__vect_summary__ngram_range=(1, 2);, score=0.725 total time=  11.4s
# [CV 5/5; 3/48] START classifier__C=0.1, classifier__max_iter=100, classifier__solver=liblinear, transformer__vect_reviewText__max_features=10000, transformer__vect_reviewText__ngram_range=(1, 2), transformer__vect_summary__max_features=10000, transformer__vect_summary__ngram_range=(1, 2)
# [CV 5/5; 3/48] END classifier__C=0.1, classifier__max_iter=100, classifier__solver=liblinear, transformer__vect_reviewText__max_features=10000, transformer__vect_reviewText__ngram_range=(1, 2), transformer__vect_summary__max_features=10000, transformer__vect_summary__ngram_range=(1, 2);, score=0.706 total time=   9.0s
# [CV 1/5; 4/48] START classifier__C=0.1, classifier__max_iter=100, classifier__solver=liblinear, transformer__vect_reviewText__max_features=10000, transformer__vect_reviewText__ngram_range=(1, 2), transformer__vect_summary__max_features=32000, transformer__vect_summary__ngram_range=(1, 2)
# [CV 1/5; 4/48] END classifier__C=0.1, classifier__max_iter=100, classifier__solver=liblinear, transformer__vect_reviewText__max_features=10000, transformer__vect_reviewText__ngram_range=(1, 2), transformer__vect_summary__max_features=32000, transformer__vect_summary__ngram_range=(1, 2);, score=0.705 total time=   8.5s
# [CV 2/5; 4/48] START classifier__C=0.1, classifier__max_iter=100, classifier__solver=liblinear, transformer__vect_reviewText__max_features=10000, transformer__vect_reviewText__ngram_range=(1, 2), transformer__vect_summary__max_features=32000, transformer__vect_summary__ngram_range=(1, 2)
# [CV 2/5; 4/48] END classifier__C=0.1, classifier__max_iter=100, classifier__solver=liblinear, transformer__vect_reviewText__max_features=10000, transformer__vect_reviewText__ngram_range=(1, 2), transformer__vect_summary__max_features=32000, transformer__vect_summary__ngram_range=(1, 2);, score=0.698 total time=   7.9s
# [CV 3/5; 4/48] START classifier__C=0.1, classifier__max_iter=100, classifier__solver=liblinear, transformer__vect_reviewText__max_features=10000, transformer__vect_reviewText__ngram_range=(1, 2), transformer__vect_summary__max_features=32000, transformer__vect_summary__ngram_range=(1, 2)
# [CV 3/5; 4/48] END classifier__C=0.1, classifier__max_iter=100, classifier__solver=liblinear, transformer__vect_reviewText__max_features=10000, transformer__vect_reviewText__ngram_range=(1, 2), transformer__vect_summary__max_features=32000, transformer__vect_summary__ngram_range=(1, 2);, score=0.714 total time=   9.7s
# [CV 4/5; 4/48] START classifier__C=0.1, classifier__max_iter=100, classifier__solver=liblinear, transformer__vect_reviewText__max_features=10000, transformer__vect_reviewText__ngram_range=(1, 2), transformer__vect_summary__max_features=32000, transformer__vect_summary__ngram_range=(1, 2)
# [CV 4/5; 4/48] END classifier__C=0.1, classifier__max_iter=100, classifier__solver=liblinear, transformer__vect_reviewText__max_features=10000, transformer__vect_reviewText__ngram_range=(1, 2), transformer__vect_summary__max_features=32000, transformer__vect_summary__ngram_range=(1, 2);, score=0.722 total time=   7.7s
# [CV 5/5; 4/48] START classifier__C=0.1, classifier__max_iter=100, classifier__solver=liblinear, transformer__vect_reviewText__max_features=10000, transformer__vect_reviewText__ngram_range=(1, 2), transformer__vect_summary__max_features=32000, transformer__vect_summary__ngram_range=(1, 2)
# [CV 5/5; 4/48] END classifier__C=0.1, classifier__max_iter=100, classifier__solver=liblinear, transformer__vect_reviewText__max_features=10000, transformer__vect_reviewText__ngram_range=(1, 2), transformer__vect_summary__max_features=32000, transformer__vect_summary__ngram_range=(1, 2);, score=0.704 total time=   7.8s
# [CV 1/5; 5/48] START classifier__C=0.1, classifier__max_iter=500, classifier__solver=liblinear, transformer__vect_reviewText__max_features=5000, transformer__vect_reviewText__ngram_range=(1, 2), transformer__vect_summary__max_features=10000, transformer__vect_summary__ngram_range=(1, 2)
# [CV 1/5; 5/48] END classifier__C=0.1, classifier__max_iter=500, classifier__solver=liblinear, transformer__vect_reviewText__max_features=5000, transformer__vect_reviewText__ngram_range=(1, 2), transformer__vect_summary__max_features=10000, transformer__vect_summary__ngram_range=(1, 2);, score=0.715 total time=   9.0s
# [CV 2/5; 5/48] START classifier__C=0.1, classifier__max_iter=500, classifier__solver=liblinear, transformer__vect_reviewText__max_features=5000, transformer__vect_reviewText__ngram_range=(1, 2), transformer__vect_summary__max_features=10000, transformer__vect_summary__ngram_range=(1, 2)
# [CV 2/5; 5/48] END classifier__C=0.1, classifier__max_iter=500, classifier__solver=liblinear, transformer__vect_reviewText__max_features=5000, transformer__vect_reviewText__ngram_range=(1, 2), transformer__vect_summary__max_features=10000, transformer__vect_summary__ngram_range=(1, 2);, score=0.708 total time=   9.0s
# [CV 3/5; 5/48] START classifier__C=0.1, classifier__max_iter=500, classifier__solver=liblinear, transformer__vect_reviewText__max_features=5000, transformer__vect_reviewText__ngram_range=(1, 2), transformer__vect_summary__max_features=10000, transformer__vect_summary__ngram_range=(1, 2)
# [CV 3/5; 5/48] END classifier__C=0.1, classifier__max_iter=500, classifier__solver=liblinear, transformer__vect_reviewText__max_features=5000, transformer__vect_reviewText__ngram_range=(1, 2), transformer__vect_summary__max_features=10000, transformer__vect_summary__ngram_range=(1, 2);, score=0.716 total time=   8.6s
# [CV 4/5; 5/48] START classifier__C=0.1, classifier__max_iter=500, classifier__solver=liblinear, transformer__vect_reviewText__max_features=5000, transformer__vect_reviewText__ngram_range=(1, 2), transformer__vect_summary__max_features=10000, transformer__vect_summary__ngram_range=(1, 2)
# [CV 4/5; 5/48] END classifier__C=0.1, classifier__max_iter=500, classifier__solver=liblinear, transformer__vect_reviewText__max_features=5000, transformer__vect_reviewText__ngram_range=(1, 2), transformer__vect_summary__max_features=10000, transformer__vect_summary__ngram_range=(1, 2);, score=0.730 total time=   7.7s
# [CV 5/5; 5/48] START classifier__C=0.1, classifier__max_iter=500, classifier__solver=liblinear, transformer__vect_reviewText__max_features=5000, transformer__vect_reviewText__ngram_range=(1, 2), transformer__vect_summary__max_features=10000, transformer__vect_summary__ngram_range=(1, 2)
# [CV 5/5; 5/48] END classifier__C=0.1, classifier__max_iter=500, classifier__solver=liblinear, transformer__vect_reviewText__max_features=5000, transformer__vect_reviewText__ngram_range=(1, 2), transformer__vect_summary__max_features=10000, transformer__vect_summary__ngram_range=(1, 2);, score=0.710 total time=   7.7s
# [CV 1/5; 6/48] START classifier__C=0.1, classifier__max_iter=500, classifier__solver=liblinear, transformer__vect_reviewText__max_features=5000, transformer__vect_reviewText__ngram_range=(1, 2), transformer__vect_summary__max_features=32000, transformer__vect_summary__ngram_range=(1, 2)
# [CV 1/5; 6/48] END classifier__C=0.1, classifier__max_iter=500, classifier__solver=liblinear, transformer__vect_reviewText__max_features=5000, transformer__vect_reviewText__ngram_range=(1, 2), transformer__vect_summary__max_features=32000, transformer__vect_summary__ngram_range=(1, 2);, score=0.712 total time=  10.4s
# [CV 2/5; 6/48] START classifier__C=0.1, classifier__max_iter=500, classifier__solver=liblinear, transformer__vect_reviewText__max_features=5000, transformer__vect_reviewText__ngram_range=(1, 2), transformer__vect_summary__max_features=32000, transformer__vect_summary__ngram_range=(1, 2)
# [CV 2/5; 6/48] END classifier__C=0.1, classifier__max_iter=500, classifier__solver=liblinear, transformer__vect_reviewText__max_features=5000, transformer__vect_reviewText__ngram_range=(1, 2), transformer__vect_summary__max_features=32000, transformer__vect_summary__ngram_range=(1, 2);, score=0.703 total time=   7.3s
# [CV 3/5; 6/48] START classifier__C=0.1, classifier__max_iter=500, classifier__solver=liblinear, transformer__vect_reviewText__max_features=5000, transformer__vect_reviewText__ngram_range=(1, 2), transformer__vect_summary__max_features=32000, transformer__vect_summary__ngram_range=(1, 2)
# [CV 3/5; 6/48] END classifier__C=0.1, classifier__max_iter=500, classifier__solver=liblinear, transformer__vect_reviewText__max_features=5000, transformer__vect_reviewText__ngram_range=(1, 2), transformer__vect_summary__max_features=32000, transformer__vect_summary__ngram_range=(1, 2);, score=0.718 total time=   8.7s
# [CV 4/5; 6/48] START classifier__C=0.1, classifier__max_iter=500, classifier__solver=liblinear, transformer__vect_reviewText__max_features=5000, transformer__vect_reviewText__ngram_range=(1, 2), transformer__vect_summary__max_features=32000, transformer__vect_summary__ngram_range=(1, 2)
# [CV 4/5; 6/48] END classifier__C=0.1, classifier__max_iter=500, classifier__solver=liblinear, transformer__vect_reviewText__max_features=5000, transformer__vect_reviewText__ngram_range=(1, 2), transformer__vect_summary__max_features=32000, transformer__vect_summary__ngram_range=(1, 2);, score=0.728 total time=   9.3s
# [CV 5/5; 6/48] START classifier__C=0.1, classifier__max_iter=500, classifier__solver=liblinear, transformer__vect_reviewText__max_features=5000, transformer__vect_reviewText__ngram_range=(1, 2), transformer__vect_summary__max_features=32000, transformer__vect_summary__ngram_range=(1, 2)
# [CV 5/5; 6/48] END classifier__C=0.1, classifier__max_iter=500, classifier__solver=liblinear, transformer__vect_reviewText__max_features=5000, transformer__vect_reviewText__ngram_range=(1, 2), transformer__vect_summary__max_features=32000, transformer__vect_summary__ngram_range=(1, 2);, score=0.709 total time=   8.2s
# [CV 1/5; 7/48] START classifier__C=0.1, classifier__max_iter=500, classifier__solver=liblinear, transformer__vect_reviewText__max_features=10000, transformer__vect_reviewText__ngram_range=(1, 2), transformer__vect_summary__max_features=10000, transformer__vect_summary__ngram_range=(1, 2)
# [CV 1/5; 7/48] END classifier__C=0.1, classifier__max_iter=500, classifier__solver=liblinear, transformer__vect_reviewText__max_features=10000, transformer__vect_reviewText__ngram_range=(1, 2), transformer__vect_summary__max_features=10000, transformer__vect_summary__ngram_range=(1, 2);, score=0.709 total time=   8.1s
# [CV 2/5; 7/48] START classifier__C=0.1, classifier__max_iter=500, classifier__solver=liblinear, transformer__vect_reviewText__max_features=10000, transformer__vect_reviewText__ngram_range=(1, 2), transformer__vect_summary__max_features=10000, transformer__vect_summary__ngram_range=(1, 2)
# [CV 2/5; 7/48] END classifier__C=0.1, classifier__max_iter=500, classifier__solver=liblinear, transformer__vect_reviewText__max_features=10000, transformer__vect_reviewText__ngram_range=(1, 2), transformer__vect_summary__max_features=10000, transformer__vect_summary__ngram_range=(1, 2);, score=0.704 total time=   8.9s
# [CV 3/5; 7/48] START classifier__C=0.1, classifier__max_iter=500, classifier__solver=liblinear, transformer__vect_reviewText__max_features=10000, transformer__vect_reviewText__ngram_range=(1, 2), transformer__vect_summary__max_features=10000, transformer__vect_summary__ngram_range=(1, 2)
# [CV 3/5; 7/48] END classifier__C=0.1, classifier__max_iter=500, classifier__solver=liblinear, transformer__vect_reviewText__max_features=10000, transformer__vect_reviewText__ngram_range=(1, 2), transformer__vect_summary__max_features=10000, transformer__vect_summary__ngram_range=(1, 2);, score=0.714 total time=   9.4s
# [CV 4/5; 7/48] START classifier__C=0.1, classifier__max_iter=500, classifier__solver=liblinear, transformer__vect_reviewText__max_features=10000, transformer__vect_reviewText__ngram_range=(1, 2), transformer__vect_summary__max_features=10000, transformer__vect_summary__ngram_range=(1, 2)
# [CV 4/5; 7/48] END classifier__C=0.1, classifier__max_iter=500, classifier__solver=liblinear, transformer__vect_reviewText__max_features=10000, transformer__vect_reviewText__ngram_range=(1, 2), transformer__vect_summary__max_features=10000, transformer__vect_summary__ngram_range=(1, 2);, score=0.725 total time=   7.2s
# [CV 5/5; 7/48] START classifier__C=0.1, classifier__max_iter=500, classifier__solver=liblinear, transformer__vect_reviewText__max_features=10000, transformer__vect_reviewText__ngram_range=(1, 2), transformer__vect_summary__max_features=10000, transformer__vect_summary__ngram_range=(1, 2)
# [CV 5/5; 7/48] END classifier__C=0.1, classifier__max_iter=500, classifier__solver=liblinear, transformer__vect_reviewText__max_features=10000, transformer__vect_reviewText__ngram_range=(1, 2), transformer__vect_summary__max_features=10000, transformer__vect_summary__ngram_range=(1, 2);, score=0.706 total time=  10.3s
# [CV 1/5; 8/48] START classifier__C=0.1, classifier__max_iter=500, classifier__solver=liblinear, transformer__vect_reviewText__max_features=10000, transformer__vect_reviewText__ngram_range=(1, 2), transformer__vect_summary__max_features=32000, transformer__vect_summary__ngram_range=(1, 2)
# [CV 1/5; 8/48] END classifier__C=0.1, classifier__max_iter=500, classifier__solver=liblinear, transformer__vect_reviewText__max_features=10000, transformer__vect_reviewText__ngram_range=(1, 2), transformer__vect_summary__max_features=32000, transformer__vect_summary__ngram_range=(1, 2);, score=0.705 total time=   6.4s
# [CV 2/5; 8/48] START classifier__C=0.1, classifier__max_iter=500, classifier__solver=liblinear, transformer__vect_reviewText__max_features=10000, transformer__vect_reviewText__ngram_range=(1, 2), transformer__vect_summary__max_features=32000, transformer__vect_summary__ngram_range=(1, 2)
# [CV 2/5; 8/48] END classifier__C=0.1, classifier__max_iter=500, classifier__solver=liblinear, transformer__vect_reviewText__max_features=10000, transformer__vect_reviewText__ngram_range=(1, 2), transformer__vect_summary__max_features=32000, transformer__vect_summary__ngram_range=(1, 2);, score=0.698 total time=   8.3s
# [CV 3/5; 8/48] START classifier__C=0.1, classifier__max_iter=500, classifier__solver=liblinear, transformer__vect_reviewText__max_features=10000, transformer__vect_reviewText__ngram_range=(1, 2), transformer__vect_summary__max_features=32000, transformer__vect_summary__ngram_range=(1, 2)
# [CV 3/5; 8/48] END classifier__C=0.1, classifier__max_iter=500, classifier__solver=liblinear, transformer__vect_reviewText__max_features=10000, transformer__vect_reviewText__ngram_range=(1, 2), transformer__vect_summary__max_features=32000, transformer__vect_summary__ngram_range=(1, 2);, score=0.714 total time=  10.0s
# [CV 4/5; 8/48] START classifier__C=0.1, classifier__max_iter=500, classifier__solver=liblinear, transformer__vect_reviewText__max_features=10000, transformer__vect_reviewText__ngram_range=(1, 2), transformer__vect_summary__max_features=32000, transformer__vect_summary__ngram_range=(1, 2)
# [CV 4/5; 8/48] END classifier__C=0.1, classifier__max_iter=500, classifier__solver=liblinear, transformer__vect_reviewText__max_features=10000, transformer__vect_reviewText__ngram_range=(1, 2), transformer__vect_summary__max_features=32000, transformer__vect_summary__ngram_range=(1, 2);, score=0.722 total time=   5.0s
# [CV 5/5; 8/48] START classifier__C=0.1, classifier__max_iter=500, classifier__solver=liblinear, transformer__vect_reviewText__max_features=10000, transformer__vect_reviewText__ngram_range=(1, 2), transformer__vect_summary__max_features=32000, transformer__vect_summary__ngram_range=(1, 2)
# [CV 5/5; 8/48] END classifier__C=0.1, classifier__max_iter=500, classifier__solver=liblinear, transformer__vect_reviewText__max_features=10000, transformer__vect_reviewText__ngram_range=(1, 2), transformer__vect_summary__max_features=32000, transformer__vect_summary__ngram_range=(1, 2);, score=0.704 total time=   8.3s
# [CV 1/5; 9/48] START classifier__C=0.1, classifier__max_iter=1000, classifier__solver=liblinear, transformer__vect_reviewText__max_features=5000, transformer__vect_reviewText__ngram_range=(1, 2), transformer__vect_summary__max_features=10000, transformer__vect_summary__ngram_range=(1, 2)
# [CV 1/5; 9/48] END classifier__C=0.1, classifier__max_iter=1000, classifier__solver=liblinear, transformer__vect_reviewText__max_features=5000, transformer__vect_reviewText__ngram_range=(1, 2), transformer__vect_summary__max_features=10000, transformer__vect_summary__ngram_range=(1, 2);, score=0.715 total time=   8.7s
# [CV 2/5; 9/48] START classifier__C=0.1, classifier__max_iter=1000, classifier__solver=liblinear, transformer__vect_reviewText__max_features=5000, transformer__vect_reviewText__ngram_range=(1, 2), transformer__vect_summary__max_features=10000, transformer__vect_summary__ngram_range=(1, 2)
# [CV 2/5; 9/48] END classifier__C=0.1, classifier__max_iter=1000, classifier__solver=liblinear, transformer__vect_reviewText__max_features=5000, transformer__vect_reviewText__ngram_range=(1, 2), transformer__vect_summary__max_features=10000, transformer__vect_summary__ngram_range=(1, 2);, score=0.708 total time=   6.0s
# [CV 3/5; 9/48] START classifier__C=0.1, classifier__max_iter=1000, classifier__solver=liblinear, transformer__vect_reviewText__max_features=5000, transformer__vect_reviewText__ngram_range=(1, 2), transformer__vect_summary__max_features=10000, transformer__vect_summary__ngram_range=(1, 2)
# [CV 3/5; 9/48] END classifier__C=0.1, classifier__max_iter=1000, classifier__solver=liblinear, transformer__vect_reviewText__max_features=5000, transformer__vect_reviewText__ngram_range=(1, 2), transformer__vect_summary__max_features=10000, transformer__vect_summary__ngram_range=(1, 2);, score=0.716 total time=  10.0s
# [CV 4/5; 9/48] START classifier__C=0.1, classifier__max_iter=1000, classifier__solver=liblinear, transformer__vect_reviewText__max_features=5000, transformer__vect_reviewText__ngram_range=(1, 2), transformer__vect_summary__max_features=10000, transformer__vect_summary__ngram_range=(1, 2)
# [CV 4/5; 9/48] END classifier__C=0.1, classifier__max_iter=1000, classifier__solver=liblinear, transformer__vect_reviewText__max_features=5000, transformer__vect_reviewText__ngram_range=(1, 2), transformer__vect_summary__max_features=10000, transformer__vect_summary__ngram_range=(1, 2);, score=0.730 total time=   9.3s
# [CV 5/5; 9/48] START classifier__C=0.1, classifier__max_iter=1000, classifier__solver=liblinear, transformer__vect_reviewText__max_features=5000, transformer__vect_reviewText__ngram_range=(1, 2), transformer__vect_summary__max_features=10000, transformer__vect_summary__ngram_range=(1, 2)
# [CV 5/5; 9/48] END classifier__C=0.1, classifier__max_iter=1000, classifier__solver=liblinear, transformer__vect_reviewText__max_features=5000, transformer__vect_reviewText__ngram_range=(1, 2), transformer__vect_summary__max_features=10000, transformer__vect_summary__ngram_range=(1, 2);, score=0.710 total time=   9.8s
# [CV 1/5; 10/48] START classifier__C=0.1, classifier__max_iter=1000, classifier__solver=liblinear, transformer__vect_reviewText__max_features=5000, transformer__vect_reviewText__ngram_range=(1, 2), transformer__vect_summary__max_features=32000, transformer__vect_summary__ngram_range=(1, 2)
# [CV 1/5; 10/48] END classifier__C=0.1, classifier__max_iter=1000, classifier__solver=liblinear, transformer__vect_reviewText__max_features=5000, transformer__vect_reviewText__ngram_range=(1, 2), transformer__vect_summary__max_features=32000, transformer__vect_summary__ngram_range=(1, 2);, score=0.712 total time=   9.7s
# [CV 2/5; 10/48] START classifier__C=0.1, classifier__max_iter=1000, classifier__solver=liblinear, transformer__vect_reviewText__max_features=5000, transformer__vect_reviewText__ngram_range=(1, 2), transformer__vect_summary__max_features=32000, transformer__vect_summary__ngram_range=(1, 2)
# [CV 2/5; 10/48] END classifier__C=0.1, classifier__max_iter=1000, classifier__solver=liblinear, transformer__vect_reviewText__max_features=5000, transformer__vect_reviewText__ngram_range=(1, 2), transformer__vect_summary__max_features=32000, transformer__vect_summary__ngram_range=(1, 2);, score=0.703 total time=   8.3s
# [CV 3/5; 10/48] START classifier__C=0.1, classifier__max_iter=1000, classifier__solver=liblinear, transformer__vect_reviewText__max_features=5000, transformer__vect_reviewText__ngram_range=(1, 2), transformer__vect_summary__max_features=32000, transformer__vect_summary__ngram_range=(1, 2)
# [CV 3/5; 10/48] END classifier__C=0.1, classifier__max_iter=1000, classifier__solver=liblinear, transformer__vect_reviewText__max_features=5000, transformer__vect_reviewText__ngram_range=(1, 2), transformer__vect_summary__max_features=32000, transformer__vect_summary__ngram_range=(1, 2);, score=0.718 total time=   8.7s
# [CV 4/5; 10/48] START classifier__C=0.1, classifier__max_iter=1000, classifier__solver=liblinear, transformer__vect_reviewText__max_features=5000, transformer__vect_reviewText__ngram_range=(1, 2), transformer__vect_summary__max_features=32000, transformer__vect_summary__ngram_range=(1, 2)
# [CV 4/5; 10/48] END classifier__C=0.1, classifier__max_iter=1000, classifier__solver=liblinear, transformer__vect_reviewText__max_features=5000, transformer__vect_reviewText__ngram_range=(1, 2), transformer__vect_summary__max_features=32000, transformer__vect_summary__ngram_range=(1, 2);, score=0.728 total time=   8.7s
# [CV 5/5; 10/48] START classifier__C=0.1, classifier__max_iter=1000, classifier__solver=liblinear, transformer__vect_reviewText__max_features=5000, transformer__vect_reviewText__ngram_range=(1, 2), transformer__vect_summary__max_features=32000, transformer__vect_summary__ngram_range=(1, 2)
# [CV 5/5; 10/48] END classifier__C=0.1, classifier__max_iter=1000, classifier__solver=liblinear, transformer__vect_reviewText__max_features=5000, transformer__vect_reviewText__ngram_range=(1, 2), transformer__vect_summary__max_features=32000, transformer__vect_summary__ngram_range=(1, 2);, score=0.709 total time=   5.3s
# [CV 1/5; 11/48] START classifier__C=0.1, classifier__max_iter=1000, classifier__solver=liblinear, transformer__vect_reviewText__max_features=10000, transformer__vect_reviewText__ngram_range=(1, 2), transformer__vect_summary__max_features=10000, transformer__vect_summary__ngram_range=(1, 2)
# [CV 1/5; 11/48] END classifier__C=0.1, classifier__max_iter=1000, classifier__solver=liblinear, transformer__vect_reviewText__max_features=10000, transformer__vect_reviewText__ngram_range=(1, 2), transformer__vect_summary__max_features=10000, transformer__vect_summary__ngram_range=(1, 2);, score=0.709 total time=  10.5s
# [CV 2/5; 11/48] START classifier__C=0.1, classifier__max_iter=1000, classifier__solver=liblinear, transformer__vect_reviewText__max_features=10000, transformer__vect_reviewText__ngram_range=(1, 2), transformer__vect_summary__max_features=10000, transformer__vect_summary__ngram_range=(1, 2)
# [CV 2/5; 11/48] END classifier__C=0.1, classifier__max_iter=1000, classifier__solver=liblinear, transformer__vect_reviewText__max_features=10000, transformer__vect_reviewText__ngram_range=(1, 2), transformer__vect_summary__max_features=10000, transformer__vect_summary__ngram_range=(1, 2);, score=0.704 total time=   6.9s
# [CV 3/5; 11/48] START classifier__C=0.1, classifier__max_iter=1000, classifier__solver=liblinear, transformer__vect_reviewText__max_features=10000, transformer__vect_reviewText__ngram_range=(1, 2), transformer__vect_summary__max_features=10000, transformer__vect_summary__ngram_range=(1, 2)
# [CV 3/5; 11/48] END classifier__C=0.1, classifier__max_iter=1000, classifier__solver=liblinear, transformer__vect_reviewText__max_features=10000, transformer__vect_reviewText__ngram_range=(1, 2), transformer__vect_summary__max_features=10000, transformer__vect_summary__ngram_range=(1, 2);, score=0.714 total time=  11.2s
# [CV 4/5; 11/48] START classifier__C=0.1, classifier__max_iter=1000, classifier__solver=liblinear, transformer__vect_reviewText__max_features=10000, transformer__vect_reviewText__ngram_range=(1, 2), transformer__vect_summary__max_features=10000, transformer__vect_summary__ngram_range=(1, 2)
# [CV 4/5; 11/48] END classifier__C=0.1, classifier__max_iter=1000, classifier__solver=liblinear, transformer__vect_reviewText__max_features=10000, transformer__vect_reviewText__ngram_range=(1, 2), transformer__vect_summary__max_features=10000, transformer__vect_summary__ngram_range=(1, 2);, score=0.725 total time=  10.6s
# [CV 5/5; 11/48] START classifier__C=0.1, classifier__max_iter=1000, classifier__solver=liblinear, transformer__vect_reviewText__max_features=10000, transformer__vect_reviewText__ngram_range=(1, 2), transformer__vect_summary__max_features=10000, transformer__vect_summary__ngram_range=(1, 2)
# [CV 5/5; 11/48] END classifier__C=0.1, classifier__max_iter=1000, classifier__solver=liblinear, transformer__vect_reviewText__max_features=10000, transformer__vect_reviewText__ngram_range=(1, 2), transformer__vect_summary__max_features=10000, transformer__vect_summary__ngram_range=(1, 2);, score=0.706 total time=   7.2s
# [CV 1/5; 12/48] START classifier__C=0.1, classifier__max_iter=1000, classifier__solver=liblinear, transformer__vect_reviewText__max_features=10000, transformer__vect_reviewText__ngram_range=(1, 2), transformer__vect_summary__max_features=32000, transformer__vect_summary__ngram_range=(1, 2)
# [CV 1/5; 12/48] END classifier__C=0.1, classifier__max_iter=1000, classifier__solver=liblinear, transformer__vect_reviewText__max_features=10000, transformer__vect_reviewText__ngram_range=(1, 2), transformer__vect_summary__max_features=32000, transformer__vect_summary__ngram_range=(1, 2);, score=0.705 total time=  10.0s
# [CV 2/5; 12/48] START classifier__C=0.1, classifier__max_iter=1000, classifier__solver=liblinear, transformer__vect_reviewText__max_features=10000, transformer__vect_reviewText__ngram_range=(1, 2), transformer__vect_summary__max_features=32000, transformer__vect_summary__ngram_range=(1, 2)
# [CV 2/5; 12/48] END classifier__C=0.1, classifier__max_iter=1000, classifier__solver=liblinear, transformer__vect_reviewText__max_features=10000, transformer__vect_reviewText__ngram_range=(1, 2), transformer__vect_summary__max_features=32000, transformer__vect_summary__ngram_range=(1, 2);, score=0.698 total time=  10.7s
# [CV 3/5; 12/48] START classifier__C=0.1, classifier__max_iter=1000, classifier__solver=liblinear, transformer__vect_reviewText__max_features=10000, transformer__vect_reviewText__ngram_range=(1, 2), transformer__vect_summary__max_features=32000, transformer__vect_summary__ngram_range=(1, 2)
# [CV 3/5; 12/48] END classifier__C=0.1, classifier__max_iter=1000, classifier__solver=liblinear, transformer__vect_reviewText__max_features=10000, transformer__vect_reviewText__ngram_range=(1, 2), transformer__vect_summary__max_features=32000, transformer__vect_summary__ngram_range=(1, 2);, score=0.714 total time=   7.2s
# [CV 4/5; 12/48] START classifier__C=0.1, classifier__max_iter=1000, classifier__solver=liblinear, transformer__vect_reviewText__max_features=10000, transformer__vect_reviewText__ngram_range=(1, 2), transformer__vect_summary__max_features=32000, transformer__vect_summary__ngram_range=(1, 2)
# [CV 4/5; 12/48] END classifier__C=0.1, classifier__max_iter=1000, classifier__solver=liblinear, transformer__vect_reviewText__max_features=10000, transformer__vect_reviewText__ngram_range=(1, 2), transformer__vect_summary__max_features=32000, transformer__vect_summary__ngram_range=(1, 2);, score=0.722 total time=   9.6s
# [CV 5/5; 12/48] START classifier__C=0.1, classifier__max_iter=1000, classifier__solver=liblinear, transformer__vect_reviewText__max_features=10000, transformer__vect_reviewText__ngram_range=(1, 2), transformer__vect_summary__max_features=32000, transformer__vect_summary__ngram_range=(1, 2)
# [CV 5/5; 12/48] END classifier__C=0.1, classifier__max_iter=1000, classifier__solver=liblinear, transformer__vect_reviewText__max_features=10000, transformer__vect_reviewText__ngram_range=(1, 2), transformer__vect_summary__max_features=32000, transformer__vect_summary__ngram_range=(1, 2);, score=0.704 total time=  10.9s
# [CV 1/5; 13/48] START classifier__C=1.0, classifier__max_iter=100, classifier__solver=liblinear, transformer__vect_reviewText__max_features=5000, transformer__vect_reviewText__ngram_range=(1, 2), transformer__vect_summary__max_features=10000, transformer__vect_summary__ngram_range=(1, 2)
# [CV 1/5; 13/48] END classifier__C=1.0, classifier__max_iter=100, classifier__solver=liblinear, transformer__vect_reviewText__max_features=5000, transformer__vect_reviewText__ngram_range=(1, 2), transformer__vect_summary__max_features=10000, transformer__vect_summary__ngram_range=(1, 2);, score=0.797 total time=  10.8s
# [CV 2/5; 13/48] START classifier__C=1.0, classifier__max_iter=100, classifier__solver=liblinear, transformer__vect_reviewText__max_features=5000, transformer__vect_reviewText__ngram_range=(1, 2), transformer__vect_summary__max_features=10000, transformer__vect_summary__ngram_range=(1, 2)
# [CV 2/5; 13/48] END classifier__C=1.0, classifier__max_iter=100, classifier__solver=liblinear, transformer__vect_reviewText__max_features=5000, transformer__vect_reviewText__ngram_range=(1, 2), transformer__vect_summary__max_features=10000, transformer__vect_summary__ngram_range=(1, 2);, score=0.793 total time=  12.8s
# [CV 3/5; 13/48] START classifier__C=1.0, classifier__max_iter=100, classifier__solver=liblinear, transformer__vect_reviewText__max_features=5000, transformer__vect_reviewText__ngram_range=(1, 2), transformer__vect_summary__max_features=10000, transformer__vect_summary__ngram_range=(1, 2)
# [CV 3/5; 13/48] END classifier__C=1.0, classifier__max_iter=100, classifier__solver=liblinear, transformer__vect_reviewText__max_features=5000, transformer__vect_reviewText__ngram_range=(1, 2), transformer__vect_summary__max_features=10000, transformer__vect_summary__ngram_range=(1, 2);, score=0.806 total time=   8.0s
# [CV 4/5; 13/48] START classifier__C=1.0, classifier__max_iter=100, classifier__solver=liblinear, transformer__vect_reviewText__max_features=5000, transformer__vect_reviewText__ngram_range=(1, 2), transformer__vect_summary__max_features=10000, transformer__vect_summary__ngram_range=(1, 2)
# [CV 4/5; 13/48] END classifier__C=1.0, classifier__max_iter=100, classifier__solver=liblinear, transformer__vect_reviewText__max_features=5000, transformer__vect_reviewText__ngram_range=(1, 2), transformer__vect_summary__max_features=10000, transformer__vect_summary__ngram_range=(1, 2);, score=0.821 total time=  13.6s
# [CV 5/5; 13/48] START classifier__C=1.0, classifier__max_iter=100, classifier__solver=liblinear, transformer__vect_reviewText__max_features=5000, transformer__vect_reviewText__ngram_range=(1, 2), transformer__vect_summary__max_features=10000, transformer__vect_summary__ngram_range=(1, 2)
# [CV 5/5; 13/48] END classifier__C=1.0, classifier__max_iter=100, classifier__solver=liblinear, transformer__vect_reviewText__max_features=5000, transformer__vect_reviewText__ngram_range=(1, 2), transformer__vect_summary__max_features=10000, transformer__vect_summary__ngram_range=(1, 2);, score=0.787 total time=  11.9s
# [CV 1/5; 14/48] START classifier__C=1.0, classifier__max_iter=100, classifier__solver=liblinear, transformer__vect_reviewText__max_features=5000, transformer__vect_reviewText__ngram_range=(1, 2), transformer__vect_summary__max_features=32000, transformer__vect_summary__ngram_range=(1, 2)
# [CV 1/5; 14/48] END classifier__C=1.0, classifier__max_iter=100, classifier__solver=liblinear, transformer__vect_reviewText__max_features=5000, transformer__vect_reviewText__ngram_range=(1, 2), transformer__vect_summary__max_features=32000, transformer__vect_summary__ngram_range=(1, 2);, score=0.798 total time=   9.9s
# [CV 2/5; 14/48] START classifier__C=1.0, classifier__max_iter=100, classifier__solver=liblinear, transformer__vect_reviewText__max_features=5000, transformer__vect_reviewText__ngram_range=(1, 2), transformer__vect_summary__max_features=32000, transformer__vect_summary__ngram_range=(1, 2)
# [CV 2/5; 14/48] END classifier__C=1.0, classifier__max_iter=100, classifier__solver=liblinear, transformer__vect_reviewText__max_features=5000, transformer__vect_reviewText__ngram_range=(1, 2), transformer__vect_summary__max_features=32000, transformer__vect_summary__ngram_range=(1, 2);, score=0.793 total time=   9.7s
# [CV 3/5; 14/48] START classifier__C=1.0, classifier__max_iter=100, classifier__solver=liblinear, transformer__vect_reviewText__max_features=5000, transformer__vect_reviewText__ngram_range=(1, 2), transformer__vect_summary__max_features=32000, transformer__vect_summary__ngram_range=(1, 2)
# [CV 3/5; 14/48] END classifier__C=1.0, classifier__max_iter=100, classifier__solver=liblinear, transformer__vect_reviewText__max_features=5000, transformer__vect_reviewText__ngram_range=(1, 2), transformer__vect_summary__max_features=32000, transformer__vect_summary__ngram_range=(1, 2);, score=0.806 total time=  12.7s
# [CV 4/5; 14/48] START classifier__C=1.0, classifier__max_iter=100, classifier__solver=liblinear, transformer__vect_reviewText__max_features=5000, transformer__vect_reviewText__ngram_range=(1, 2), transformer__vect_summary__max_features=32000, transformer__vect_summary__ngram_range=(1, 2)
# [CV 4/5; 14/48] END classifier__C=1.0, classifier__max_iter=100, classifier__solver=liblinear, transformer__vect_reviewText__max_features=5000, transformer__vect_reviewText__ngram_range=(1, 2), transformer__vect_summary__max_features=32000, transformer__vect_summary__ngram_range=(1, 2);, score=0.818 total time=  13.5s
# [CV 5/5; 14/48] START classifier__C=1.0, classifier__max_iter=100, classifier__solver=liblinear, transformer__vect_reviewText__max_features=5000, transformer__vect_reviewText__ngram_range=(1, 2), transformer__vect_summary__max_features=32000, transformer__vect_summary__ngram_range=(1, 2)
# [CV 5/5; 14/48] END classifier__C=1.0, classifier__max_iter=100, classifier__solver=liblinear, transformer__vect_reviewText__max_features=5000, transformer__vect_reviewText__ngram_range=(1, 2), transformer__vect_summary__max_features=32000, transformer__vect_summary__ngram_range=(1, 2);, score=0.786 total time=   8.9s
# [CV 1/5; 15/48] START classifier__C=1.0, classifier__max_iter=100, classifier__solver=liblinear, transformer__vect_reviewText__max_features=10000, transformer__vect_reviewText__ngram_range=(1, 2), transformer__vect_summary__max_features=10000, transformer__vect_summary__ngram_range=(1, 2)
# [CV 1/5; 15/48] END classifier__C=1.0, classifier__max_iter=100, classifier__solver=liblinear, transformer__vect_reviewText__max_features=10000, transformer__vect_reviewText__ngram_range=(1, 2), transformer__vect_summary__max_features=10000, transformer__vect_summary__ngram_range=(1, 2);, score=0.794 total time=   7.4s
# [CV 2/5; 15/48] START classifier__C=1.0, classifier__max_iter=100, classifier__solver=liblinear, transformer__vect_reviewText__max_features=10000, transformer__vect_reviewText__ngram_range=(1, 2), transformer__vect_summary__max_features=10000, transformer__vect_summary__ngram_range=(1, 2)
# [CV 2/5; 15/48] END classifier__C=1.0, classifier__max_iter=100, classifier__solver=liblinear, transformer__vect_reviewText__max_features=10000, transformer__vect_reviewText__ngram_range=(1, 2), transformer__vect_summary__max_features=10000, transformer__vect_summary__ngram_range=(1, 2);, score=0.787 total time=  12.8s
# [CV 3/5; 15/48] START classifier__C=1.0, classifier__max_iter=100, classifier__solver=liblinear, transformer__vect_reviewText__max_features=10000, transformer__vect_reviewText__ngram_range=(1, 2), transformer__vect_summary__max_features=10000, transformer__vect_summary__ngram_range=(1, 2)
# [CV 3/5; 15/48] END classifier__C=1.0, classifier__max_iter=100, classifier__solver=liblinear, transformer__vect_reviewText__max_features=10000, transformer__vect_reviewText__ngram_range=(1, 2), transformer__vect_summary__max_features=10000, transformer__vect_summary__ngram_range=(1, 2);, score=0.796 total time=  15.0s
# [CV 4/5; 15/48] START classifier__C=1.0, classifier__max_iter=100, classifier__solver=liblinear, transformer__vect_reviewText__max_features=10000, transformer__vect_reviewText__ngram_range=(1, 2), transformer__vect_summary__max_features=10000, transformer__vect_summary__ngram_range=(1, 2)
# [CV 4/5; 15/48] END classifier__C=1.0, classifier__max_iter=100, classifier__solver=liblinear, transformer__vect_reviewText__max_features=10000, transformer__vect_reviewText__ngram_range=(1, 2), transformer__vect_summary__max_features=10000, transformer__vect_summary__ngram_range=(1, 2);, score=0.812 total time=  10.8s
# [CV 5/5; 15/48] START classifier__C=1.0, classifier__max_iter=100, classifier__solver=liblinear, transformer__vect_reviewText__max_features=10000, transformer__vect_reviewText__ngram_range=(1, 2), transformer__vect_summary__max_features=10000, transformer__vect_summary__ngram_range=(1, 2)
# [CV 5/5; 15/48] END classifier__C=1.0, classifier__max_iter=100, classifier__solver=liblinear, transformer__vect_reviewText__max_features=10000, transformer__vect_reviewText__ngram_range=(1, 2), transformer__vect_summary__max_features=10000, transformer__vect_summary__ngram_range=(1, 2);, score=0.787 total time=  10.0s
# [CV 1/5; 16/48] START classifier__C=1.0, classifier__max_iter=100, classifier__solver=liblinear, transformer__vect_reviewText__max_features=10000, transformer__vect_reviewText__ngram_range=(1, 2), transformer__vect_summary__max_features=32000, transformer__vect_summary__ngram_range=(1, 2)
# [CV 1/5; 16/48] END classifier__C=1.0, classifier__max_iter=100, classifier__solver=liblinear, transformer__vect_reviewText__max_features=10000, transformer__vect_reviewText__ngram_range=(1, 2), transformer__vect_summary__max_features=32000, transformer__vect_summary__ngram_range=(1, 2);, score=0.794 total time=  13.0s
# [CV 2/5; 16/48] START classifier__C=1.0, classifier__max_iter=100, classifier__solver=liblinear, transformer__vect_reviewText__max_features=10000, transformer__vect_reviewText__ngram_range=(1, 2), transformer__vect_summary__max_features=32000, transformer__vect_summary__ngram_range=(1, 2)
# [CV 2/5; 16/48] END classifier__C=1.0, classifier__max_iter=100, classifier__solver=liblinear, transformer__vect_reviewText__max_features=10000, transformer__vect_reviewText__ngram_range=(1, 2), transformer__vect_summary__max_features=32000, transformer__vect_summary__ngram_range=(1, 2);, score=0.787 total time=   9.7s
# [CV 3/5; 16/48] START classifier__C=1.0, classifier__max_iter=100, classifier__solver=liblinear, transformer__vect_reviewText__max_features=10000, transformer__vect_reviewText__ngram_range=(1, 2), transformer__vect_summary__max_features=32000, transformer__vect_summary__ngram_range=(1, 2)
# [CV 3/5; 16/48] END classifier__C=1.0, classifier__max_iter=100, classifier__solver=liblinear, transformer__vect_reviewText__max_features=10000, transformer__vect_reviewText__ngram_range=(1, 2), transformer__vect_summary__max_features=32000, transformer__vect_summary__ngram_range=(1, 2);, score=0.801 total time=   8.0s
# [CV 4/5; 16/48] START classifier__C=1.0, classifier__max_iter=100, classifier__solver=liblinear, transformer__vect_reviewText__max_features=10000, transformer__vect_reviewText__ngram_range=(1, 2), transformer__vect_summary__max_features=32000, transformer__vect_summary__ngram_range=(1, 2)
# ...
# [CV 1/5; 44/48] START classifier__C=10.0, classifier__max_iter=500, classifier__solver=liblinear, transformer__vect_reviewText__max_features=10000, transformer__vect_reviewText__ngram_range=(1, 2), transformer__vect_summary__max_features=32000, transformer__vect_summary__ngram_range=(1, 2)
# [CV 1/5; 44/48] END classifier__C=10.0, classifier__max_iter=500, classifier__solver=liblinear, transformer__vect_reviewText__max_features=10000, transformer__vect_reviewText__ngram_range=(1, 2), transformer__vect_summary__max_features=32000, transformer__vect_summary__ngram_range=(1, 2);, score=0.811 total time=  10.6s
# [CV 2/5; 44/48] START classifier__C=10.0, classifier__max_iter=500, classifier__solver=liblinear, transformer__vect_reviewText__max_features=10000, transformer__vect_reviewText__ngram_range=(1, 2), transformer__vect_summary__max_features=32000, transformer__vect_summary__ngram_range=(1, 2)
# [CV 2/5; 44/48] END classifier__C=10.0, classifier__max_iter=500, classifier__solver=liblinear, transformer__vect_reviewText__max_features=10000, transformer__vect_reviewText__ngram_range=(1, 2), transformer__vect_summary__max_features=32000, transformer__vect_summary__ngram_range=(1, 2);, score=0.794 total time=  10.6s
# [CV 3/5; 44/48] START classifier__C=10.0, classifier__max_iter=500, classifier__solver=liblinear, transformer__vect_reviewText__max_features=10000, transformer__vect_reviewText__ngram_range=(1, 2), transformer__vect_summary__max_features=32000, transformer__vect_summary__ngram_range=(1, 2)
# [CV 3/5; 44/48] END classifier__C=10.0, classifier__max_iter=500, classifier__solver=liblinear, transformer__vect_reviewText__max_features=10000, transformer__vect_reviewText__ngram_range=(1, 2), transformer__vect_summary__max_features=32000, transformer__vect_summary__ngram_range=(1, 2);, score=0.806 total time=  13.5s
# [CV 4/5; 44/48] START classifier__C=10.0, classifier__max_iter=500, classifier__solver=liblinear, transformer__vect_reviewText__max_features=10000, transformer__vect_reviewText__ngram_range=(1, 2), transformer__vect_summary__max_features=32000, transformer__vect_summary__ngram_range=(1, 2)
# [CV 4/5; 44/48] END classifier__C=10.0, classifier__max_iter=500, classifier__solver=liblinear, transformer__vect_reviewText__max_features=10000, transformer__vect_reviewText__ngram_range=(1, 2), transformer__vect_summary__max_features=32000, transformer__vect_summary__ngram_range=(1, 2);, score=0.814 total time=  14.0s
# [CV 5/5; 44/48] START classifier__C=10.0, classifier__max_iter=500, classifier__solver=liblinear, transformer__vect_reviewText__max_features=10000, transformer__vect_reviewText__ngram_range=(1, 2), transformer__vect_summary__max_features=32000, transformer__vect_summary__ngram_range=(1, 2)
# [CV 5/5; 44/48] END classifier__C=10.0, classifier__max_iter=500, classifier__solver=liblinear, transformer__vect_reviewText__max_features=10000, transformer__vect_reviewText__ngram_range=(1, 2), transformer__vect_summary__max_features=32000, transformer__vect_summary__ngram_range=(1, 2);, score=0.799 total time=  12.2s
# [CV 1/5; 45/48] START classifier__C=10.0, classifier__max_iter=1000, classifier__solver=liblinear, transformer__vect_reviewText__max_features=5000, transformer__vect_reviewText__ngram_range=(1, 2), transformer__vect_summary__max_features=10000, transformer__vect_summary__ngram_range=(1, 2)
# [CV 1/5; 45/48] END classifier__C=10.0, classifier__max_iter=1000, classifier__solver=liblinear, transformer__vect_reviewText__max_features=5000, transformer__vect_reviewText__ngram_range=(1, 2), transformer__vect_summary__max_features=10000, transformer__vect_summary__ngram_range=(1, 2);, score=0.807 total time=  16.9s
# [CV 2/5; 45/48] START classifier__C=10.0, classifier__max_iter=1000, classifier__solver=liblinear, transformer__vect_reviewText__max_features=5000, transformer__vect_reviewText__ngram_range=(1, 2), transformer__vect_summary__max_features=10000, transformer__vect_summary__ngram_range=(1, 2)
# [CV 2/5; 45/48] END classifier__C=10.0, classifier__max_iter=1000, classifier__solver=liblinear, transformer__vect_reviewText__max_features=5000, transformer__vect_reviewText__ngram_range=(1, 2), transformer__vect_summary__max_features=10000, transformer__vect_summary__ngram_range=(1, 2);, score=0.790 total time=  16.7s
# [CV 3/5; 45/48] START classifier__C=10.0, classifier__max_iter=1000, classifier__solver=liblinear, transformer__vect_reviewText__max_features=5000, transformer__vect_reviewText__ngram_range=(1, 2), transformer__vect_summary__max_features=10000, transformer__vect_summary__ngram_range=(1, 2)
# [CV 3/5; 45/48] END classifier__C=10.0, classifier__max_iter=1000, classifier__solver=liblinear, transformer__vect_reviewText__max_features=5000, transformer__vect_reviewText__ngram_range=(1, 2), transformer__vect_summary__max_features=10000, transformer__vect_summary__ngram_range=(1, 2);, score=0.801 total time=  11.5s
# [CV 4/5; 45/48] START classifier__C=10.0, classifier__max_iter=1000, classifier__solver=liblinear, transformer__vect_reviewText__max_features=5000, transformer__vect_reviewText__ngram_range=(1, 2), transformer__vect_summary__max_features=10000, transformer__vect_summary__ngram_range=(1, 2)
# [CV 4/5; 45/48] END classifier__C=10.0, classifier__max_iter=1000, classifier__solver=liblinear, transformer__vect_reviewText__max_features=5000, transformer__vect_reviewText__ngram_range=(1, 2), transformer__vect_summary__max_features=10000, transformer__vect_summary__ngram_range=(1, 2);, score=0.811 total time=  11.0s
# [CV 5/5; 45/48] START classifier__C=10.0, classifier__max_iter=1000, classifier__solver=liblinear, transformer__vect_reviewText__max_features=5000, transformer__vect_reviewText__ngram_range=(1, 2), transformer__vect_summary__max_features=10000, transformer__vect_summary__ngram_range=(1, 2)
# [CV 5/5; 45/48] END classifier__C=10.0, classifier__max_iter=1000, classifier__solver=liblinear, transformer__vect_reviewText__max_features=5000, transformer__vect_reviewText__ngram_range=(1, 2), transformer__vect_summary__max_features=10000, transformer__vect_summary__ngram_range=(1, 2);, score=0.794 total time=  11.6s
# [CV 1/5; 46/48] START classifier__C=10.0, classifier__max_iter=1000, classifier__solver=liblinear, transformer__vect_reviewText__max_features=5000, transformer__vect_reviewText__ngram_range=(1, 2), transformer__vect_summary__max_features=32000, transformer__vect_summary__ngram_range=(1, 2)
# [CV 1/5; 46/48] END classifier__C=10.0, classifier__max_iter=1000, classifier__solver=liblinear, transformer__vect_reviewText__max_features=5000, transformer__vect_reviewText__ngram_range=(1, 2), transformer__vect_summary__max_features=32000, transformer__vect_summary__ngram_range=(1, 2);, score=0.811 total time=  10.2s
# [CV 2/5; 46/48] START classifier__C=10.0, classifier__max_iter=1000, classifier__solver=liblinear, transformer__vect_reviewText__max_features=5000, transformer__vect_reviewText__ngram_range=(1, 2), transformer__vect_summary__max_features=32000, transformer__vect_summary__ngram_range=(1, 2)
# [CV 2/5; 46/48] END classifier__C=10.0, classifier__max_iter=1000, classifier__solver=liblinear, transformer__vect_reviewText__max_features=5000, transformer__vect_reviewText__ngram_range=(1, 2), transformer__vect_summary__max_features=32000, transformer__vect_summary__ngram_range=(1, 2);, score=0.795 total time=  10.5s
# [CV 3/5; 46/48] START classifier__C=10.0, classifier__max_iter=1000, classifier__solver=liblinear, transformer__vect_reviewText__max_features=5000, transformer__vect_reviewText__ngram_range=(1, 2), transformer__vect_summary__max_features=32000, transformer__vect_summary__ngram_range=(1, 2)
# [CV 3/5; 46/48] END classifier__C=10.0, classifier__max_iter=1000, classifier__solver=liblinear, transformer__vect_reviewText__max_features=5000, transformer__vect_reviewText__ngram_range=(1, 2), transformer__vect_summary__max_features=32000, transformer__vect_summary__ngram_range=(1, 2);, score=0.802 total time=  10.9s
# [CV 4/5; 46/48] START classifier__C=10.0, classifier__max_iter=1000, classifier__solver=liblinear, transformer__vect_reviewText__max_features=5000, transformer__vect_reviewText__ngram_range=(1, 2), transformer__vect_summary__max_features=32000, transformer__vect_summary__ngram_range=(1, 2)
# [CV 4/5; 46/48] END classifier__C=10.0, classifier__max_iter=1000, classifier__solver=liblinear, transformer__vect_reviewText__max_features=5000, transformer__vect_reviewText__ngram_range=(1, 2), transformer__vect_summary__max_features=32000, transformer__vect_summary__ngram_range=(1, 2);, score=0.817 total time=   8.7s
# [CV 5/5; 46/48] START classifier__C=10.0, classifier__max_iter=1000, classifier__solver=liblinear, transformer__vect_reviewText__max_features=5000, transformer__vect_reviewText__ngram_range=(1, 2), transformer__vect_summary__max_features=32000, transformer__vect_summary__ngram_range=(1, 2)
# [CV 5/5; 46/48] END classifier__C=10.0, classifier__max_iter=1000, classifier__solver=liblinear, transformer__vect_reviewText__max_features=5000, transformer__vect_reviewText__ngram_range=(1, 2), transformer__vect_summary__max_features=32000, transformer__vect_summary__ngram_range=(1, 2);, score=0.798 total time=   9.4s
# [CV 1/5; 47/48] START classifier__C=10.0, classifier__max_iter=1000, classifier__solver=liblinear, transformer__vect_reviewText__max_features=10000, transformer__vect_reviewText__ngram_range=(1, 2), transformer__vect_summary__max_features=10000, transformer__vect_summary__ngram_range=(1, 2)
# [CV 1/5; 47/48] END classifier__C=10.0, classifier__max_iter=1000, classifier__solver=liblinear, transformer__vect_reviewText__max_features=10000, transformer__vect_reviewText__ngram_range=(1, 2), transformer__vect_summary__max_features=10000, transformer__vect_summary__ngram_range=(1, 2);, score=0.807 total time=   6.1s
# [CV 2/5; 47/48] START classifier__C=10.0, classifier__max_iter=1000, classifier__solver=liblinear, transformer__vect_reviewText__max_features=10000, transformer__vect_reviewText__ngram_range=(1, 2), transformer__vect_summary__max_features=10000, transformer__vect_summary__ngram_range=(1, 2)
# [CV 2/5; 47/48] END classifier__C=10.0, classifier__max_iter=1000, classifier__solver=liblinear, transformer__vect_reviewText__max_features=10000, transformer__vect_reviewText__ngram_range=(1, 2), transformer__vect_summary__max_features=10000, transformer__vect_summary__ngram_range=(1, 2);, score=0.789 total time=   5.9s
# [CV 3/5; 47/48] START classifier__C=10.0, classifier__max_iter=1000, classifier__solver=liblinear, transformer__vect_reviewText__max_features=10000, transformer__vect_reviewText__ngram_range=(1, 2), transformer__vect_summary__max_features=10000, transformer__vect_summary__ngram_range=(1, 2)
# [CV 3/5; 47/48] END classifier__C=10.0, classifier__max_iter=1000, classifier__solver=liblinear, transformer__vect_reviewText__max_features=10000, transformer__vect_reviewText__ngram_range=(1, 2), transformer__vect_summary__max_features=10000, transformer__vect_summary__ngram_range=(1, 2);, score=0.805 total time=   7.2s
# [CV 4/5; 47/48] START classifier__C=10.0, classifier__max_iter=1000, classifier__solver=liblinear, transformer__vect_reviewText__max_features=10000, transformer__vect_reviewText__ngram_range=(1, 2), transformer__vect_summary__max_features=10000, transformer__vect_summary__ngram_range=(1, 2)
# [CV 4/5; 47/48] END classifier__C=10.0, classifier__max_iter=1000, classifier__solver=liblinear, transformer__vect_reviewText__max_features=10000, transformer__vect_reviewText__ngram_range=(1, 2), transformer__vect_summary__max_features=10000, transformer__vect_summary__ngram_range=(1, 2);, score=0.811 total time=   5.1s
# [CV 5/5; 47/48] START classifier__C=10.0, classifier__max_iter=1000, classifier__solver=liblinear, transformer__vect_reviewText__max_features=10000, transformer__vect_reviewText__ngram_range=(1, 2), transformer__vect_summary__max_features=10000, transformer__vect_summary__ngram_range=(1, 2)
# [CV 5/5; 47/48] END classifier__C=10.0, classifier__max_iter=1000, classifier__solver=liblinear, transformer__vect_reviewText__max_features=10000, transformer__vect_reviewText__ngram_range=(1, 2), transformer__vect_summary__max_features=10000, transformer__vect_summary__ngram_range=(1, 2);, score=0.800 total time=   6.0s
# [CV 1/5; 48/48] START classifier__C=10.0, classifier__max_iter=1000, classifier__solver=liblinear, transformer__vect_reviewText__max_features=10000, transformer__vect_reviewText__ngram_range=(1, 2), transformer__vect_summary__max_features=32000, transformer__vect_summary__ngram_range=(1, 2)
# [CV 1/5; 48/48] END classifier__C=10.0, classifier__max_iter=1000, classifier__solver=liblinear, transformer__vect_reviewText__max_features=10000, transformer__vect_reviewText__ngram_range=(1, 2), transformer__vect_summary__max_features=32000, transformer__vect_summary__ngram_range=(1, 2);, score=0.811 total time=   5.3s
# [CV 2/5; 48/48] START classifier__C=10.0, classifier__max_iter=1000, classifier__solver=liblinear, transformer__vect_reviewText__max_features=10000, transformer__vect_reviewText__ngram_range=(1, 2), transformer__vect_summary__max_features=32000, transformer__vect_summary__ngram_range=(1, 2)
# [CV 2/5; 48/48] END classifier__C=10.0, classifier__max_iter=1000, classifier__solver=liblinear, transformer__vect_reviewText__max_features=10000, transformer__vect_reviewText__ngram_range=(1, 2), transformer__vect_summary__max_features=32000, transformer__vect_summary__ngram_range=(1, 2);, score=0.794 total time=   5.9s
# [CV 3/5; 48/48] START classifier__C=10.0, classifier__max_iter=1000, classifier__solver=liblinear, transformer__vect_reviewText__max_features=10000, transformer__vect_reviewText__ngram_range=(1, 2), transformer__vect_summary__max_features=32000, transformer__vect_summary__ngram_range=(1, 2)
# [CV 3/5; 48/48] END classifier__C=10.0, classifier__max_iter=1000, classifier__solver=liblinear, transformer__vect_reviewText__max_features=10000, transformer__vect_reviewText__ngram_range=(1, 2), transformer__vect_summary__max_features=32000, transformer__vect_summary__ngram_range=(1, 2);, score=0.806 total time=   5.3s
# [CV 4/5; 48/48] START classifier__C=10.0, classifier__max_iter=1000, classifier__solver=liblinear, transformer__vect_reviewText__max_features=10000, transformer__vect_reviewText__ngram_range=(1, 2), transformer__vect_summary__max_features=32000, transformer__vect_summary__ngram_range=(1, 2)
# [CV 4/5; 48/48] END classifier__C=10.0, classifier__max_iter=1000, classifier__solver=liblinear, transformer__vect_reviewText__max_features=10000, transformer__vect_reviewText__ngram_range=(1, 2), transformer__vect_summary__max_features=32000, transformer__vect_summary__ngram_range=(1, 2);, score=0.814 total time=   7.1s
# [CV 5/5; 48/48] START classifier__C=10.0, classifier__max_iter=1000, classifier__solver=liblinear, transformer__vect_reviewText__max_features=10000, transformer__vect_reviewText__ngram_range=(1, 2), transformer__vect_summary__max_features=32000, transformer__vect_summary__ngram_range=(1, 2)
# [CV 5/5; 48/48] END classifier__C=10.0, classifier__max_iter=1000, classifier__solver=liblinear, transformer__vect_reviewText__max_features=10000, transformer__vect_reviewText__ngram_range=(1, 2), transformer__vect_summary__max_features=32000, transformer__vect_summary__ngram_range=(1, 2);, score=0.799 total time=   6.1s
# -----------------------------------------------------------------------------------------------------------------------------------
# Best: 0.807604 using {'classifier__C': 5.0, 'classifier__max_iter': 100, 'classifier__solver': 'liblinear', 'transformer__vect_reviewText__max_features': 5000, 'transformer__vect_reviewText__ngram_range': (1, 2), 'transformer__vect_summary__max_features': 32000, 'transformer__vect_summary__ngram_range': (1, 2)}
# f1_score:  0.8143643540061167
# accuracy:  0.8898595409386776
# auc score:  0.7959306256175568

# %% [markdown]
# # Multinomial Naive Bayes

# %%
from sklearn.naive_bayes import MultinomialNB

pipe = Pipeline([
    ("transformer", ct),
    ("classifier", MultinomialNB())
])

mnbModel_params = {
    "transformer__vect_summary__ngram_range": [(1, 2)],
    "transformer__vect_reviewText__ngram_range": [(1, 2)],
    "transformer__vect_summary__max_features": [10000, 32000],
    "transformer__vect_reviewText__max_features": [5000, 10000],
    "classifier__alpha": [0.01, 0.1, 0.5, 1, 10],
    'classifier__fit_prior': [True, False],
}


# perform grid search cross-validation to find the best hyperparameters
grid_mnb = GridSearchCV(pipe, mnbModel_params, cv=5, scoring='f1_macro', verbose=10)

grid_mnb.fit(X_train, y_train)
print("Best: %f using %s" % (grid_mnb.best_score_, grid_mnb.best_params_))

# predict
y_pred_mnb = grid_mnb.best_estimator_.predict(X_test)

# f1 score
fscore = f1_score(y_test, y_pred_mnb, average='macro')
print("f1_score: ", fscore)
f1_arr.append(fscore)

# accuracy
accur = accuracy_score(y_test, y_pred_mnb)
accuracy_arr.append(accur)
print("accuracy: ", accur)

# auc score
aucscore = roc_auc_score(y_test, y_pred_mnb)
print("auc score: ", aucscore)
auc_arr.append(aucscore)

# confusion matrix
cm = confusion_matrix(y_test, y_pred_mnb)
tn, fp, fn, tp = cm.ravel()
fpr = fp / (fp + tn)
tpr = tp / (tp + fn)
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues',
            xticklabels=['Predicted Negative', 'Predicted Positive'],
            yticklabels=['Actual Negative\nFPR={:.2f}'.format(fpr), 'Actual Positive\nTPR={:.2f}'.format(tpr)])
plt.title("Confusion Matrix")
plt.show()

# ROC curve
y_pred_prob_mnb = grid_mnb.predict_proba(X_test)
fpr, tpr, threshold = roc_curve(y_test, y_pred_prob_mnb[:,1])
sns.lineplot(x=fpr, y=tpr,label="AUC="+str(aucscore))
plt.plot([0, 1], [0, 1], color='navy', lw=2, linestyle='--')
plt.xlabel("FPR")
plt.ylabel("TPR")
plt.title("ROC Curve")
plt.show()

model_arr.append("MultinomialNB")
# Out:
# Fitting 5 folds for each of 40 candidates, totalling 200 fits
# [CV 1/5; 1/40] START classifier__alpha=0.01, classifier__fit_prior=True, transformer__vect_reviewText__max_features=5000, transformer__vect_reviewText__ngram_range=(1, 2), transformer__vect_summary__max_features=10000, transformer__vect_summary__ngram_range=(1, 2)
# [CV 1/5; 1/40] END classifier__alpha=0.01, classifier__fit_prior=True, transformer__vect_reviewText__max_features=5000, transformer__vect_reviewText__ngram_range=(1, 2), transformer__vect_summary__max_features=10000, transformer__vect_summary__ngram_range=(1, 2);, score=0.792 total time=   2.3s
# [CV 2/5; 1/40] START classifier__alpha=0.01, classifier__fit_prior=True, transformer__vect_reviewText__max_features=5000, transformer__vect_reviewText__ngram_range=(1, 2), transformer__vect_summary__max_features=10000, transformer__vect_summary__ngram_range=(1, 2)
# [CV 2/5; 1/40] END classifier__alpha=0.01, classifier__fit_prior=True, transformer__vect_reviewText__max_features=5000, transformer__vect_reviewText__ngram_range=(1, 2), transformer__vect_summary__max_features=10000, transformer__vect_summary__ngram_range=(1, 2);, score=0.784 total time=   2.3s
# [CV 3/5; 1/40] START classifier__alpha=0.01, classifier__fit_prior=True, transformer__vect_reviewText__max_features=5000, transformer__vect_reviewText__ngram_range=(1, 2), transformer__vect_summary__max_features=10000, transformer__vect_summary__ngram_range=(1, 2)
# [CV 3/5; 1/40] END classifier__alpha=0.01, classifier__fit_prior=True, transformer__vect_reviewText__max_features=5000, transformer__vect_reviewText__ngram_range=(1, 2), transformer__vect_summary__max_features=10000, transformer__vect_summary__ngram_range=(1, 2);, score=0.776 total time=   2.6s
# [CV 4/5; 1/40] START classifier__alpha=0.01, classifier__fit_prior=True, transformer__vect_reviewText__max_features=5000, transformer__vect_reviewText__ngram_range=(1, 2), transformer__vect_summary__max_features=10000, transformer__vect_summary__ngram_range=(1, 2)
# [CV 4/5; 1/40] END classifier__alpha=0.01, classifier__fit_prior=True, transformer__vect_reviewText__max_features=5000, transformer__vect_reviewText__ngram_range=(1, 2), transformer__vect_summary__max_features=10000, transformer__vect_summary__ngram_range=(1, 2);, score=0.804 total time=   2.3s
# [CV 5/5; 1/40] START classifier__alpha=0.01, classifier__fit_prior=True, transformer__vect_reviewText__max_features=5000, transformer__vect_reviewText__ngram_range=(1, 2), transformer__vect_summary__max_features=10000, transformer__vect_summary__ngram_range=(1, 2)
# [CV 5/5; 1/40] END classifier__alpha=0.01, classifier__fit_prior=True, transformer__vect_reviewText__max_features=5000, transformer__vect_reviewText__ngram_range=(1, 2), transformer__vect_summary__max_features=10000, transformer__vect_summary__ngram_range=(1, 2);, score=0.778 total time=   2.4s
# [CV 1/5; 2/40] START classifier__alpha=0.01, classifier__fit_prior=True, transformer__vect_reviewText__max_features=5000, transformer__vect_reviewText__ngram_range=(1, 2), transformer__vect_summary__max_features=32000, transformer__vect_summary__ngram_range=(1, 2)
# [CV 1/5; 2/40] END classifier__alpha=0.01, classifier__fit_prior=True, transformer__vect_reviewText__max_features=5000, transformer__vect_reviewText__ngram_range=(1, 2), transformer__vect_summary__max_features=32000, transformer__vect_summary__ngram_range=(1, 2);, score=0.786 total time=   2.4s
# [CV 2/5; 2/40] START classifier__alpha=0.01, classifier__fit_prior=True, transformer__vect_reviewText__max_features=5000, transformer__vect_reviewText__ngram_range=(1, 2), transformer__vect_summary__max_features=32000, transformer__vect_summary__ngram_range=(1, 2)
# [CV 2/5; 2/40] END classifier__alpha=0.01, classifier__fit_prior=True, transformer__vect_reviewText__max_features=5000, transformer__vect_reviewText__ngram_range=(1, 2), transformer__vect_summary__max_features=32000, transformer__vect_summary__ngram_range=(1, 2);, score=0.779 total time=   2.2s
# [CV 3/5; 2/40] START classifier__alpha=0.01, classifier__fit_prior=True, transformer__vect_reviewText__max_features=5000, transformer__vect_reviewText__ngram_range=(1, 2), transformer__vect_summary__max_features=32000, transformer__vect_summary__ngram_range=(1, 2)
# [CV 3/5; 2/40] END classifier__alpha=0.01, classifier__fit_prior=True, transformer__vect_reviewText__max_features=5000, transformer__vect_reviewText__ngram_range=(1, 2), transformer__vect_summary__max_features=32000, transformer__vect_summary__ngram_range=(1, 2);, score=0.779 total time=   2.2s
# [CV 4/5; 2/40] START classifier__alpha=0.01, classifier__fit_prior=True, transformer__vect_reviewText__max_features=5000, transformer__vect_reviewText__ngram_range=(1, 2), transformer__vect_summary__max_features=32000, transformer__vect_summary__ngram_range=(1, 2)
# [CV 4/5; 2/40] END classifier__alpha=0.01, classifier__fit_prior=True, transformer__vect_reviewText__max_features=5000, transformer__vect_reviewText__ngram_range=(1, 2), transformer__vect_summary__max_features=32000, transformer__vect_summary__ngram_range=(1, 2);, score=0.791 total time=   2.2s
# [CV 5/5; 2/40] START classifier__alpha=0.01, classifier__fit_prior=True, transformer__vect_reviewText__max_features=5000, transformer__vect_reviewText__ngram_range=(1, 2), transformer__vect_summary__max_features=32000, transformer__vect_summary__ngram_range=(1, 2)
# [CV 5/5; 2/40] END classifier__alpha=0.01, classifier__fit_prior=True, transformer__vect_reviewText__max_features=5000, transformer__vect_reviewText__ngram_range=(1, 2), transformer__vect_summary__max_features=32000, transformer__vect_summary__ngram_range=(1, 2);, score=0.776 total time=   2.3s
# [CV 1/5; 3/40] START classifier__alpha=0.01, classifier__fit_prior=True, transformer__vect_reviewText__max_features=10000, transformer__vect_reviewText__ngram_range=(1, 2), transformer__vect_summary__max_features=10000, transformer__vect_summary__ngram_range=(1, 2)
# [CV 1/5; 3/40] END classifier__alpha=0.01, classifier__fit_prior=True, transformer__vect_reviewText__max_features=10000, transformer__vect_reviewText__ngram_range=(1, 2), transformer__vect_summary__max_features=10000, transformer__vect_summary__ngram_range=(1, 2);, score=0.795 total time=   2.2s
# [CV 2/5; 3/40] START classifier__alpha=0.01, classifier__fit_prior=True, transformer__vect_reviewText__max_features=10000, transformer__vect_reviewText__ngram_range=(1, 2), transformer__vect_summary__max_features=10000, transformer__vect_summary__ngram_range=(1, 2)
# [CV 2/5; 3/40] END classifier__alpha=0.01, classifier__fit_prior=True, transformer__vect_reviewText__max_features=10000, transformer__vect_reviewText__ngram_range=(1, 2), transformer__vect_summary__max_features=10000, transformer__vect_summary__ngram_range=(1, 2);, score=0.782 total time=   2.2s
# [CV 3/5; 3/40] START classifier__alpha=0.01, classifier__fit_prior=True, transformer__vect_reviewText__max_features=10000, transformer__vect_reviewText__ngram_range=(1, 2), transformer__vect_summary__max_features=10000, transformer__vect_summary__ngram_range=(1, 2)
# [CV 3/5; 3/40] END classifier__alpha=0.01, classifier__fit_prior=True, transformer__vect_reviewText__max_features=10000, transformer__vect_reviewText__ngram_range=(1, 2), transformer__vect_summary__max_features=10000, transformer__vect_summary__ngram_range=(1, 2);, score=0.775 total time=   2.2s
# [CV 4/5; 3/40] START classifier__alpha=0.01, classifier__fit_prior=True, transformer__vect_reviewText__max_features=10000, transformer__vect_reviewText__ngram_range=(1, 2), transformer__vect_summary__max_features=10000, transformer__vect_summary__ngram_range=(1, 2)
# [CV 4/5; 3/40] END classifier__alpha=0.01, classifier__fit_prior=True, transformer__vect_reviewText__max_features=10000, transformer__vect_reviewText__ngram_range=(1, 2), transformer__vect_summary__max_features=10000, transformer__vect_summary__ngram_range=(1, 2);, score=0.796 total time=   2.3s
# [CV 5/5; 3/40] START classifier__alpha=0.01, classifier__fit_prior=True, transformer__vect_reviewText__max_features=10000, transformer__vect_reviewText__ngram_range=(1, 2), transformer__vect_summary__max_features=10000, transformer__vect_summary__ngram_range=(1, 2)
# [CV 5/5; 3/40] END classifier__alpha=0.01, classifier__fit_prior=True, transformer__vect_reviewText__max_features=10000, transformer__vect_reviewText__ngram_range=(1, 2), transformer__vect_summary__max_features=10000, transformer__vect_summary__ngram_range=(1, 2);, score=0.774 total time=   2.3s
# [CV 1/5; 4/40] START classifier__alpha=0.01, classifier__fit_prior=True, transformer__vect_reviewText__max_features=10000, transformer__vect_reviewText__ngram_range=(1, 2), transformer__vect_summary__max_features=32000, transformer__vect_summary__ngram_range=(1, 2)
# [CV 1/5; 4/40] END classifier__alpha=0.01, classifier__fit_prior=True, transformer__vect_reviewText__max_features=10000, transformer__vect_reviewText__ngram_range=(1, 2), transformer__vect_summary__max_features=32000, transformer__vect_summary__ngram_range=(1, 2);, score=0.790 total time=   2.2s
# [CV 2/5; 4/40] START classifier__alpha=0.01, classifier__fit_prior=True, transformer__vect_reviewText__max_features=10000, transformer__vect_reviewText__ngram_range=(1, 2), transformer__vect_summary__max_features=32000, transformer__vect_summary__ngram_range=(1, 2)
# [CV 2/5; 4/40] END classifier__alpha=0.01, classifier__fit_prior=True, transformer__vect_reviewText__max_features=10000, transformer__vect_reviewText__ngram_range=(1, 2), transformer__vect_summary__max_features=32000, transformer__vect_summary__ngram_range=(1, 2);, score=0.779 total time=   2.3s
# [CV 3/5; 4/40] START classifier__alpha=0.01, classifier__fit_prior=True, transformer__vect_reviewText__max_features=10000, transformer__vect_reviewText__ngram_range=(1, 2), transformer__vect_summary__max_features=32000, transformer__vect_summary__ngram_range=(1, 2)
# [CV 3/5; 4/40] END classifier__alpha=0.01, classifier__fit_prior=True, transformer__vect_reviewText__max_features=10000, transformer__vect_reviewText__ngram_range=(1, 2), transformer__vect_summary__max_features=32000, transformer__vect_summary__ngram_range=(1, 2);, score=0.776 total time=   2.3s
# [CV 4/5; 4/40] START classifier__alpha=0.01, classifier__fit_prior=True, transformer__vect_reviewText__max_features=10000, transformer__vect_reviewText__ngram_range=(1, 2), transformer__vect_summary__max_features=32000, transformer__vect_summary__ngram_range=(1, 2)
# [CV 4/5; 4/40] END classifier__alpha=0.01, classifier__fit_prior=True, transformer__vect_reviewText__max_features=10000, transformer__vect_reviewText__ngram_range=(1, 2), transformer__vect_summary__max_features=32000, transformer__vect_summary__ngram_range=(1, 2);, score=0.787 total time=   2.3s
# [CV 5/5; 4/40] START classifier__alpha=0.01, classifier__fit_prior=True, transformer__vect_reviewText__max_features=10000, transformer__vect_reviewText__ngram_range=(1, 2), transformer__vect_summary__max_features=32000, transformer__vect_summary__ngram_range=(1, 2)
# [CV 5/5; 4/40] END classifier__alpha=0.01, classifier__fit_prior=True, transformer__vect_reviewText__max_features=10000, transformer__vect_reviewText__ngram_range=(1, 2), transformer__vect_summary__max_features=32000, transformer__vect_summary__ngram_range=(1, 2);, score=0.774 total time=   2.3s
# [CV 1/5; 5/40] START classifier__alpha=0.01, classifier__fit_prior=False, transformer__vect_reviewText__max_features=5000, transformer__vect_reviewText__ngram_range=(1, 2), transformer__vect_summary__max_features=10000, transformer__vect_summary__ngram_range=(1, 2)
# [CV 1/5; 5/40] END classifier__alpha=0.01, classifier__fit_prior=False, transformer__vect_reviewText__max_features=5000, transformer__vect_reviewText__ngram_range=(1, 2), transformer__vect_summary__max_features=10000, transformer__vect_summary__ngram_range=(1, 2);, score=0.806 total time=   2.4s
# [CV 2/5; 5/40] START classifier__alpha=0.01, classifier__fit_prior=False, transformer__vect_reviewText__max_features=5000, transformer__vect_reviewText__ngram_range=(1, 2), transformer__vect_summary__max_features=10000, transformer__vect_summary__ngram_range=(1, 2)
# [CV 2/5; 5/40] END classifier__alpha=0.01, classifier__fit_prior=False, transformer__vect_reviewText__max_features=5000, transformer__vect_reviewText__ngram_range=(1, 2), transformer__vect_summary__max_features=10000, transformer__vect_summary__ngram_range=(1, 2);, score=0.786 total time=   2.3s
# [CV 3/5; 5/40] START classifier__alpha=0.01, classifier__fit_prior=False, transformer__vect_reviewText__max_features=5000, transformer__vect_reviewText__ngram_range=(1, 2), transformer__vect_summary__max_features=10000, transformer__vect_summary__ngram_range=(1, 2)
# [CV 3/5; 5/40] END classifier__alpha=0.01, classifier__fit_prior=False, transformer__vect_reviewText__max_features=5000, transformer__vect_reviewText__ngram_range=(1, 2), transformer__vect_summary__max_features=10000, transformer__vect_summary__ngram_range=(1, 2);, score=0.797 total time=   2.1s
# [CV 4/5; 5/40] START classifier__alpha=0.01, classifier__fit_prior=False, transformer__vect_reviewText__max_features=5000, transformer__vect_reviewText__ngram_range=(1, 2), transformer__vect_summary__max_features=10000, transformer__vect_summary__ngram_range=(1, 2)
# [CV 4/5; 5/40] END classifier__alpha=0.01, classifier__fit_prior=False, transformer__vect_reviewText__max_features=5000, transformer__vect_reviewText__ngram_range=(1, 2), transformer__vect_summary__max_features=10000, transformer__vect_summary__ngram_range=(1, 2);, score=0.797 total time=   2.3s
# [CV 5/5; 5/40] START classifier__alpha=0.01, classifier__fit_prior=False, transformer__vect_reviewText__max_features=5000, transformer__vect_reviewText__ngram_range=(1, 2), transformer__vect_summary__max_features=10000, transformer__vect_summary__ngram_range=(1, 2)
# [CV 5/5; 5/40] END classifier__alpha=0.01, classifier__fit_prior=False, transformer__vect_reviewText__max_features=5000, transformer__vect_reviewText__ngram_range=(1, 2), transformer__vect_summary__max_features=10000, transformer__vect_summary__ngram_range=(1, 2);, score=0.783 total time=   2.3s
# [CV 1/5; 6/40] START classifier__alpha=0.01, classifier__fit_prior=False, transformer__vect_reviewText__max_features=5000, transformer__vect_reviewText__ngram_range=(1, 2), transformer__vect_summary__max_features=32000, transformer__vect_summary__ngram_range=(1, 2)
# [CV 1/5; 6/40] END classifier__alpha=0.01, classifier__fit_prior=False, transformer__vect_reviewText__max_features=5000, transformer__vect_reviewText__ngram_range=(1, 2), transformer__vect_summary__max_features=32000, transformer__vect_summary__ngram_range=(1, 2);, score=0.802 total time=   2.4s
# [CV 2/5; 6/40] START classifier__alpha=0.01, classifier__fit_prior=False, transformer__vect_reviewText__max_features=5000, transformer__vect_reviewText__ngram_range=(1, 2), transformer__vect_summary__max_features=32000, transformer__vect_summary__ngram_range=(1, 2)
# [CV 2/5; 6/40] END classifier__alpha=0.01, classifier__fit_prior=False, transformer__vect_reviewText__max_features=5000, transformer__vect_reviewText__ngram_range=(1, 2), transformer__vect_summary__max_features=32000, transformer__vect_summary__ngram_range=(1, 2);, score=0.786 total time=   2.2s
# [CV 3/5; 6/40] START classifier__alpha=0.01, classifier__fit_prior=False, transformer__vect_reviewText__max_features=5000, transformer__vect_reviewText__ngram_range=(1, 2), transformer__vect_summary__max_features=32000, transformer__vect_summary__ngram_range=(1, 2)
# [CV 3/5; 6/40] END classifier__alpha=0.01, classifier__fit_prior=False, transformer__vect_reviewText__max_features=5000, transformer__vect_reviewText__ngram_range=(1, 2), transformer__vect_summary__max_features=32000, transformer__vect_summary__ngram_range=(1, 2);, score=0.795 total time=   2.3s
# [CV 4/5; 6/40] START classifier__alpha=0.01, classifier__fit_prior=False, transformer__vect_reviewText__max_features=5000, transformer__vect_reviewText__ngram_range=(1, 2), transformer__vect_summary__max_features=32000, transformer__vect_summary__ngram_range=(1, 2)
# [CV 4/5; 6/40] END classifier__alpha=0.01, classifier__fit_prior=False, transformer__vect_reviewText__max_features=5000, transformer__vect_reviewText__ngram_range=(1, 2), transformer__vect_summary__max_features=32000, transformer__vect_summary__ngram_range=(1, 2);, score=0.790 total time=   2.4s
# [CV 5/5; 6/40] START classifier__alpha=0.01, classifier__fit_prior=False, transformer__vect_reviewText__max_features=5000, transformer__vect_reviewText__ngram_range=(1, 2), transformer__vect_summary__max_features=32000, transformer__vect_summary__ngram_range=(1, 2)
# [CV 5/5; 6/40] END classifier__alpha=0.01, classifier__fit_prior=False, transformer__vect_reviewText__max_features=5000, transformer__vect_reviewText__ngram_range=(1, 2), transformer__vect_summary__max_features=32000, transformer__vect_summary__ngram_range=(1, 2);, score=0.777 total time=   2.3s
# [CV 1/5; 7/40] START classifier__alpha=0.01, classifier__fit_prior=False, transformer__vect_reviewText__max_features=10000, transformer__vect_reviewText__ngram_range=(1, 2), transformer__vect_summary__max_features=10000, transformer__vect_summary__ngram_range=(1, 2)
# [CV 1/5; 7/40] END classifier__alpha=0.01, classifier__fit_prior=False, transformer__vect_reviewText__max_features=10000, transformer__vect_reviewText__ngram_range=(1, 2), transformer__vect_summary__max_features=10000, transformer__vect_summary__ngram_range=(1, 2);, score=0.809 total time=   2.4s
# [CV 2/5; 7/40] START classifier__alpha=0.01, classifier__fit_prior=False, transformer__vect_reviewText__max_features=10000, transformer__vect_reviewText__ngram_range=(1, 2), transformer__vect_summary__max_features=10000, transformer__vect_summary__ngram_range=(1, 2)
# [CV 2/5; 7/40] END classifier__alpha=0.01, classifier__fit_prior=False, transformer__vect_reviewText__max_features=10000, transformer__vect_reviewText__ngram_range=(1, 2), transformer__vect_summary__max_features=10000, transformer__vect_summary__ngram_range=(1, 2);, score=0.790 total time=   2.2s
# [CV 3/5; 7/40] START classifier__alpha=0.01, classifier__fit_prior=False, transformer__vect_reviewText__max_features=10000, transformer__vect_reviewText__ngram_range=(1, 2), transformer__vect_summary__max_features=10000, transformer__vect_summary__ngram_range=(1, 2)
# [CV 3/5; 7/40] END classifier__alpha=0.01, classifier__fit_prior=False, transformer__vect_reviewText__max_features=10000, transformer__vect_reviewText__ngram_range=(1, 2), transformer__vect_summary__max_features=10000, transformer__vect_summary__ngram_range=(1, 2);, score=0.798 total time=   2.3s
# [CV 4/5; 7/40] START classifier__alpha=0.01, classifier__fit_prior=False, transformer__vect_reviewText__max_features=10000, transformer__vect_reviewText__ngram_range=(1, 2), transformer__vect_summary__max_features=10000, transformer__vect_summary__ngram_range=(1, 2)
# [CV 4/5; 7/40] END classifier__alpha=0.01, classifier__fit_prior=False, transformer__vect_reviewText__max_features=10000, transformer__vect_reviewText__ngram_range=(1, 2), transformer__vect_summary__max_features=10000, transformer__vect_summary__ngram_range=(1, 2);, score=0.800 total time=   2.2s
# [CV 5/5; 7/40] START classifier__alpha=0.01, classifier__fit_prior=False, transformer__vect_reviewText__max_features=10000, transformer__vect_reviewText__ngram_range=(1, 2), transformer__vect_summary__max_features=10000, transformer__vect_summary__ngram_range=(1, 2)
# [CV 5/5; 7/40] END classifier__alpha=0.01, classifier__fit_prior=False, transformer__vect_reviewText__max_features=10000, transformer__vect_reviewText__ngram_range=(1, 2), transformer__vect_summary__max_features=10000, transformer__vect_summary__ngram_range=(1, 2);, score=0.793 total time=   2.3s
# [CV 1/5; 8/40] START classifier__alpha=0.01, classifier__fit_prior=False, transformer__vect_reviewText__max_features=10000, transformer__vect_reviewText__ngram_range=(1, 2), transformer__vect_summary__max_features=32000, transformer__vect_summary__ngram_range=(1, 2)
# [CV 1/5; 8/40] END classifier__alpha=0.01, classifier__fit_prior=False, transformer__vect_reviewText__max_features=10000, transformer__vect_reviewText__ngram_range=(1, 2), transformer__vect_summary__max_features=32000, transformer__vect_summary__ngram_range=(1, 2);, score=0.806 total time=   2.3s
# [CV 2/5; 8/40] START classifier__alpha=0.01, classifier__fit_prior=False, transformer__vect_reviewText__max_features=10000, transformer__vect_reviewText__ngram_range=(1, 2), transformer__vect_summary__max_features=32000, transformer__vect_summary__ngram_range=(1, 2)
# [CV 2/5; 8/40] END classifier__alpha=0.01, classifier__fit_prior=False, transformer__vect_reviewText__max_features=10000, transformer__vect_reviewText__ngram_range=(1, 2), transformer__vect_summary__max_features=32000, transformer__vect_summary__ngram_range=(1, 2);, score=0.790 total time=   2.2s
# [CV 3/5; 8/40] START classifier__alpha=0.01, classifier__fit_prior=False, transformer__vect_reviewText__max_features=10000, transformer__vect_reviewText__ngram_range=(1, 2), transformer__vect_summary__max_features=32000, transformer__vect_summary__ngram_range=(1, 2)
# [CV 3/5; 8/40] END classifier__alpha=0.01, classifier__fit_prior=False, transformer__vect_reviewText__max_features=10000, transformer__vect_reviewText__ngram_range=(1, 2), transformer__vect_summary__max_features=32000, transformer__vect_summary__ngram_range=(1, 2);, score=0.797 total time=   2.4s
# [CV 4/5; 8/40] START classifier__alpha=0.01, classifier__fit_prior=False, transformer__vect_reviewText__max_features=10000, transformer__vect_reviewText__ngram_range=(1, 2), transformer__vect_summary__max_features=32000, transformer__vect_summary__ngram_range=(1, 2)
# [CV 4/5; 8/40] END classifier__alpha=0.01, classifier__fit_prior=False, transformer__vect_reviewText__max_features=10000, transformer__vect_reviewText__ngram_range=(1, 2), transformer__vect_summary__max_features=32000, transformer__vect_summary__ngram_range=(1, 2);, score=0.790 total time=   2.3s
# [CV 5/5; 8/40] START classifier__alpha=0.01, classifier__fit_prior=False, transformer__vect_reviewText__max_features=10000, transformer__vect_reviewText__ngram_range=(1, 2), transformer__vect_summary__max_features=32000, transformer__vect_summary__ngram_range=(1, 2)
# [CV 5/5; 8/40] END classifier__alpha=0.01, classifier__fit_prior=False, transformer__vect_reviewText__max_features=10000, transformer__vect_reviewText__ngram_range=(1, 2), transformer__vect_summary__max_features=32000, transformer__vect_summary__ngram_range=(1, 2);, score=0.790 total time=   2.2s
# [CV 1/5; 9/40] START classifier__alpha=0.1, classifier__fit_prior=True, transformer__vect_reviewText__max_features=5000, transformer__vect_reviewText__ngram_range=(1, 2), transformer__vect_summary__max_features=10000, transformer__vect_summary__ngram_range=(1, 2)
# [CV 1/5; 9/40] END classifier__alpha=0.1, classifier__fit_prior=True, transformer__vect_reviewText__max_features=5000, transformer__vect_reviewText__ngram_range=(1, 2), transformer__vect_summary__max_features=10000, transformer__vect_summary__ngram_range=(1, 2);, score=0.793 total time=   2.2s
# [CV 2/5; 9/40] START classifier__alpha=0.1, classifier__fit_prior=True, transformer__vect_reviewText__max_features=5000, transformer__vect_reviewText__ngram_range=(1, 2), transformer__vect_summary__max_features=10000, transformer__vect_summary__ngram_range=(1, 2)
# [CV 2/5; 9/40] END classifier__alpha=0.1, classifier__fit_prior=True, transformer__vect_reviewText__max_features=5000, transformer__vect_reviewText__ngram_range=(1, 2), transformer__vect_summary__max_features=10000, transformer__vect_summary__ngram_range=(1, 2);, score=0.784 total time=   2.3s
# [CV 3/5; 9/40] START classifier__alpha=0.1, classifier__fit_prior=True, transformer__vect_reviewText__max_features=5000, transformer__vect_reviewText__ngram_range=(1, 2), transformer__vect_summary__max_features=10000, transformer__vect_summary__ngram_range=(1, 2)
# [CV 3/5; 9/40] END classifier__alpha=0.1, classifier__fit_prior=True, transformer__vect_reviewText__max_features=5000, transformer__vect_reviewText__ngram_range=(1, 2), transformer__vect_summary__max_features=10000, transformer__vect_summary__ngram_range=(1, 2);, score=0.775 total time=   2.3s
# [CV 4/5; 9/40] START classifier__alpha=0.1, classifier__fit_prior=True, transformer__vect_reviewText__max_features=5000, transformer__vect_reviewText__ngram_range=(1, 2), transformer__vect_summary__max_features=10000, transformer__vect_summary__ngram_range=(1, 2)
# [CV 4/5; 9/40] END classifier__alpha=0.1, classifier__fit_prior=True, transformer__vect_reviewText__max_features=5000, transformer__vect_reviewText__ngram_range=(1, 2), transformer__vect_summary__max_features=10000, transformer__vect_summary__ngram_range=(1, 2);, score=0.803 total time=   2.3s
# [CV 5/5; 9/40] START classifier__alpha=0.1, classifier__fit_prior=True, transformer__vect_reviewText__max_features=5000, transformer__vect_reviewText__ngram_range=(1, 2), transformer__vect_summary__max_features=10000, transformer__vect_summary__ngram_range=(1, 2)
# [CV 5/5; 9/40] END classifier__alpha=0.1, classifier__fit_prior=True, transformer__vect_reviewText__max_features=5000, transformer__vect_reviewText__ngram_range=(1, 2), transformer__vect_summary__max_features=10000, transformer__vect_summary__ngram_range=(1, 2);, score=0.779 total time=   2.4s
# [CV 1/5; 10/40] START classifier__alpha=0.1, classifier__fit_prior=True, transformer__vect_reviewText__max_features=5000, transformer__vect_reviewText__ngram_range=(1, 2), transformer__vect_summary__max_features=32000, transformer__vect_summary__ngram_range=(1, 2)
# [CV 1/5; 10/40] END classifier__alpha=0.1, classifier__fit_prior=True, transformer__vect_reviewText__max_features=5000, transformer__vect_reviewText__ngram_range=(1, 2), transformer__vect_summary__max_features=32000, transformer__vect_summary__ngram_range=(1, 2);, score=0.777 total time=   2.3s
# [CV 2/5; 10/40] START classifier__alpha=0.1, classifier__fit_prior=True, transformer__vect_reviewText__max_features=5000, transformer__vect_reviewText__ngram_range=(1, 2), transformer__vect_summary__max_features=32000, transformer__vect_summary__ngram_range=(1, 2)
# [CV 2/5; 10/40] END classifier__alpha=0.1, classifier__fit_prior=True, transformer__vect_reviewText__max_features=5000, transformer__vect_reviewText__ngram_range=(1, 2), transformer__vect_summary__max_features=32000, transformer__vect_summary__ngram_range=(1, 2);, score=0.778 total time=   2.4s
# [CV 3/5; 10/40] START classifier__alpha=0.1, classifier__fit_prior=True, transformer__vect_reviewText__max_features=5000, transformer__vect_reviewText__ngram_range=(1, 2), transformer__vect_summary__max_features=32000, transformer__vect_summary__ngram_range=(1, 2)
# [CV 3/5; 10/40] END classifier__alpha=0.1, classifier__fit_prior=True, transformer__vect_reviewText__max_features=5000, transformer__vect_reviewText__ngram_range=(1, 2), transformer__vect_summary__max_features=32000, transformer__vect_summary__ngram_range=(1, 2);, score=0.779 total time=   2.4s
# [CV 4/5; 10/40] START classifier__alpha=0.1, classifier__fit_prior=True, transformer__vect_reviewText__max_features=5000, transformer__vect_reviewText__ngram_range=(1, 2), transformer__vect_summary__max_features=32000, transformer__vect_summary__ngram_range=(1, 2)
# [CV 4/5; 10/40] END classifier__alpha=0.1, classifier__fit_prior=True, transformer__vect_reviewText__max_features=5000, transformer__vect_reviewText__ngram_range=(1, 2), transformer__vect_summary__max_features=32000, transformer__vect_summary__ngram_range=(1, 2);, score=0.786 total time=   2.2s
# [CV 5/5; 10/40] START classifier__alpha=0.1, classifier__fit_prior=True, transformer__vect_reviewText__max_features=5000, transformer__vect_reviewText__ngram_range=(1, 2), transformer__vect_summary__max_features=32000, transformer__vect_summary__ngram_range=(1, 2)
# [CV 5/5; 10/40] END classifier__alpha=0.1, classifier__fit_prior=True, transformer__vect_reviewText__max_features=5000, transformer__vect_reviewText__ngram_range=(1, 2), transformer__vect_summary__max_features=32000, transformer__vect_summary__ngram_range=(1, 2);, score=0.772 total time=   2.6s
# [CV 1/5; 11/40] START classifier__alpha=0.1, classifier__fit_prior=True, transformer__vect_reviewText__max_features=10000, transformer__vect_reviewText__ngram_range=(1, 2), transformer__vect_summary__max_features=10000, transformer__vect_summary__ngram_range=(1, 2)
# [CV 1/5; 11/40] END classifier__alpha=0.1, classifier__fit_prior=True, transformer__vect_reviewText__max_features=10000, transformer__vect_reviewText__ngram_range=(1, 2), transformer__vect_summary__max_features=10000, transformer__vect_summary__ngram_range=(1, 2);, score=0.795 total time=   2.4s
# [CV 2/5; 11/40] START classifier__alpha=0.1, classifier__fit_prior=True, transformer__vect_reviewText__max_features=10000, transformer__vect_reviewText__ngram_range=(1, 2), transformer__vect_summary__max_features=10000, transformer__vect_summary__ngram_range=(1, 2)
# [CV 2/5; 11/40] END classifier__alpha=0.1, classifier__fit_prior=True, transformer__vect_reviewText__max_features=10000, transformer__vect_reviewText__ngram_range=(1, 2), transformer__vect_summary__max_features=10000, transformer__vect_summary__ngram_range=(1, 2);, score=0.787 total time=   2.4s
# [CV 3/5; 11/40] START classifier__alpha=0.1, classifier__fit_prior=True, transformer__vect_reviewText__max_features=10000, transformer__vect_reviewText__ngram_range=(1, 2), transformer__vect_summary__max_features=10000, transformer__vect_summary__ngram_range=(1, 2)
# [CV 3/5; 11/40] END classifier__alpha=0.1, classifier__fit_prior=True, transformer__vect_reviewText__max_features=10000, transformer__vect_reviewText__ngram_range=(1, 2), transformer__vect_summary__max_features=10000, transformer__vect_summary__ngram_range=(1, 2);, score=0.776 total time=   2.5s
# [CV 4/5; 11/40] START classifier__alpha=0.1, classifier__fit_prior=True, transformer__vect_reviewText__max_features=10000, transformer__vect_reviewText__ngram_range=(1, 2), transformer__vect_summary__max_features=10000, transformer__vect_summary__ngram_range=(1, 2)
# [CV 4/5; 11/40] END classifier__alpha=0.1, classifier__fit_prior=True, transformer__vect_reviewText__max_features=10000, transformer__vect_reviewText__ngram_range=(1, 2), transformer__vect_summary__max_features=10000, transformer__vect_summary__ngram_range=(1, 2);, score=0.801 total time=   2.6s
# [CV 5/5; 11/40] START classifier__alpha=0.1, classifier__fit_prior=True, transformer__vect_reviewText__max_features=10000, transformer__vect_reviewText__ngram_range=(1, 2), transformer__vect_summary__max_features=10000, transformer__vect_summary__ngram_range=(1, 2)
# [CV 5/5; 11/40] END classifier__alpha=0.1, classifier__fit_prior=True, transformer__vect_reviewText__max_features=10000, transformer__vect_reviewText__ngram_range=(1, 2), transformer__vect_summary__max_features=10000, transformer__vect_summary__ngram_range=(1, 2);, score=0.779 total time=   2.8s
# [CV 1/5; 12/40] START classifier__alpha=0.1, classifier__fit_prior=True, transformer__vect_reviewText__max_features=10000, transformer__vect_reviewText__ngram_range=(1, 2), transformer__vect_summary__max_features=32000, transformer__vect_summary__ngram_range=(1, 2)
# [CV 1/5; 12/40] END classifier__alpha=0.1, classifier__fit_prior=True, transformer__vect_reviewText__max_features=10000, transformer__vect_reviewText__ngram_range=(1, 2), transformer__vect_summary__max_features=32000, transformer__vect_summary__ngram_range=(1, 2);, score=0.778 total time=   2.7s
# [CV 2/5; 12/40] START classifier__alpha=0.1, classifier__fit_prior=True, transformer__vect_reviewText__max_features=10000, transformer__vect_reviewText__ngram_range=(1, 2), transformer__vect_summary__max_features=32000, transformer__vect_summary__ngram_range=(1, 2)
# [CV 2/5; 12/40] END classifier__alpha=0.1, classifier__fit_prior=True, transformer__vect_reviewText__max_features=10000, transformer__vect_reviewText__ngram_range=(1, 2), transformer__vect_summary__max_features=32000, transformer__vect_summary__ngram_range=(1, 2);, score=0.780 total time=   3.1s
# [CV 3/5; 12/40] START classifier__alpha=0.1, classifier__fit_prior=True, transformer__vect_reviewText__max_features=10000, transformer__vect_reviewText__ngram_range=(1, 2), transformer__vect_summary__max_features=32000, transformer__vect_summary__ngram_range=(1, 2)
# [CV 3/5; 12/40] END classifier__alpha=0.1, classifier__fit_prior=True, transformer__vect_reviewText__max_features=10000, transformer__vect_reviewText__ngram_range=(1, 2), transformer__vect_summary__max_features=32000, transformer__vect_summary__ngram_range=(1, 2);, score=0.778 total time=   2.6s
# [CV 4/5; 12/40] START classifier__alpha=0.1, classifier__fit_prior=True, transformer__vect_reviewText__max_features=10000, transformer__vect_reviewText__ngram_range=(1, 2), transformer__vect_summary__max_features=32000, transformer__vect_summary__ngram_range=(1, 2)
# [CV 4/5; 12/40] END classifier__alpha=0.1, classifier__fit_prior=True, transformer__vect_reviewText__max_features=10000, transformer__vect_reviewText__ngram_range=(1, 2), transformer__vect_summary__max_features=32000, transformer__vect_summary__ngram_range=(1, 2);, score=0.790 total time=   2.4s
# [CV 5/5; 12/40] START classifier__alpha=0.1, classifier__fit_prior=True, transformer__vect_reviewText__max_features=10000, transformer__vect_reviewText__ngram_range=(1, 2), transformer__vect_summary__max_features=32000, transformer__vect_summary__ngram_range=(1, 2)
# [CV 5/5; 12/40] END classifier__alpha=0.1, classifier__fit_prior=True, transformer__vect_reviewText__max_features=10000, transformer__vect_reviewText__ngram_range=(1, 2), transformer__vect_summary__max_features=32000, transformer__vect_summary__ngram_range=(1, 2);, score=0.775 total time=   2.3s
# [CV 1/5; 13/40] START classifier__alpha=0.1, classifier__fit_prior=False, transformer__vect_reviewText__max_features=5000, transformer__vect_reviewText__ngram_range=(1, 2), transformer__vect_summary__max_features=10000, transformer__vect_summary__ngram_range=(1, 2)
# [CV 1/5; 13/40] END classifier__alpha=0.1, classifier__fit_prior=False, transformer__vect_reviewText__max_features=5000, transformer__vect_reviewText__ngram_range=(1, 2), transformer__vect_summary__max_features=10000, transformer__vect_summary__ngram_range=(1, 2);, score=0.810 total time=   2.7s
# [CV 2/5; 13/40] START classifier__alpha=0.1, classifier__fit_prior=False, transformer__vect_reviewText__max_features=5000, transformer__vect_reviewText__ngram_range=(1, 2), transformer__vect_summary__max_features=10000, transformer__vect_summary__ngram_range=(1, 2)
# [CV 2/5; 13/40] END classifier__alpha=0.1, classifier__fit_prior=False, transformer__vect_reviewText__max_features=5000, transformer__vect_reviewText__ngram_range=(1, 2), transformer__vect_summary__max_features=10000, transformer__vect_summary__ngram_range=(1, 2);, score=0.794 total time=   2.4s
# [CV 3/5; 13/40] START classifier__alpha=0.1, classifier__fit_prior=False, transformer__vect_reviewText__max_features=5000, transformer__vect_reviewText__ngram_range=(1, 2), transformer__vect_summary__max_features=10000, transformer__vect_summary__ngram_range=(1, 2)
# [CV 3/5; 13/40] END classifier__alpha=0.1, classifier__fit_prior=False, transformer__vect_reviewText__max_features=5000, transformer__vect_reviewText__ngram_range=(1, 2), transformer__vect_summary__max_features=10000, transformer__vect_summary__ngram_range=(1, 2);, score=0.804 total time=   2.4s
# [CV 4/5; 13/40] START classifier__alpha=0.1, classifier__fit_prior=False, transformer__vect_reviewText__max_features=5000, transformer__vect_reviewText__ngram_range=(1, 2), transformer__vect_summary__max_features=10000, transformer__vect_summary__ngram_range=(1, 2)
# [CV 4/5; 13/40] END classifier__alpha=0.1, classifier__fit_prior=False, transformer__vect_reviewText__max_features=5000, transformer__vect_reviewText__ngram_range=(1, 2), transformer__vect_summary__max_features=10000, transformer__vect_summary__ngram_range=(1, 2);, score=0.809 total time=   2.4s
# [CV 5/5; 13/40] START classifier__alpha=0.1, classifier__fit_prior=False, transformer__vect_reviewText__max_features=5000, transformer__vect_reviewText__ngram_range=(1, 2), transformer__vect_summary__max_features=10000, transformer__vect_summary__ngram_range=(1, 2)
# [CV 5/5; 13/40] END classifier__alpha=0.1, classifier__fit_prior=False, transformer__vect_reviewText__max_features=5000, transformer__vect_reviewText__ngram_range=(1, 2), transformer__vect_summary__max_features=10000, transformer__vect_summary__ngram_range=(1, 2);, score=0.793 total time=   2.4s
# [CV 1/5; 14/40] START classifier__alpha=0.1, classifier__fit_prior=False, transformer__vect_reviewText__max_features=5000, transformer__vect_reviewText__ngram_range=(1, 2), transformer__vect_summary__max_features=32000, transformer__vect_summary__ngram_range=(1, 2)
# [CV 1/5; 14/40] END classifier__alpha=0.1, classifier__fit_prior=False, transformer__vect_reviewText__max_features=5000, transformer__vect_reviewText__ngram_range=(1, 2), transformer__vect_summary__max_features=32000, transformer__vect_summary__ngram_range=(1, 2);, score=0.818 total time=   2.3s
# [CV 2/5; 14/40] START classifier__alpha=0.1, classifier__fit_prior=False, transformer__vect_reviewText__max_features=5000, transformer__vect_reviewText__ngram_range=(1, 2), transformer__vect_summary__max_features=32000, transformer__vect_summary__ngram_range=(1, 2)
# [CV 2/5; 14/40] END classifier__alpha=0.1, classifier__fit_prior=False, transformer__vect_reviewText__max_features=5000, transformer__vect_reviewText__ngram_range=(1, 2), transformer__vect_summary__max_features=32000, transformer__vect_summary__ngram_range=(1, 2);, score=0.795 total time=   2.5s
# [CV 3/5; 14/40] START classifier__alpha=0.1, classifier__fit_prior=False, transformer__vect_reviewText__max_features=5000, transformer__vect_reviewText__ngram_range=(1, 2), transformer__vect_summary__max_features=32000, transformer__vect_summary__ngram_range=(1, 2)
# [CV 3/5; 14/40] END classifier__alpha=0.1, classifier__fit_prior=False, transformer__vect_reviewText__max_features=5000, transformer__vect_reviewText__ngram_range=(1, 2), transformer__vect_summary__max_features=32000, transformer__vect_summary__ngram_range=(1, 2);, score=0.806 total time=   2.3s
# [CV 4/5; 14/40] START classifier__alpha=0.1, classifier__fit_prior=False, transformer__vect_reviewText__max_features=5000, transformer__vect_reviewText__ngram_range=(1, 2), transformer__vect_summary__max_features=32000, transformer__vect_summary__ngram_range=(1, 2)
# [CV 4/5; 14/40] END classifier__alpha=0.1, classifier__fit_prior=False, transformer__vect_reviewText__max_features=5000, transformer__vect_reviewText__ngram_range=(1, 2), transformer__vect_summary__max_features=32000, transformer__vect_summary__ngram_range=(1, 2);, score=0.811 total time=   2.5s
# [CV 5/5; 14/40] START classifier__alpha=0.1, classifier__fit_prior=False, transformer__vect_reviewText__max_features=5000, transformer__vect_reviewText__ngram_range=(1, 2), transformer__vect_summary__max_features=32000, transformer__vect_summary__ngram_range=(1, 2)
# [CV 5/5; 14/40] END classifier__alpha=0.1, classifier__fit_prior=False, transformer__vect_reviewText__max_features=5000, transformer__vect_reviewText__ngram_range=(1, 2), transformer__vect_summary__max_features=32000, transformer__vect_summary__ngram_range=(1, 2);, score=0.802 total time=   2.6s
# [CV 1/5; 15/40] START classifier__alpha=0.1, classifier__fit_prior=False, transformer__vect_reviewText__max_features=10000, transformer__vect_reviewText__ngram_range=(1, 2), transformer__vect_summary__max_features=10000, transformer__vect_summary__ngram_range=(1, 2)
# [CV 1/5; 15/40] END classifier__alpha=0.1, classifier__fit_prior=False, transformer__vect_reviewText__max_features=10000, transformer__vect_reviewText__ngram_range=(1, 2), transformer__vect_summary__max_features=10000, transformer__vect_summary__ngram_range=(1, 2);, score=0.816 total time=   2.5s
# [CV 2/5; 15/40] START classifier__alpha=0.1, classifier__fit_prior=False, transformer__vect_reviewText__max_features=10000, transformer__vect_reviewText__ngram_range=(1, 2), transformer__vect_summary__max_features=10000, transformer__vect_summary__ngram_range=(1, 2)
# [CV 2/5; 15/40] END classifier__alpha=0.1, classifier__fit_prior=False, transformer__vect_reviewText__max_features=10000, transformer__vect_reviewText__ngram_range=(1, 2), transformer__vect_summary__max_features=10000, transformer__vect_summary__ngram_range=(1, 2);, score=0.794 total time=   2.6s
# [CV 3/5; 15/40] START classifier__alpha=0.1, classifier__fit_prior=False, transformer__vect_reviewText__max_features=10000, transformer__vect_reviewText__ngram_range=(1, 2), transformer__vect_summary__max_features=10000, transformer__vect_summary__ngram_range=(1, 2)
# [CV 3/5; 15/40] END classifier__alpha=0.1, classifier__fit_prior=False, transformer__vect_reviewText__max_features=10000, transformer__vect_reviewText__ngram_range=(1, 2), transformer__vect_summary__max_features=10000, transformer__vect_summary__ngram_range=(1, 2);, score=0.807 total time=   2.6s
# [CV 4/5; 15/40] START classifier__alpha=0.1, classifier__fit_prior=False, transformer__vect_reviewText__max_features=10000, transformer__vect_reviewText__ngram_range=(1, 2), transformer__vect_summary__max_features=10000, transformer__vect_summary__ngram_range=(1, 2)
# [CV 4/5; 15/40] END classifier__alpha=0.1, classifier__fit_prior=False, transformer__vect_reviewText__max_features=10000, transformer__vect_reviewText__ngram_range=(1, 2), transformer__vect_summary__max_features=10000, transformer__vect_summary__ngram_range=(1, 2);, score=0.811 total time=   2.5s
# [CV 5/5; 15/40] START classifier__alpha=0.1, classifier__fit_prior=False, transformer__vect_reviewText__max_features=10000, transformer__vect_reviewText__ngram_range=(1, 2), transformer__vect_summary__max_features=10000, transformer__vect_summary__ngram_range=(1, 2)
# [CV 5/5; 15/40] END classifier__alpha=0.1, classifier__fit_prior=False, transformer__vect_reviewText__max_features=10000, transformer__vect_reviewText__ngram_range=(1, 2), transformer__vect_summary__max_features=10000, transformer__vect_summary__ngram_range=(1, 2);, score=0.797 total time=   2.8s
# [CV 1/5; 16/40] START classifier__alpha=0.1, classifier__fit_prior=False, transformer__vect_reviewText__max_features=10000, transformer__vect_reviewText__ngram_range=(1, 2), transformer__vect_summary__max_features=32000, transformer__vect_summary__ngram_range=(1, 2)
# [CV 1/5; 16/40] END classifier__alpha=0.1, classifier__fit_prior=False, transformer__vect_reviewText__max_features=10000, transformer__vect_reviewText__ngram_range=(1, 2), transformer__vect_summary__max_features=32000, transformer__vect_summary__ngram_range=(1, 2);, score=0.824 total time=   2.5s
# [CV 2/5; 16/40] START classifier__alpha=0.1, classifier__fit_prior=False, transformer__vect_reviewText__max_features=10000, transformer__vect_reviewText__ngram_range=(1, 2), transformer__vect_summary__max_features=32000, transformer__vect_summary__ngram_range=(1, 2)
# [CV 2/5; 16/40] END classifier__alpha=0.1, classifier__fit_prior=False, transformer__vect_reviewText__max_features=10000, transformer__vect_reviewText__ngram_range=(1, 2), transformer__vect_summary__max_features=32000, transformer__vect_summary__ngram_range=(1, 2);, score=0.799 total time=   2.6s
# [CV 3/5; 16/40] START classifier__alpha=0.1, classifier__fit_prior=False, transformer__vect_reviewText__max_features=10000, transformer__vect_reviewText__ngram_range=(1, 2), transformer__vect_summary__max_features=32000, transformer__vect_summary__ngram_range=(1, 2)
# [CV 3/5; 16/40] END classifier__alpha=0.1, classifier__fit_prior=False, transformer__vect_reviewText__max_features=10000, transformer__vect_reviewText__ngram_range=(1, 2), transformer__vect_summary__max_features=32000, transformer__vect_summary__ngram_range=(1, 2);, score=0.807 total time=   2.4s
# [CV 4/5; 16/40] START classifier__alpha=0.1, classifier__fit_prior=False, transformer__vect_reviewText__max_features=10000, transformer__vect_reviewText__ngram_range=(1, 2), transformer__vect_summary__max_features=32000, transformer__vect_summary__ngram_range=(1, 2)
# [CV 4/5; 16/40] END classifier__alpha=0.1, classifier__fit_prior=False, transformer__vect_reviewText__max_features=10000, transformer__vect_reviewText__ngram_range=(1, 2), transformer__vect_summary__max_features=32000, transformer__vect_summary__ngram_range=(1, 2);, score=0.809 total time=   2.8s
# [CV 5/5; 16/40] START classifier__alpha=0.1, classifier__fit_prior=False, transformer__vect_reviewText__max_features=10000, transformer__vect_reviewText__ngram_range=(1, 2), transformer__vect_summary__max_features=32000, transformer__vect_summary__ngram_range=(1, 2)
# [CV 5/5; 16/40] END classifier__alpha=0.1, classifier__fit_prior=False, transformer__vect_reviewText__max_features=10000, transformer__vect_reviewText__ngram_range=(1, 2), transformer__vect_summary__max_features=32000, transformer__vect_summary__ngram_range=(1, 2);, score=0.800 total time=   2.6s
# [CV 1/5; 17/40] START classifier__alpha=0.5, classifier__fit_prior=True, transformer__vect_reviewText__max_features=5000, transformer__vect_reviewText__ngram_range=(1, 2), transformer__vect_summary__max_features=10000, transformer__vect_summary__ngram_range=(1, 2)
# [CV 1/5; 17/40] END classifier__alpha=0.5, classifier__fit_prior=True, transformer__vect_reviewText__max_features=5000, transformer__vect_reviewText__ngram_range=(1, 2), transformer__vect_summary__max_features=10000, transformer__vect_summary__ngram_range=(1, 2);, score=0.765 total time=   2.8s
# [CV 2/5; 17/40] START classifier__alpha=0.5, classifier__fit_prior=True, transformer__vect_reviewText__max_features=5000, transformer__vect_reviewText__ngram_range=(1, 2), transformer__vect_summary__max_features=10000, transformer__vect_summary__ngram_range=(1, 2)
# [CV 2/5; 17/40] END classifier__alpha=0.5, classifier__fit_prior=True, transformer__vect_reviewText__max_features=5000, transformer__vect_reviewText__ngram_range=(1, 2), transformer__vect_summary__max_features=10000, transformer__vect_summary__ngram_range=(1, 2);, score=0.762 total time=   2.6s
# [CV 3/5; 17/40] START classifier__alpha=0.5, classifier__fit_prior=True, transformer__vect_reviewText__max_features=5000, transformer__vect_reviewText__ngram_range=(1, 2), transformer__vect_summary__max_features=10000, transformer__vect_summary__ngram_range=(1, 2)
# [CV 3/5; 17/40] END classifier__alpha=0.5, classifier__fit_prior=True, transformer__vect_reviewText__max_features=5000, transformer__vect_reviewText__ngram_range=(1, 2), transformer__vect_summary__max_features=10000, transformer__vect_summary__ngram_range=(1, 2);, score=0.761 total time=   2.5s
# [CV 4/5; 17/40] START classifier__alpha=0.5, classifier__fit_prior=True, transformer__vect_reviewText__max_features=5000, transformer__vect_reviewText__ngram_range=(1, 2), transformer__vect_summary__max_features=10000, transformer__vect_summary__ngram_range=(1, 2)
# [CV 4/5; 17/40] END classifier__alpha=0.5, classifier__fit_prior=True, transformer__vect_reviewText__max_features=5000, transformer__vect_reviewText__ngram_range=(1, 2), transformer__vect_summary__max_features=10000, transformer__vect_summary__ngram_range=(1, 2);, score=0.769 total time=   2.5s
# [CV 5/5; 17/40] START classifier__alpha=0.5, classifier__fit_prior=True, transformer__vect_reviewText__max_features=5000, transformer__vect_reviewText__ngram_range=(1, 2), transformer__vect_summary__max_features=10000, transformer__vect_summary__ngram_range=(1, 2)
# [CV 5/5; 17/40] END classifier__alpha=0.5, classifier__fit_prior=True, transformer__vect_reviewText__max_features=5000, transformer__vect_reviewText__ngram_range=(1, 2), transformer__vect_summary__max_features=10000, transformer__vect_summary__ngram_range=(1, 2);, score=0.756 total time=   2.4s
# ...
# [CV 3/5; 35/40] END classifier__alpha=10, classifier__fit_prior=True, transformer__vect_reviewText__max_features=10000, transformer__vect_reviewText__ngram_range=(1, 2), transformer__vect_summary__max_features=10000, transformer__vect_summary__ngram_range=(1, 2);, score=0.489 total time=   2.5s
# [CV 4/5; 35/40] START classifier__alpha=10, classifier__fit_prior=True, transformer__vect_reviewText__max_features=10000, transformer__vect_reviewText__ngram_range=(1, 2), transformer__vect_summary__max_features=10000, transformer__vect_summary__ngram_range=(1, 2)
# [CV 4/5; 35/40] END classifier__alpha=10, classifier__fit_prior=True, transformer__vect_reviewText__max_features=10000, transformer__vect_reviewText__ngram_range=(1, 2), transformer__vect_summary__max_features=10000, transformer__vect_summary__ngram_range=(1, 2);, score=0.485 total time=   2.9s
# [CV 5/5; 35/40] START classifier__alpha=10, classifier__fit_prior=True, transformer__vect_reviewText__max_features=10000, transformer__vect_reviewText__ngram_range=(1, 2), transformer__vect_summary__max_features=10000, transformer__vect_summary__ngram_range=(1, 2)
# [CV 5/5; 35/40] END classifier__alpha=10, classifier__fit_prior=True, transformer__vect_reviewText__max_features=10000, transformer__vect_reviewText__ngram_range=(1, 2), transformer__vect_summary__max_features=10000, transformer__vect_summary__ngram_range=(1, 2);, score=0.471 total time=   2.2s
# [CV 1/5; 36/40] START classifier__alpha=10, classifier__fit_prior=True, transformer__vect_reviewText__max_features=10000, transformer__vect_reviewText__ngram_range=(1, 2), transformer__vect_summary__max_features=32000, transformer__vect_summary__ngram_range=(1, 2)
# [CV 1/5; 36/40] END classifier__alpha=10, classifier__fit_prior=True, transformer__vect_reviewText__max_features=10000, transformer__vect_reviewText__ngram_range=(1, 2), transformer__vect_summary__max_features=32000, transformer__vect_summary__ngram_range=(1, 2);, score=0.450 total time=   2.3s
# [CV 2/5; 36/40] START classifier__alpha=10, classifier__fit_prior=True, transformer__vect_reviewText__max_features=10000, transformer__vect_reviewText__ngram_range=(1, 2), transformer__vect_summary__max_features=32000, transformer__vect_summary__ngram_range=(1, 2)
# [CV 2/5; 36/40] END classifier__alpha=10, classifier__fit_prior=True, transformer__vect_reviewText__max_features=10000, transformer__vect_reviewText__ngram_range=(1, 2), transformer__vect_summary__max_features=32000, transformer__vect_summary__ngram_range=(1, 2);, score=0.447 total time=   2.3s
# [CV 3/5; 36/40] START classifier__alpha=10, classifier__fit_prior=True, transformer__vect_reviewText__max_features=10000, transformer__vect_reviewText__ngram_range=(1, 2), transformer__vect_summary__max_features=32000, transformer__vect_summary__ngram_range=(1, 2)
# [CV 3/5; 36/40] END classifier__alpha=10, classifier__fit_prior=True, transformer__vect_reviewText__max_features=10000, transformer__vect_reviewText__ngram_range=(1, 2), transformer__vect_summary__max_features=32000, transformer__vect_summary__ngram_range=(1, 2);, score=0.453 total time=   2.3s
# [CV 4/5; 36/40] START classifier__alpha=10, classifier__fit_prior=True, transformer__vect_reviewText__max_features=10000, transformer__vect_reviewText__ngram_range=(1, 2), transformer__vect_summary__max_features=32000, transformer__vect_summary__ngram_range=(1, 2)
# [CV 4/5; 36/40] END classifier__alpha=10, classifier__fit_prior=True, transformer__vect_reviewText__max_features=10000, transformer__vect_reviewText__ngram_range=(1, 2), transformer__vect_summary__max_features=32000, transformer__vect_summary__ngram_range=(1, 2);, score=0.450 total time=   2.3s
# [CV 5/5; 36/40] START classifier__alpha=10, classifier__fit_prior=True, transformer__vect_reviewText__max_features=10000, transformer__vect_reviewText__ngram_range=(1, 2), transformer__vect_summary__max_features=32000, transformer__vect_summary__ngram_range=(1, 2)
# [CV 5/5; 36/40] END classifier__alpha=10, classifier__fit_prior=True, transformer__vect_reviewText__max_features=10000, transformer__vect_reviewText__ngram_range=(1, 2), transformer__vect_summary__max_features=32000, transformer__vect_summary__ngram_range=(1, 2);, score=0.450 total time=   2.3s
# [CV 1/5; 37/40] START classifier__alpha=10, classifier__fit_prior=False, transformer__vect_reviewText__max_features=5000, transformer__vect_reviewText__ngram_range=(1, 2), transformer__vect_summary__max_features=10000, transformer__vect_summary__ngram_range=(1, 2)
# [CV 1/5; 37/40] END classifier__alpha=10, classifier__fit_prior=False, transformer__vect_reviewText__max_features=5000, transformer__vect_reviewText__ngram_range=(1, 2), transformer__vect_summary__max_features=10000, transformer__vect_summary__ngram_range=(1, 2);, score=0.575 total time=   2.2s
# [CV 2/5; 37/40] START classifier__alpha=10, classifier__fit_prior=False, transformer__vect_reviewText__max_features=5000, transformer__vect_reviewText__ngram_range=(1, 2), transformer__vect_summary__max_features=10000, transformer__vect_summary__ngram_range=(1, 2)
# [CV 2/5; 37/40] END classifier__alpha=10, classifier__fit_prior=False, transformer__vect_reviewText__max_features=5000, transformer__vect_reviewText__ngram_range=(1, 2), transformer__vect_summary__max_features=10000, transformer__vect_summary__ngram_range=(1, 2);, score=0.569 total time=   2.2s
# [CV 3/5; 37/40] START classifier__alpha=10, classifier__fit_prior=False, transformer__vect_reviewText__max_features=5000, transformer__vect_reviewText__ngram_range=(1, 2), transformer__vect_summary__max_features=10000, transformer__vect_summary__ngram_range=(1, 2)
# [CV 3/5; 37/40] END classifier__alpha=10, classifier__fit_prior=False, transformer__vect_reviewText__max_features=5000, transformer__vect_reviewText__ngram_range=(1, 2), transformer__vect_summary__max_features=10000, transformer__vect_summary__ngram_range=(1, 2);, score=0.574 total time=   2.2s
# [CV 4/5; 37/40] START classifier__alpha=10, classifier__fit_prior=False, transformer__vect_reviewText__max_features=5000, transformer__vect_reviewText__ngram_range=(1, 2), transformer__vect_summary__max_features=10000, transformer__vect_summary__ngram_range=(1, 2)
# [CV 4/5; 37/40] END classifier__alpha=10, classifier__fit_prior=False, transformer__vect_reviewText__max_features=5000, transformer__vect_reviewText__ngram_range=(1, 2), transformer__vect_summary__max_features=10000, transformer__vect_summary__ngram_range=(1, 2);, score=0.564 total time=   2.2s
# [CV 5/5; 37/40] START classifier__alpha=10, classifier__fit_prior=False, transformer__vect_reviewText__max_features=5000, transformer__vect_reviewText__ngram_range=(1, 2), transformer__vect_summary__max_features=10000, transformer__vect_summary__ngram_range=(1, 2)
# [CV 5/5; 37/40] END classifier__alpha=10, classifier__fit_prior=False, transformer__vect_reviewText__max_features=5000, transformer__vect_reviewText__ngram_range=(1, 2), transformer__vect_summary__max_features=10000, transformer__vect_summary__ngram_range=(1, 2);, score=0.554 total time=   2.2s
# [CV 1/5; 38/40] START classifier__alpha=10, classifier__fit_prior=False, transformer__vect_reviewText__max_features=5000, transformer__vect_reviewText__ngram_range=(1, 2), transformer__vect_summary__max_features=32000, transformer__vect_summary__ngram_range=(1, 2)
# [CV 1/5; 38/40] END classifier__alpha=10, classifier__fit_prior=False, transformer__vect_reviewText__max_features=5000, transformer__vect_reviewText__ngram_range=(1, 2), transformer__vect_summary__max_features=32000, transformer__vect_summary__ngram_range=(1, 2);, score=0.491 total time=   2.2s
# [CV 2/5; 38/40] START classifier__alpha=10, classifier__fit_prior=False, transformer__vect_reviewText__max_features=5000, transformer__vect_reviewText__ngram_range=(1, 2), transformer__vect_summary__max_features=32000, transformer__vect_summary__ngram_range=(1, 2)
# [CV 2/5; 38/40] END classifier__alpha=10, classifier__fit_prior=False, transformer__vect_reviewText__max_features=5000, transformer__vect_reviewText__ngram_range=(1, 2), transformer__vect_summary__max_features=32000, transformer__vect_summary__ngram_range=(1, 2);, score=0.487 total time=   2.2s
# [CV 3/5; 38/40] START classifier__alpha=10, classifier__fit_prior=False, transformer__vect_reviewText__max_features=5000, transformer__vect_reviewText__ngram_range=(1, 2), transformer__vect_summary__max_features=32000, transformer__vect_summary__ngram_range=(1, 2)
# [CV 3/5; 38/40] END classifier__alpha=10, classifier__fit_prior=False, transformer__vect_reviewText__max_features=5000, transformer__vect_reviewText__ngram_range=(1, 2), transformer__vect_summary__max_features=32000, transformer__vect_summary__ngram_range=(1, 2);, score=0.493 total time=   2.3s
# [CV 4/5; 38/40] START classifier__alpha=10, classifier__fit_prior=False, transformer__vect_reviewText__max_features=5000, transformer__vect_reviewText__ngram_range=(1, 2), transformer__vect_summary__max_features=32000, transformer__vect_summary__ngram_range=(1, 2)
# [CV 4/5; 38/40] END classifier__alpha=10, classifier__fit_prior=False, transformer__vect_reviewText__max_features=5000, transformer__vect_reviewText__ngram_range=(1, 2), transformer__vect_summary__max_features=32000, transformer__vect_summary__ngram_range=(1, 2);, score=0.491 total time=   2.2s
# [CV 5/5; 38/40] START classifier__alpha=10, classifier__fit_prior=False, transformer__vect_reviewText__max_features=5000, transformer__vect_reviewText__ngram_range=(1, 2), transformer__vect_summary__max_features=32000, transformer__vect_summary__ngram_range=(1, 2)
# [CV 5/5; 38/40] END classifier__alpha=10, classifier__fit_prior=False, transformer__vect_reviewText__max_features=5000, transformer__vect_reviewText__ngram_range=(1, 2), transformer__vect_summary__max_features=32000, transformer__vect_summary__ngram_range=(1, 2);, score=0.476 total time=   2.2s
# [CV 1/5; 39/40] START classifier__alpha=10, classifier__fit_prior=False, transformer__vect_reviewText__max_features=10000, transformer__vect_reviewText__ngram_range=(1, 2), transformer__vect_summary__max_features=10000, transformer__vect_summary__ngram_range=(1, 2)
# [CV 1/5; 39/40] END classifier__alpha=10, classifier__fit_prior=False, transformer__vect_reviewText__max_features=10000, transformer__vect_reviewText__ngram_range=(1, 2), transformer__vect_summary__max_features=10000, transformer__vect_summary__ngram_range=(1, 2);, score=0.558 total time=   2.1s
# [CV 2/5; 39/40] START classifier__alpha=10, classifier__fit_prior=False, transformer__vect_reviewText__max_features=10000, transformer__vect_reviewText__ngram_range=(1, 2), transformer__vect_summary__max_features=10000, transformer__vect_summary__ngram_range=(1, 2)
# [CV 2/5; 39/40] END classifier__alpha=10, classifier__fit_prior=False, transformer__vect_reviewText__max_features=10000, transformer__vect_reviewText__ngram_range=(1, 2), transformer__vect_summary__max_features=10000, transformer__vect_summary__ngram_range=(1, 2);, score=0.545 total time=   2.3s
# [CV 3/5; 39/40] START classifier__alpha=10, classifier__fit_prior=False, transformer__vect_reviewText__max_features=10000, transformer__vect_reviewText__ngram_range=(1, 2), transformer__vect_summary__max_features=10000, transformer__vect_summary__ngram_range=(1, 2)
# [CV 3/5; 39/40] END classifier__alpha=10, classifier__fit_prior=False, transformer__vect_reviewText__max_features=10000, transformer__vect_reviewText__ngram_range=(1, 2), transformer__vect_summary__max_features=10000, transformer__vect_summary__ngram_range=(1, 2);, score=0.545 total time=   2.2s
# [CV 4/5; 39/40] START classifier__alpha=10, classifier__fit_prior=False, transformer__vect_reviewText__max_features=10000, transformer__vect_reviewText__ngram_range=(1, 2), transformer__vect_summary__max_features=10000, transformer__vect_summary__ngram_range=(1, 2)
# [CV 4/5; 39/40] END classifier__alpha=10, classifier__fit_prior=False, transformer__vect_reviewText__max_features=10000, transformer__vect_reviewText__ngram_range=(1, 2), transformer__vect_summary__max_features=10000, transformer__vect_summary__ngram_range=(1, 2);, score=0.545 total time=   2.3s
# [CV 5/5; 39/40] START classifier__alpha=10, classifier__fit_prior=False, transformer__vect_reviewText__max_features=10000, transformer__vect_reviewText__ngram_range=(1, 2), transformer__vect_summary__max_features=10000, transformer__vect_summary__ngram_range=(1, 2)
# [CV 5/5; 39/40] END classifier__alpha=10, classifier__fit_prior=False, transformer__vect_reviewText__max_features=10000, transformer__vect_reviewText__ngram_range=(1, 2), transformer__vect_summary__max_features=10000, transformer__vect_summary__ngram_range=(1, 2);, score=0.536 total time=   2.2s
# [CV 1/5; 40/40] START classifier__alpha=10, classifier__fit_prior=False, transformer__vect_reviewText__max_features=10000, transformer__vect_reviewText__ngram_range=(1, 2), transformer__vect_summary__max_features=32000, transformer__vect_summary__ngram_range=(1, 2)
# [CV 1/5; 40/40] END classifier__alpha=10, classifier__fit_prior=False, transformer__vect_reviewText__max_features=10000, transformer__vect_reviewText__ngram_range=(1, 2), transformer__vect_summary__max_features=32000, transformer__vect_summary__ngram_range=(1, 2);, score=0.494 total time=   2.3s
# [CV 2/5; 40/40] START classifier__alpha=10, classifier__fit_prior=False, transformer__vect_reviewText__max_features=10000, transformer__vect_reviewText__ngram_range=(1, 2), transformer__vect_summary__max_features=32000, transformer__vect_summary__ngram_range=(1, 2)
# [CV 2/5; 40/40] END classifier__alpha=10, classifier__fit_prior=False, transformer__vect_reviewText__max_features=10000, transformer__vect_reviewText__ngram_range=(1, 2), transformer__vect_summary__max_features=32000, transformer__vect_summary__ngram_range=(1, 2);, score=0.485 total time=   2.3s
# [CV 3/5; 40/40] START classifier__alpha=10, classifier__fit_prior=False, transformer__vect_reviewText__max_features=10000, transformer__vect_reviewText__ngram_range=(1, 2), transformer__vect_summary__max_features=32000, transformer__vect_summary__ngram_range=(1, 2)
# [CV 3/5; 40/40] END classifier__alpha=10, classifier__fit_prior=False, transformer__vect_reviewText__max_features=10000, transformer__vect_reviewText__ngram_range=(1, 2), transformer__vect_summary__max_features=32000, transformer__vect_summary__ngram_range=(1, 2);, score=0.488 total time=   2.3s
# [CV 4/5; 40/40] START classifier__alpha=10, classifier__fit_prior=False, transformer__vect_reviewText__max_features=10000, transformer__vect_reviewText__ngram_range=(1, 2), transformer__vect_summary__max_features=32000, transformer__vect_summary__ngram_range=(1, 2)
# [CV 4/5; 40/40] END classifier__alpha=10, classifier__fit_prior=False, transformer__vect_reviewText__max_features=10000, transformer__vect_reviewText__ngram_range=(1, 2), transformer__vect_summary__max_features=32000, transformer__vect_summary__ngram_range=(1, 2);, score=0.487 total time=   2.2s
# [CV 5/5; 40/40] START classifier__alpha=10, classifier__fit_prior=False, transformer__vect_reviewText__max_features=10000, transformer__vect_reviewText__ngram_range=(1, 2), transformer__vect_summary__max_features=32000, transformer__vect_summary__ngram_range=(1, 2)
# [CV 5/5; 40/40] END classifier__alpha=10, classifier__fit_prior=False, transformer__vect_reviewText__max_features=10000, transformer__vect_reviewText__ngram_range=(1, 2), transformer__vect_summary__max_features=32000, transformer__vect_summary__ngram_range=(1, 2);, score=0.474 total time=   2.1s
# Best: 0.809570 using {'classifier__alpha': 0.5, 'classifier__fit_prior': False, 'transformer__vect_reviewText__max_features': 10000, 'transformer__vect_reviewText__ngram_range': (1, 2), 'transformer__vect_summary__max_features': 10000, 'transformer__vect_summary__ngram_range': (1, 2)}
# f1_score:  0.8210957623021629
# accuracy:  0.880781089414183
# auc score:  0.8392909147641584

# %% [markdown]
# # SVC

# %%
from sklearn.svm import LinearSVC
from sklearn.calibration import CalibratedClassifierCV

pipe = Pipeline([
    ("transformer", ct),
    ("classifier", CalibratedClassifierCV(estimator = LinearSVC()))
])

svcModel_params = {
    "transformer__vect_summary__ngram_range": [(1, 2)],
    "transformer__vect_reviewText__ngram_range": [(1, 2)],
    "transformer__vect_summary__max_features": [10000, 32000],
    "transformer__vect_reviewText__max_features": [5000, 10000],
    "classifier__estimator__C": [10, 1, 0.1, 0.01],
    "classifier__estimator__penalty": ['l1', 'l2'],
}


# perform grid search cross-validation to find the best hyperparameters
grid_svc = GridSearchCV(pipe, svcModel_params, cv=5, scoring='f1_macro', verbose=10)

grid_svc.fit(X_train, y_train)
print("-----------------------------------------------------------------------------------------------------------------------------------")
print("Best: %f using %s" % (grid_svc.best_score_, grid_svc.best_params_))

# predict
y_pred_svc = grid_svc.best_estimator_.predict(X_test)

# f1 score
fscore = f1_score(y_test, y_pred_svc, average='macro')
print("f1_score: ", fscore)
f1_arr.append(fscore)

# accuracy
accur = accuracy_score(y_test, y_pred_svc)
accuracy_arr.append(accur)
print("accuracy: ", accur)

# auc score
aucscore = roc_auc_score(y_test, y_pred_svc)
print("auc score: ", aucscore)
auc_arr.append(aucscore)

# confusion matrix
cm_svc = confusion_matrix(y_test, y_pred_svc)
tn, fp, fn, tp = cm_svc.ravel()
fpr = fp / (fp + tn)
tpr = tp / (tp + fn)
sns.heatmap(cm_svc, annot=True, fmt='d', cmap='Blues',
            xticklabels=['Predicted Negative', 'Predicted Positive'],
            yticklabels=['Actual Negative\nFPR={:.2f}'.format(fpr), 'Actual Positive\nTPR={:.2f}'.format(tpr)])
plt.title("Confusion Matrix")
plt.show()

# ROC curve
y_pred_prob_svc = grid_svc.best_estimator_.predict_proba(X_test)
fpr, tpr, threshold = roc_curve(y_test, y_pred_prob_svc[:, 1])
sns.lineplot(x=fpr, y=tpr, label="AUC="+str(aucscore))
plt.plot([0, 1], [0, 1], color='navy', lw=2, linestyle='--')
plt.xlabel("FPR")
plt.ylabel("TPR")
plt.title("ROC Curve")
plt.show()

model_arr.append("LinearSVC")

# Best: 0.805811 using {'classifier__C': 1, 'classifier__penalty': 'l2', 'transformer__vect_reviewText__max_features': 10000, 'transformer__vect_reviewText__ngram_range': (1, 2), 'transformer__vect_summary__max_features': 40000, 'transformer__vect_summary__ngram_range': (1, 2)}
# Out:
# Fitting 5 folds for each of 32 candidates, totalling 160 fits
# [CV 1/5; 1/32] START classifier__estimator__C=10, classifier__estimator__penalty=l1, transformer__vect_reviewText__max_features=5000, transformer__vect_reviewText__ngram_range=(1, 2), transformer__vect_summary__max_features=10000, transformer__vect_summary__ngram_range=(1, 2)
# [CV 1/5; 1/32] END classifier__estimator__C=10, classifier__estimator__penalty=l1, transformer__vect_reviewText__max_features=5000, transformer__vect_reviewText__ngram_range=(1, 2), transformer__vect_summary__max_features=10000, transformer__vect_summary__ngram_range=(1, 2);, score=nan total time=   2.6s
# [CV 2/5; 1/32] START classifier__estimator__C=10, classifier__estimator__penalty=l1, transformer__vect_reviewText__max_features=5000, transformer__vect_reviewText__ngram_range=(1, 2), transformer__vect_summary__max_features=10000, transformer__vect_summary__ngram_range=(1, 2)
# [CV 2/5; 1/32] END classifier__estimator__C=10, classifier__estimator__penalty=l1, transformer__vect_reviewText__max_features=5000, transformer__vect_reviewText__ngram_range=(1, 2), transformer__vect_summary__max_features=10000, transformer__vect_summary__ngram_range=(1, 2);, score=nan total time=   2.1s
# [CV 3/5; 1/32] START classifier__estimator__C=10, classifier__estimator__penalty=l1, transformer__vect_reviewText__max_features=5000, transformer__vect_reviewText__ngram_range=(1, 2), transformer__vect_summary__max_features=10000, transformer__vect_summary__ngram_range=(1, 2)
# [CV 3/5; 1/32] END classifier__estimator__C=10, classifier__estimator__penalty=l1, transformer__vect_reviewText__max_features=5000, transformer__vect_reviewText__ngram_range=(1, 2), transformer__vect_summary__max_features=10000, transformer__vect_summary__ngram_range=(1, 2);, score=nan total time=   2.3s
# [CV 4/5; 1/32] START classifier__estimator__C=10, classifier__estimator__penalty=l1, transformer__vect_reviewText__max_features=5000, transformer__vect_reviewText__ngram_range=(1, 2), transformer__vect_summary__max_features=10000, transformer__vect_summary__ngram_range=(1, 2)
# [CV 4/5; 1/32] END classifier__estimator__C=10, classifier__estimator__penalty=l1, transformer__vect_reviewText__max_features=5000, transformer__vect_reviewText__ngram_range=(1, 2), transformer__vect_summary__max_features=10000, transformer__vect_summary__ngram_range=(1, 2);, score=nan total time=   2.5s
# [CV 5/5; 1/32] START classifier__estimator__C=10, classifier__estimator__penalty=l1, transformer__vect_reviewText__max_features=5000, transformer__vect_reviewText__ngram_range=(1, 2), transformer__vect_summary__max_features=10000, transformer__vect_summary__ngram_range=(1, 2)
# [CV 5/5; 1/32] END classifier__estimator__C=10, classifier__estimator__penalty=l1, transformer__vect_reviewText__max_features=5000, transformer__vect_reviewText__ngram_range=(1, 2), transformer__vect_summary__max_features=10000, transformer__vect_summary__ngram_range=(1, 2);, score=nan total time=   2.3s
# [CV 1/5; 2/32] START classifier__estimator__C=10, classifier__estimator__penalty=l1, transformer__vect_reviewText__max_features=5000, transformer__vect_reviewText__ngram_range=(1, 2), transformer__vect_summary__max_features=32000, transformer__vect_summary__ngram_range=(1, 2)
# [CV 1/5; 2/32] END classifier__estimator__C=10, classifier__estimator__penalty=l1, transformer__vect_reviewText__max_features=5000, transformer__vect_reviewText__ngram_range=(1, 2), transformer__vect_summary__max_features=32000, transformer__vect_summary__ngram_range=(1, 2);, score=nan total time=   2.5s
# [CV 2/5; 2/32] START classifier__estimator__C=10, classifier__estimator__penalty=l1, transformer__vect_reviewText__max_features=5000, transformer__vect_reviewText__ngram_range=(1, 2), transformer__vect_summary__max_features=32000, transformer__vect_summary__ngram_range=(1, 2)
# [CV 2/5; 2/32] END classifier__estimator__C=10, classifier__estimator__penalty=l1, transformer__vect_reviewText__max_features=5000, transformer__vect_reviewText__ngram_range=(1, 2), transformer__vect_summary__max_features=32000, transformer__vect_summary__ngram_range=(1, 2);, score=nan total time=   2.5s
# [CV 3/5; 2/32] START classifier__estimator__C=10, classifier__estimator__penalty=l1, transformer__vect_reviewText__max_features=5000, transformer__vect_reviewText__ngram_range=(1, 2), transformer__vect_summary__max_features=32000, transformer__vect_summary__ngram_range=(1, 2)
# [CV 3/5; 2/32] END classifier__estimator__C=10, classifier__estimator__penalty=l1, transformer__vect_reviewText__max_features=5000, transformer__vect_reviewText__ngram_range=(1, 2), transformer__vect_summary__max_features=32000, transformer__vect_summary__ngram_range=(1, 2);, score=nan total time=   2.3s
# [CV 4/5; 2/32] START classifier__estimator__C=10, classifier__estimator__penalty=l1, transformer__vect_reviewText__max_features=5000, transformer__vect_reviewText__ngram_range=(1, 2), transformer__vect_summary__max_features=32000, transformer__vect_summary__ngram_range=(1, 2)
# [CV 4/5; 2/32] END classifier__estimator__C=10, classifier__estimator__penalty=l1, transformer__vect_reviewText__max_features=5000, transformer__vect_reviewText__ngram_range=(1, 2), transformer__vect_summary__max_features=32000, transformer__vect_summary__ngram_range=(1, 2);, score=nan total time=   2.5s
# [CV 5/5; 2/32] START classifier__estimator__C=10, classifier__estimator__penalty=l1, transformer__vect_reviewText__max_features=5000, transformer__vect_reviewText__ngram_range=(1, 2), transformer__vect_summary__max_features=32000, transformer__vect_summary__ngram_range=(1, 2)
# [CV 5/5; 2/32] END classifier__estimator__C=10, classifier__estimator__penalty=l1, transformer__vect_reviewText__max_features=5000, transformer__vect_reviewText__ngram_range=(1, 2), transformer__vect_summary__max_features=32000, transformer__vect_summary__ngram_range=(1, 2);, score=nan total time=   2.3s
# [CV 1/5; 3/32] START classifier__estimator__C=10, classifier__estimator__penalty=l1, transformer__vect_reviewText__max_features=10000, transformer__vect_reviewText__ngram_range=(1, 2), transformer__vect_summary__max_features=10000, transformer__vect_summary__ngram_range=(1, 2)
# [CV 1/5; 3/32] END classifier__estimator__C=10, classifier__estimator__penalty=l1, transformer__vect_reviewText__max_features=10000, transformer__vect_reviewText__ngram_range=(1, 2), transformer__vect_summary__max_features=10000, transformer__vect_summary__ngram_range=(1, 2);, score=nan total time=   2.2s
# [CV 2/5; 3/32] START classifier__estimator__C=10, classifier__estimator__penalty=l1, transformer__vect_reviewText__max_features=10000, transformer__vect_reviewText__ngram_range=(1, 2), transformer__vect_summary__max_features=10000, transformer__vect_summary__ngram_range=(1, 2)
# [CV 2/5; 3/32] END classifier__estimator__C=10, classifier__estimator__penalty=l1, transformer__vect_reviewText__max_features=10000, transformer__vect_reviewText__ngram_range=(1, 2), transformer__vect_summary__max_features=10000, transformer__vect_summary__ngram_range=(1, 2);, score=nan total time=   2.1s
# [CV 3/5; 3/32] START classifier__estimator__C=10, classifier__estimator__penalty=l1, transformer__vect_reviewText__max_features=10000, transformer__vect_reviewText__ngram_range=(1, 2), transformer__vect_summary__max_features=10000, transformer__vect_summary__ngram_range=(1, 2)
# [CV 3/5; 3/32] END classifier__estimator__C=10, classifier__estimator__penalty=l1, transformer__vect_reviewText__max_features=10000, transformer__vect_reviewText__ngram_range=(1, 2), transformer__vect_summary__max_features=10000, transformer__vect_summary__ngram_range=(1, 2);, score=nan total time=   2.2s
# [CV 4/5; 3/32] START classifier__estimator__C=10, classifier__estimator__penalty=l1, transformer__vect_reviewText__max_features=10000, transformer__vect_reviewText__ngram_range=(1, 2), transformer__vect_summary__max_features=10000, transformer__vect_summary__ngram_range=(1, 2)
# [CV 4/5; 3/32] END classifier__estimator__C=10, classifier__estimator__penalty=l1, transformer__vect_reviewText__max_features=10000, transformer__vect_reviewText__ngram_range=(1, 2), transformer__vect_summary__max_features=10000, transformer__vect_summary__ngram_range=(1, 2);, score=nan total time=   2.2s
# [CV 5/5; 3/32] START classifier__estimator__C=10, classifier__estimator__penalty=l1, transformer__vect_reviewText__max_features=10000, transformer__vect_reviewText__ngram_range=(1, 2), transformer__vect_summary__max_features=10000, transformer__vect_summary__ngram_range=(1, 2)
# [CV 5/5; 3/32] END classifier__estimator__C=10, classifier__estimator__penalty=l1, transformer__vect_reviewText__max_features=10000, transformer__vect_reviewText__ngram_range=(1, 2), transformer__vect_summary__max_features=10000, transformer__vect_summary__ngram_range=(1, 2);, score=nan total time=   2.2s
# [CV 1/5; 4/32] START classifier__estimator__C=10, classifier__estimator__penalty=l1, transformer__vect_reviewText__max_features=10000, transformer__vect_reviewText__ngram_range=(1, 2), transformer__vect_summary__max_features=32000, transformer__vect_summary__ngram_range=(1, 2)
# [CV 1/5; 4/32] END classifier__estimator__C=10, classifier__estimator__penalty=l1, transformer__vect_reviewText__max_features=10000, transformer__vect_reviewText__ngram_range=(1, 2), transformer__vect_summary__max_features=32000, transformer__vect_summary__ngram_range=(1, 2);, score=nan total time=   2.2s
# [CV 2/5; 4/32] START classifier__estimator__C=10, classifier__estimator__penalty=l1, transformer__vect_reviewText__max_features=10000, transformer__vect_reviewText__ngram_range=(1, 2), transformer__vect_summary__max_features=32000, transformer__vect_summary__ngram_range=(1, 2)
# [CV 2/5; 4/32] END classifier__estimator__C=10, classifier__estimator__penalty=l1, transformer__vect_reviewText__max_features=10000, transformer__vect_reviewText__ngram_range=(1, 2), transformer__vect_summary__max_features=32000, transformer__vect_summary__ngram_range=(1, 2);, score=nan total time=   2.5s
# [CV 3/5; 4/32] START classifier__estimator__C=10, classifier__estimator__penalty=l1, transformer__vect_reviewText__max_features=10000, transformer__vect_reviewText__ngram_range=(1, 2), transformer__vect_summary__max_features=32000, transformer__vect_summary__ngram_range=(1, 2)
# [CV 3/5; 4/32] END classifier__estimator__C=10, classifier__estimator__penalty=l1, transformer__vect_reviewText__max_features=10000, transformer__vect_reviewText__ngram_range=(1, 2), transformer__vect_summary__max_features=32000, transformer__vect_summary__ngram_range=(1, 2);, score=nan total time=   2.2s
# [CV 4/5; 4/32] START classifier__estimator__C=10, classifier__estimator__penalty=l1, transformer__vect_reviewText__max_features=10000, transformer__vect_reviewText__ngram_range=(1, 2), transformer__vect_summary__max_features=32000, transformer__vect_summary__ngram_range=(1, 2)
# [CV 4/5; 4/32] END classifier__estimator__C=10, classifier__estimator__penalty=l1, transformer__vect_reviewText__max_features=10000, transformer__vect_reviewText__ngram_range=(1, 2), transformer__vect_summary__max_features=32000, transformer__vect_summary__ngram_range=(1, 2);, score=nan total time=   2.2s
# [CV 5/5; 4/32] START classifier__estimator__C=10, classifier__estimator__penalty=l1, transformer__vect_reviewText__max_features=10000, transformer__vect_reviewText__ngram_range=(1, 2), transformer__vect_summary__max_features=32000, transformer__vect_summary__ngram_range=(1, 2)
# [CV 5/5; 4/32] END classifier__estimator__C=10, classifier__estimator__penalty=l1, transformer__vect_reviewText__max_features=10000, transformer__vect_reviewText__ngram_range=(1, 2), transformer__vect_summary__max_features=32000, transformer__vect_summary__ngram_range=(1, 2);, score=nan total time=   2.2s
# [CV 1/5; 5/32] START classifier__estimator__C=10, classifier__estimator__penalty=l2, transformer__vect_reviewText__max_features=5000, transformer__vect_reviewText__ngram_range=(1, 2), transformer__vect_summary__max_features=10000, transformer__vect_summary__ngram_range=(1, 2)
# [CV 1/5; 5/32] END classifier__estimator__C=10, classifier__estimator__penalty=l2, transformer__vect_reviewText__max_features=5000, transformer__vect_reviewText__ngram_range=(1, 2), transformer__vect_summary__max_features=10000, transformer__vect_summary__ngram_range=(1, 2);, score=0.780 total time=   6.8s
# [CV 2/5; 5/32] START classifier__estimator__C=10, classifier__estimator__penalty=l2, transformer__vect_reviewText__max_features=5000, transformer__vect_reviewText__ngram_range=(1, 2), transformer__vect_summary__max_features=10000, transformer__vect_summary__ngram_range=(1, 2)
# [CV 2/5; 5/32] END classifier__estimator__C=10, classifier__estimator__penalty=l2, transformer__vect_reviewText__max_features=5000, transformer__vect_reviewText__ngram_range=(1, 2), transformer__vect_summary__max_features=10000, transformer__vect_summary__ngram_range=(1, 2);, score=0.758 total time=   7.5s
# [CV 3/5; 5/32] START classifier__estimator__C=10, classifier__estimator__penalty=l2, transformer__vect_reviewText__max_features=5000, transformer__vect_reviewText__ngram_range=(1, 2), transformer__vect_summary__max_features=10000, transformer__vect_summary__ngram_range=(1, 2)
# [CV 3/5; 5/32] END classifier__estimator__C=10, classifier__estimator__penalty=l2, transformer__vect_reviewText__max_features=5000, transformer__vect_reviewText__ngram_range=(1, 2), transformer__vect_summary__max_features=10000, transformer__vect_summary__ngram_range=(1, 2);, score=0.771 total time=   7.2s
# [CV 4/5; 5/32] START classifier__estimator__C=10, classifier__estimator__penalty=l2, transformer__vect_reviewText__max_features=5000, transformer__vect_reviewText__ngram_range=(1, 2), transformer__vect_summary__max_features=10000, transformer__vect_summary__ngram_range=(1, 2)
# [CV 4/5; 5/32] END classifier__estimator__C=10, classifier__estimator__penalty=l2, transformer__vect_reviewText__max_features=5000, transformer__vect_reviewText__ngram_range=(1, 2), transformer__vect_summary__max_features=10000, transformer__vect_summary__ngram_range=(1, 2);, score=0.786 total time=   6.4s
# [CV 5/5; 5/32] START classifier__estimator__C=10, classifier__estimator__penalty=l2, transformer__vect_reviewText__max_features=5000, transformer__vect_reviewText__ngram_range=(1, 2), transformer__vect_summary__max_features=10000, transformer__vect_summary__ngram_range=(1, 2)
# [CV 5/5; 5/32] END classifier__estimator__C=10, classifier__estimator__penalty=l2, transformer__vect_reviewText__max_features=5000, transformer__vect_reviewText__ngram_range=(1, 2), transformer__vect_summary__max_features=10000, transformer__vect_summary__ngram_range=(1, 2);, score=0.769 total time=   7.2s
# [CV 1/5; 6/32] START classifier__estimator__C=10, classifier__estimator__penalty=l2, transformer__vect_reviewText__max_features=5000, transformer__vect_reviewText__ngram_range=(1, 2), transformer__vect_summary__max_features=32000, transformer__vect_summary__ngram_range=(1, 2)
# [CV 1/5; 6/32] END classifier__estimator__C=10, classifier__estimator__penalty=l2, transformer__vect_reviewText__max_features=5000, transformer__vect_reviewText__ngram_range=(1, 2), transformer__vect_summary__max_features=32000, transformer__vect_summary__ngram_range=(1, 2);, score=0.792 total time=   8.4s
# [CV 2/5; 6/32] START classifier__estimator__C=10, classifier__estimator__penalty=l2, transformer__vect_reviewText__max_features=5000, transformer__vect_reviewText__ngram_range=(1, 2), transformer__vect_summary__max_features=32000, transformer__vect_summary__ngram_range=(1, 2)
# [CV 2/5; 6/32] END classifier__estimator__C=10, classifier__estimator__penalty=l2, transformer__vect_reviewText__max_features=5000, transformer__vect_reviewText__ngram_range=(1, 2), transformer__vect_summary__max_features=32000, transformer__vect_summary__ngram_range=(1, 2);, score=0.774 total time=   7.8s
# [CV 3/5; 6/32] START classifier__estimator__C=10, classifier__estimator__penalty=l2, transformer__vect_reviewText__max_features=5000, transformer__vect_reviewText__ngram_range=(1, 2), transformer__vect_summary__max_features=32000, transformer__vect_summary__ngram_range=(1, 2)
# [CV 3/5; 6/32] END classifier__estimator__C=10, classifier__estimator__penalty=l2, transformer__vect_reviewText__max_features=5000, transformer__vect_reviewText__ngram_range=(1, 2), transformer__vect_summary__max_features=32000, transformer__vect_summary__ngram_range=(1, 2);, score=0.781 total time=   8.0s
# [CV 4/5; 6/32] START classifier__estimator__C=10, classifier__estimator__penalty=l2, transformer__vect_reviewText__max_features=5000, transformer__vect_reviewText__ngram_range=(1, 2), transformer__vect_summary__max_features=32000, transformer__vect_summary__ngram_range=(1, 2)
# [CV 4/5; 6/32] END classifier__estimator__C=10, classifier__estimator__penalty=l2, transformer__vect_reviewText__max_features=5000, transformer__vect_reviewText__ngram_range=(1, 2), transformer__vect_summary__max_features=32000, transformer__vect_summary__ngram_range=(1, 2);, score=0.790 total time=   8.9s
# [CV 5/5; 6/32] START classifier__estimator__C=10, classifier__estimator__penalty=l2, transformer__vect_reviewText__max_features=5000, transformer__vect_reviewText__ngram_range=(1, 2), transformer__vect_summary__max_features=32000, transformer__vect_summary__ngram_range=(1, 2)
# [CV 5/5; 6/32] END classifier__estimator__C=10, classifier__estimator__penalty=l2, transformer__vect_reviewText__max_features=5000, transformer__vect_reviewText__ngram_range=(1, 2), transformer__vect_summary__max_features=32000, transformer__vect_summary__ngram_range=(1, 2);, score=0.778 total time=   8.8s
# [CV 1/5; 7/32] START classifier__estimator__C=10, classifier__estimator__penalty=l2, transformer__vect_reviewText__max_features=10000, transformer__vect_reviewText__ngram_range=(1, 2), transformer__vect_summary__max_features=10000, transformer__vect_summary__ngram_range=(1, 2)
# [CV 1/5; 7/32] END classifier__estimator__C=10, classifier__estimator__penalty=l2, transformer__vect_reviewText__max_features=10000, transformer__vect_reviewText__ngram_range=(1, 2), transformer__vect_summary__max_features=10000, transformer__vect_summary__ngram_range=(1, 2);, score=0.781 total time=   8.9s
# [CV 2/5; 7/32] START classifier__estimator__C=10, classifier__estimator__penalty=l2, transformer__vect_reviewText__max_features=10000, transformer__vect_reviewText__ngram_range=(1, 2), transformer__vect_summary__max_features=10000, transformer__vect_summary__ngram_range=(1, 2)
# [CV 2/5; 7/32] END classifier__estimator__C=10, classifier__estimator__penalty=l2, transformer__vect_reviewText__max_features=10000, transformer__vect_reviewText__ngram_range=(1, 2), transformer__vect_summary__max_features=10000, transformer__vect_summary__ngram_range=(1, 2);, score=0.765 total time=   7.4s
# [CV 3/5; 7/32] START classifier__estimator__C=10, classifier__estimator__penalty=l2, transformer__vect_reviewText__max_features=10000, transformer__vect_reviewText__ngram_range=(1, 2), transformer__vect_summary__max_features=10000, transformer__vect_summary__ngram_range=(1, 2)
# [CV 3/5; 7/32] END classifier__estimator__C=10, classifier__estimator__penalty=l2, transformer__vect_reviewText__max_features=10000, transformer__vect_reviewText__ngram_range=(1, 2), transformer__vect_summary__max_features=10000, transformer__vect_summary__ngram_range=(1, 2);, score=0.777 total time=   9.3s
# [CV 4/5; 7/32] START classifier__estimator__C=10, classifier__estimator__penalty=l2, transformer__vect_reviewText__max_features=10000, transformer__vect_reviewText__ngram_range=(1, 2), transformer__vect_summary__max_features=10000, transformer__vect_summary__ngram_range=(1, 2)
# [CV 4/5; 7/32] END classifier__estimator__C=10, classifier__estimator__penalty=l2, transformer__vect_reviewText__max_features=10000, transformer__vect_reviewText__ngram_range=(1, 2), transformer__vect_summary__max_features=10000, transformer__vect_summary__ngram_range=(1, 2);, score=0.790 total time=   8.5s
# [CV 5/5; 7/32] START classifier__estimator__C=10, classifier__estimator__penalty=l2, transformer__vect_reviewText__max_features=10000, transformer__vect_reviewText__ngram_range=(1, 2), transformer__vect_summary__max_features=10000, transformer__vect_summary__ngram_range=(1, 2)
# [CV 5/5; 7/32] END classifier__estimator__C=10, classifier__estimator__penalty=l2, transformer__vect_reviewText__max_features=10000, transformer__vect_reviewText__ngram_range=(1, 2), transformer__vect_summary__max_features=10000, transformer__vect_summary__ngram_range=(1, 2);, score=0.773 total time=   8.7s
# [CV 1/5; 8/32] START classifier__estimator__C=10, classifier__estimator__penalty=l2, transformer__vect_reviewText__max_features=10000, transformer__vect_reviewText__ngram_range=(1, 2), transformer__vect_summary__max_features=32000, transformer__vect_summary__ngram_range=(1, 2)
# [CV 1/5; 8/32] END classifier__estimator__C=10, classifier__estimator__penalty=l2, transformer__vect_reviewText__max_features=10000, transformer__vect_reviewText__ngram_range=(1, 2), transformer__vect_summary__max_features=32000, transformer__vect_summary__ngram_range=(1, 2);, score=0.788 total time=   8.8s
# [CV 2/5; 8/32] START classifier__estimator__C=10, classifier__estimator__penalty=l2, transformer__vect_reviewText__max_features=10000, transformer__vect_reviewText__ngram_range=(1, 2), transformer__vect_summary__max_features=32000, transformer__vect_summary__ngram_range=(1, 2)
# [CV 2/5; 8/32] END classifier__estimator__C=10, classifier__estimator__penalty=l2, transformer__vect_reviewText__max_features=10000, transformer__vect_reviewText__ngram_range=(1, 2), transformer__vect_summary__max_features=32000, transformer__vect_summary__ngram_range=(1, 2);, score=0.775 total time=  10.1s
# [CV 3/5; 8/32] START classifier__estimator__C=10, classifier__estimator__penalty=l2, transformer__vect_reviewText__max_features=10000, transformer__vect_reviewText__ngram_range=(1, 2), transformer__vect_summary__max_features=32000, transformer__vect_summary__ngram_range=(1, 2)
# [CV 3/5; 8/32] END classifier__estimator__C=10, classifier__estimator__penalty=l2, transformer__vect_reviewText__max_features=10000, transformer__vect_reviewText__ngram_range=(1, 2), transformer__vect_summary__max_features=32000, transformer__vect_summary__ngram_range=(1, 2);, score=0.784 total time=   9.5s
# [CV 4/5; 8/32] START classifier__estimator__C=10, classifier__estimator__penalty=l2, transformer__vect_reviewText__max_features=10000, transformer__vect_reviewText__ngram_range=(1, 2), transformer__vect_summary__max_features=32000, transformer__vect_summary__ngram_range=(1, 2)
# [CV 4/5; 8/32] END classifier__estimator__C=10, classifier__estimator__penalty=l2, transformer__vect_reviewText__max_features=10000, transformer__vect_reviewText__ngram_range=(1, 2), transformer__vect_summary__max_features=32000, transformer__vect_summary__ngram_range=(1, 2);, score=0.797 total time=   9.6s
# [CV 5/5; 8/32] START classifier__estimator__C=10, classifier__estimator__penalty=l2, transformer__vect_reviewText__max_features=10000, transformer__vect_reviewText__ngram_range=(1, 2), transformer__vect_summary__max_features=32000, transformer__vect_summary__ngram_range=(1, 2)
# [CV 5/5; 8/32] END classifier__estimator__C=10, classifier__estimator__penalty=l2, transformer__vect_reviewText__max_features=10000, transformer__vect_reviewText__ngram_range=(1, 2), transformer__vect_summary__max_features=32000, transformer__vect_summary__ngram_range=(1, 2);, score=0.781 total time=   9.8s
# [CV 1/5; 9/32] START classifier__estimator__C=1, classifier__estimator__penalty=l1, transformer__vect_reviewText__max_features=5000, transformer__vect_reviewText__ngram_range=(1, 2), transformer__vect_summary__max_features=10000, transformer__vect_summary__ngram_range=(1, 2)
# [CV 1/5; 9/32] END classifier__estimator__C=1, classifier__estimator__penalty=l1, transformer__vect_reviewText__max_features=5000, transformer__vect_reviewText__ngram_range=(1, 2), transformer__vect_summary__max_features=10000, transformer__vect_summary__ngram_range=(1, 2);, score=nan total time=   2.3s
# [CV 2/5; 9/32] START classifier__estimator__C=1, classifier__estimator__penalty=l1, transformer__vect_reviewText__max_features=5000, transformer__vect_reviewText__ngram_range=(1, 2), transformer__vect_summary__max_features=10000, transformer__vect_summary__ngram_range=(1, 2)
# [CV 2/5; 9/32] END classifier__estimator__C=1, classifier__estimator__penalty=l1, transformer__vect_reviewText__max_features=5000, transformer__vect_reviewText__ngram_range=(1, 2), transformer__vect_summary__max_features=10000, transformer__vect_summary__ngram_range=(1, 2);, score=nan total time=   2.1s
# [CV 3/5; 9/32] START classifier__estimator__C=1, classifier__estimator__penalty=l1, transformer__vect_reviewText__max_features=5000, transformer__vect_reviewText__ngram_range=(1, 2), transformer__vect_summary__max_features=10000, transformer__vect_summary__ngram_range=(1, 2)
# [CV 3/5; 9/32] END classifier__estimator__C=1, classifier__estimator__penalty=l1, transformer__vect_reviewText__max_features=5000, transformer__vect_reviewText__ngram_range=(1, 2), transformer__vect_summary__max_features=10000, transformer__vect_summary__ngram_range=(1, 2);, score=nan total time= 1.3min
# [CV 4/5; 9/32] START classifier__estimator__C=1, classifier__estimator__penalty=l1, transformer__vect_reviewText__max_features=5000, transformer__vect_reviewText__ngram_range=(1, 2), transformer__vect_summary__max_features=10000, transformer__vect_summary__ngram_range=(1, 2)
# [CV 4/5; 9/32] END classifier__estimator__C=1, classifier__estimator__penalty=l1, transformer__vect_reviewText__max_features=5000, transformer__vect_reviewText__ngram_range=(1, 2), transformer__vect_summary__max_features=10000, transformer__vect_summary__ngram_range=(1, 2);, score=nan total time=   2.4s
# [CV 5/5; 9/32] START classifier__estimator__C=1, classifier__estimator__penalty=l1, transformer__vect_reviewText__max_features=5000, transformer__vect_reviewText__ngram_range=(1, 2), transformer__vect_summary__max_features=10000, transformer__vect_summary__ngram_range=(1, 2)
# [CV 5/5; 9/32] END classifier__estimator__C=1, classifier__estimator__penalty=l1, transformer__vect_reviewText__max_features=5000, transformer__vect_reviewText__ngram_range=(1, 2), transformer__vect_summary__max_features=10000, transformer__vect_summary__ngram_range=(1, 2);, score=nan total time=   2.2s
# [CV 1/5; 10/32] START classifier__estimator__C=1, classifier__estimator__penalty=l1, transformer__vect_reviewText__max_features=5000, transformer__vect_reviewText__ngram_range=(1, 2), transformer__vect_summary__max_features=32000, transformer__vect_summary__ngram_range=(1, 2)
# [CV 1/5; 10/32] END classifier__estimator__C=1, classifier__estimator__penalty=l1, transformer__vect_reviewText__max_features=5000, transformer__vect_reviewText__ngram_range=(1, 2), transformer__vect_summary__max_features=32000, transformer__vect_summary__ngram_range=(1, 2);, score=nan total time=   2.1s
# [CV 2/5; 10/32] START classifier__estimator__C=1, classifier__estimator__penalty=l1, transformer__vect_reviewText__max_features=5000, transformer__vect_reviewText__ngram_range=(1, 2), transformer__vect_summary__max_features=32000, transformer__vect_summary__ngram_range=(1, 2)
# [CV 2/5; 10/32] END classifier__estimator__C=1, classifier__estimator__penalty=l1, transformer__vect_reviewText__max_features=5000, transformer__vect_reviewText__ngram_range=(1, 2), transformer__vect_summary__max_features=32000, transformer__vect_summary__ngram_range=(1, 2);, score=nan total time= 1.6min
# [CV 3/5; 10/32] START classifier__estimator__C=1, classifier__estimator__penalty=l1, transformer__vect_reviewText__max_features=5000, transformer__vect_reviewText__ngram_range=(1, 2), transformer__vect_summary__max_features=32000, transformer__vect_summary__ngram_range=(1, 2)
# [CV 3/5; 10/32] END classifier__estimator__C=1, classifier__estimator__penalty=l1, transformer__vect_reviewText__max_features=5000, transformer__vect_reviewText__ngram_range=(1, 2), transformer__vect_summary__max_features=32000, transformer__vect_summary__ngram_range=(1, 2);, score=nan total time=   2.4s
# [CV 4/5; 10/32] START classifier__estimator__C=1, classifier__estimator__penalty=l1, transformer__vect_reviewText__max_features=5000, transformer__vect_reviewText__ngram_range=(1, 2), transformer__vect_summary__max_features=32000, transformer__vect_summary__ngram_range=(1, 2)
# [CV 4/5; 10/32] END classifier__estimator__C=1, classifier__estimator__penalty=l1, transformer__vect_reviewText__max_features=5000, transformer__vect_reviewText__ngram_range=(1, 2), transformer__vect_summary__max_features=32000, transformer__vect_summary__ngram_range=(1, 2);, score=nan total time=   2.3s
# [CV 5/5; 10/32] START classifier__estimator__C=1, classifier__estimator__penalty=l1, transformer__vect_reviewText__max_features=5000, transformer__vect_reviewText__ngram_range=(1, 2), transformer__vect_summary__max_features=32000, transformer__vect_summary__ngram_range=(1, 2)
# [CV 5/5; 10/32] END classifier__estimator__C=1, classifier__estimator__penalty=l1, transformer__vect_reviewText__max_features=5000, transformer__vect_reviewText__ngram_range=(1, 2), transformer__vect_summary__max_features=32000, transformer__vect_summary__ngram_range=(1, 2);, score=nan total time=   2.2s
# [CV 1/5; 11/32] START classifier__estimator__C=1, classifier__estimator__penalty=l1, transformer__vect_reviewText__max_features=10000, transformer__vect_reviewText__ngram_range=(1, 2), transformer__vect_summary__max_features=10000, transformer__vect_summary__ngram_range=(1, 2)
# [CV 1/5; 11/32] END classifier__estimator__C=1, classifier__estimator__penalty=l1, transformer__vect_reviewText__max_features=10000, transformer__vect_reviewText__ngram_range=(1, 2), transformer__vect_summary__max_features=10000, transformer__vect_summary__ngram_range=(1, 2);, score=nan total time=   2.3s
# [CV 2/5; 11/32] START classifier__estimator__C=1, classifier__estimator__penalty=l1, transformer__vect_reviewText__max_features=10000, transformer__vect_reviewText__ngram_range=(1, 2), transformer__vect_summary__max_features=10000, transformer__vect_summary__ngram_range=(1, 2)
# [CV 2/5; 11/32] END classifier__estimator__C=1, classifier__estimator__penalty=l1, transformer__vect_reviewText__max_features=10000, transformer__vect_reviewText__ngram_range=(1, 2), transformer__vect_summary__max_features=10000, transformer__vect_summary__ngram_range=(1, 2);, score=nan total time=   2.0s
# [CV 3/5; 11/32] START classifier__estimator__C=1, classifier__estimator__penalty=l1, transformer__vect_reviewText__max_features=10000, transformer__vect_reviewText__ngram_range=(1, 2), transformer__vect_summary__max_features=10000, transformer__vect_summary__ngram_range=(1, 2)
# [CV 3/5; 11/32] END classifier__estimator__C=1, classifier__estimator__penalty=l1, transformer__vect_reviewText__max_features=10000, transformer__vect_reviewText__ngram_range=(1, 2), transformer__vect_summary__max_features=10000, transformer__vect_summary__ngram_range=(1, 2);, score=nan total time=   2.2s
# [CV 4/5; 11/32] START classifier__estimator__C=1, classifier__estimator__penalty=l1, transformer__vect_reviewText__max_features=10000, transformer__vect_reviewText__ngram_range=(1, 2), transformer__vect_summary__max_features=10000, transformer__vect_summary__ngram_range=(1, 2)
# [CV 4/5; 11/32] END classifier__estimator__C=1, classifier__estimator__penalty=l1, transformer__vect_reviewText__max_features=10000, transformer__vect_reviewText__ngram_range=(1, 2), transformer__vect_summary__max_features=10000, transformer__vect_summary__ngram_range=(1, 2);, score=nan total time=   2.1s
# [CV 5/5; 11/32] START classifier__estimator__C=1, classifier__estimator__penalty=l1, transformer__vect_reviewText__max_features=10000, transformer__vect_reviewText__ngram_range=(1, 2), transformer__vect_summary__max_features=10000, transformer__vect_summary__ngram_range=(1, 2)
# [CV 5/5; 11/32] END classifier__estimator__C=1, classifier__estimator__penalty=l1, transformer__vect_reviewText__max_features=10000, transformer__vect_reviewText__ngram_range=(1, 2), transformer__vect_summary__max_features=10000, transformer__vect_summary__ngram_range=(1, 2);, score=nan total time=   2.2s
# [CV 1/5; 12/32] START classifier__estimator__C=1, classifier__estimator__penalty=l1, transformer__vect_reviewText__max_features=10000, transformer__vect_reviewText__ngram_range=(1, 2), transformer__vect_summary__max_features=32000, transformer__vect_summary__ngram_range=(1, 2)
# [CV 1/5; 12/32] END classifier__estimator__C=1, classifier__estimator__penalty=l1, transformer__vect_reviewText__max_features=10000, transformer__vect_reviewText__ngram_range=(1, 2), transformer__vect_summary__max_features=32000, transformer__vect_summary__ngram_range=(1, 2);, score=nan total time=   2.2s
# [CV 2/5; 12/32] START classifier__estimator__C=1, classifier__estimator__penalty=l1, transformer__vect_reviewText__max_features=10000, transformer__vect_reviewText__ngram_range=(1, 2), transformer__vect_summary__max_features=32000, transformer__vect_summary__ngram_range=(1, 2)
# [CV 2/5; 12/32] END classifier__estimator__C=1, classifier__estimator__penalty=l1, transformer__vect_reviewText__max_features=10000, transformer__vect_reviewText__ngram_range=(1, 2), transformer__vect_summary__max_features=32000, transformer__vect_summary__ngram_range=(1, 2);, score=nan total time=   2.2s
# [CV 3/5; 12/32] START classifier__estimator__C=1, classifier__estimator__penalty=l1, transformer__vect_reviewText__max_features=10000, transformer__vect_reviewText__ngram_range=(1, 2), transformer__vect_summary__max_features=32000, transformer__vect_summary__ngram_range=(1, 2)
# [CV 3/5; 12/32] END classifier__estimator__C=1, classifier__estimator__penalty=l1, transformer__vect_reviewText__max_features=10000, transformer__vect_reviewText__ngram_range=(1, 2), transformer__vect_summary__max_features=32000, transformer__vect_summary__ngram_range=(1, 2);, score=nan total time=   2.1s
# [CV 4/5; 12/32] START classifier__estimator__C=1, classifier__estimator__penalty=l1, transformer__vect_reviewText__max_features=10000, transformer__vect_reviewText__ngram_range=(1, 2), transformer__vect_summary__max_features=32000, transformer__vect_summary__ngram_range=(1, 2)
# [CV 4/5; 12/32] END classifier__estimator__C=1, classifier__estimator__penalty=l1, transformer__vect_reviewText__max_features=10000, transformer__vect_reviewText__ngram_range=(1, 2), transformer__vect_summary__max_features=32000, transformer__vect_summary__ngram_range=(1, 2);, score=nan total time=   2.1s
# [CV 5/5; 12/32] START classifier__estimator__C=1, classifier__estimator__penalty=l1, transformer__vect_reviewText__max_features=10000, transformer__vect_reviewText__ngram_range=(1, 2), transformer__vect_summary__max_features=32000, transformer__vect_summary__ngram_range=(1, 2)
# [CV 5/5; 12/32] END classifier__estimator__C=1, classifier__estimator__penalty=l1, transformer__vect_reviewText__max_features=10000, transformer__vect_reviewText__ngram_range=(1, 2), transformer__vect_summary__max_features=32000, transformer__vect_summary__ngram_range=(1, 2);, score=nan total time=   2.2s
# [CV 1/5; 13/32] START classifier__estimator__C=1, classifier__estimator__penalty=l2, transformer__vect_reviewText__max_features=5000, transformer__vect_reviewText__ngram_range=(1, 2), transformer__vect_summary__max_features=10000, transformer__vect_summary__ngram_range=(1, 2)
# [CV 1/5; 13/32] END classifier__estimator__C=1, classifier__estimator__penalty=l2, transformer__vect_reviewText__max_features=5000, transformer__vect_reviewText__ngram_range=(1, 2), transformer__vect_summary__max_features=10000, transformer__vect_summary__ngram_range=(1, 2);, score=0.801 total time=   6.1s
# [CV 2/5; 13/32] START classifier__estimator__C=1, classifier__estimator__penalty=l2, transformer__vect_reviewText__max_features=5000, transformer__vect_reviewText__ngram_range=(1, 2), transformer__vect_summary__max_features=10000, transformer__vect_summary__ngram_range=(1, 2)
# [CV 2/5; 13/32] END classifier__estimator__C=1, classifier__estimator__penalty=l2, transformer__vect_reviewText__max_features=5000, transformer__vect_reviewText__ngram_range=(1, 2), transformer__vect_summary__max_features=10000, transformer__vect_summary__ngram_range=(1, 2);, score=0.785 total time=   5.6s
# [CV 3/5; 13/32] START classifier__estimator__C=1, classifier__estimator__penalty=l2, transformer__vect_reviewText__max_features=5000, transformer__vect_reviewText__ngram_range=(1, 2), transformer__vect_summary__max_features=10000, transformer__vect_summary__ngram_range=(1, 2)
# [CV 3/5; 13/32] END classifier__estimator__C=1, classifier__estimator__penalty=l2, transformer__vect_reviewText__max_features=5000, transformer__vect_reviewText__ngram_range=(1, 2), transformer__vect_summary__max_features=10000, transformer__vect_summary__ngram_range=(1, 2);, score=0.792 total time=   7.3s
# [CV 4/5; 13/32] START classifier__estimator__C=1, classifier__estimator__penalty=l2, transformer__vect_reviewText__max_features=5000, transformer__vect_reviewText__ngram_range=(1, 2), transformer__vect_summary__max_features=10000, transformer__vect_summary__ngram_range=(1, 2)
# [CV 4/5; 13/32] END classifier__estimator__C=1, classifier__estimator__penalty=l2, transformer__vect_reviewText__max_features=5000, transformer__vect_reviewText__ngram_range=(1, 2), transformer__vect_summary__max_features=10000, transformer__vect_summary__ngram_range=(1, 2);, score=0.806 total time=   7.6s
# [CV 5/5; 13/32] START classifier__estimator__C=1, classifier__estimator__penalty=l2, transformer__vect_reviewText__max_features=5000, transformer__vect_reviewText__ngram_range=(1, 2), transformer__vect_summary__max_features=10000, transformer__vect_summary__ngram_range=(1, 2)
# [CV 5/5; 13/32] END classifier__estimator__C=1, classifier__estimator__penalty=l2, transformer__vect_reviewText__max_features=5000, transformer__vect_reviewText__ngram_range=(1, 2), transformer__vect_summary__max_features=10000, transformer__vect_summary__ngram_range=(1, 2);, score=0.789 total time=   6.1s
# [CV 1/5; 14/32] START classifier__estimator__C=1, classifier__estimator__penalty=l2, transformer__vect_reviewText__max_features=5000, transformer__vect_reviewText__ngram_range=(1, 2), transformer__vect_summary__max_features=32000, transformer__vect_summary__ngram_range=(1, 2)
# [CV 1/5; 14/32] END classifier__estimator__C=1, classifier__estimator__penalty=l2, transformer__vect_reviewText__max_features=5000, transformer__vect_reviewText__ngram_range=(1, 2), transformer__vect_summary__max_features=32000, transformer__vect_summary__ngram_range=(1, 2);, score=0.809 total time=   6.5s
# [CV 2/5; 14/32] START classifier__estimator__C=1, classifier__estimator__penalty=l2, transformer__vect_reviewText__max_features=5000, transformer__vect_reviewText__ngram_range=(1, 2), transformer__vect_summary__max_features=32000, transformer__vect_summary__ngram_range=(1, 2)
# [CV 2/5; 14/32] END classifier__estimator__C=1, classifier__estimator__penalty=l2, transformer__vect_reviewText__max_features=5000, transformer__vect_reviewText__ngram_range=(1, 2), transformer__vect_summary__max_features=32000, transformer__vect_summary__ngram_range=(1, 2);, score=0.790 total time=   5.8s
# [CV 3/5; 14/32] START classifier__estimator__C=1, classifier__estimator__penalty=l2, transformer__vect_reviewText__max_features=5000, transformer__vect_reviewText__ngram_range=(1, 2), transformer__vect_summary__max_features=32000, transformer__vect_summary__ngram_range=(1, 2)
# [CV 3/5; 14/32] END classifier__estimator__C=1, classifier__estimator__penalty=l2, transformer__vect_reviewText__max_features=5000, transformer__vect_reviewText__ngram_range=(1, 2), transformer__vect_summary__max_features=32000, transformer__vect_summary__ngram_range=(1, 2);, score=0.796 total time=   5.6s
# [CV 4/5; 14/32] START classifier__estimator__C=1, classifier__estimator__penalty=l2, transformer__vect_reviewText__max_features=5000, transformer__vect_reviewText__ngram_range=(1, 2), transformer__vect_summary__max_features=32000, transformer__vect_summary__ngram_range=(1, 2)
# [CV 4/5; 14/32] END classifier__estimator__C=1, classifier__estimator__penalty=l2, transformer__vect_reviewText__max_features=5000, transformer__vect_reviewText__ngram_range=(1, 2), transformer__vect_summary__max_features=32000, transformer__vect_summary__ngram_range=(1, 2);, score=0.810 total time=   6.4s
# [CV 5/5; 14/32] START classifier__estimator__C=1, classifier__estimator__penalty=l2, transformer__vect_reviewText__max_features=5000, transformer__vect_reviewText__ngram_range=(1, 2), transformer__vect_summary__max_features=32000, transformer__vect_summary__ngram_range=(1, 2)
# [CV 5/5; 14/32] END classifier__estimator__C=1, classifier__estimator__penalty=l2, transformer__vect_reviewText__max_features=5000, transformer__vect_reviewText__ngram_range=(1, 2), transformer__vect_summary__max_features=32000, transformer__vect_summary__ngram_range=(1, 2);, score=0.789 total time=   6.5s
# [CV 1/5; 15/32] START classifier__estimator__C=1, classifier__estimator__penalty=l2, transformer__vect_reviewText__max_features=10000, transformer__vect_reviewText__ngram_range=(1, 2), transformer__vect_summary__max_features=10000, transformer__vect_summary__ngram_range=(1, 2)
# [CV 1/5; 15/32] END classifier__estimator__C=1, classifier__estimator__penalty=l2, transformer__vect_reviewText__max_features=10000, transformer__vect_reviewText__ngram_range=(1, 2), transformer__vect_summary__max_features=10000, transformer__vect_summary__ngram_range=(1, 2);, score=0.794 total time=   6.9s
# [CV 2/5; 15/32] START classifier__estimator__C=1, classifier__estimator__penalty=l2, transformer__vect_reviewText__max_features=10000, transformer__vect_reviewText__ngram_range=(1, 2), transformer__vect_summary__max_features=10000, transformer__vect_summary__ngram_range=(1, 2)
# [CV 2/5; 15/32] END classifier__estimator__C=1, classifier__estimator__penalty=l2, transformer__vect_reviewText__max_features=10000, transformer__vect_reviewText__ngram_range=(1, 2), transformer__vect_summary__max_features=10000, transformer__vect_summary__ngram_range=(1, 2);, score=0.784 total time=   6.5s
# [CV 3/5; 15/32] START classifier__estimator__C=1, classifier__estimator__penalty=l2, transformer__vect_reviewText__max_features=10000, transformer__vect_reviewText__ngram_range=(1, 2), transformer__vect_summary__max_features=10000, transformer__vect_summary__ngram_range=(1, 2)
# [CV 3/5; 15/32] END classifier__estimator__C=1, classifier__estimator__penalty=l2, transformer__vect_reviewText__max_features=10000, transformer__vect_reviewText__ngram_range=(1, 2), transformer__vect_summary__max_features=10000, transformer__vect_summary__ngram_range=(1, 2);, score=0.799 total time=   6.0s
# [CV 4/5; 15/32] START classifier__estimator__C=1, classifier__estimator__penalty=l2, transformer__vect_reviewText__max_features=10000, transformer__vect_reviewText__ngram_range=(1, 2), transformer__vect_summary__max_features=10000, transformer__vect_summary__ngram_range=(1, 2)
# [CV 4/5; 15/32] END classifier__estimator__C=1, classifier__estimator__penalty=l2, transformer__vect_reviewText__max_features=10000, transformer__vect_reviewText__ngram_range=(1, 2), transformer__vect_summary__max_features=10000, transformer__vect_summary__ngram_range=(1, 2);, score=0.809 total time=   5.6s
# [CV 5/5; 15/32] START classifier__estimator__C=1, classifier__estimator__penalty=l2, transformer__vect_reviewText__max_features=10000, transformer__vect_reviewText__ngram_range=(1, 2), transformer__vect_summary__max_features=10000, transformer__vect_summary__ngram_range=(1, 2)
# [CV 5/5; 15/32] END classifier__estimator__C=1, classifier__estimator__penalty=l2, transformer__vect_reviewText__max_features=10000, transformer__vect_reviewText__ngram_range=(1, 2), transformer__vect_summary__max_features=10000, transformer__vect_summary__ngram_range=(1, 2);, score=0.790 total time=   7.3s
# [CV 1/5; 16/32] START classifier__estimator__C=1, classifier__estimator__penalty=l2, transformer__vect_reviewText__max_features=10000, transformer__vect_reviewText__ngram_range=(1, 2), transformer__vect_summary__max_features=32000, transformer__vect_summary__ngram_range=(1, 2)
# [CV 1/5; 16/32] END classifier__estimator__C=1, classifier__estimator__penalty=l2, transformer__vect_reviewText__max_features=10000, transformer__vect_reviewText__ngram_range=(1, 2), transformer__vect_summary__max_features=32000, transformer__vect_summary__ngram_range=(1, 2);, score=0.808 total time=   9.0s
# [CV 2/5; 16/32] START classifier__estimator__C=1, classifier__estimator__penalty=l2, transformer__vect_reviewText__max_features=10000, transformer__vect_reviewText__ngram_range=(1, 2), transformer__vect_summary__max_features=32000, transformer__vect_summary__ngram_range=(1, 2)
# [CV 2/5; 16/32] END classifier__estimator__C=1, classifier__estimator__penalty=l2, transformer__vect_reviewText__max_features=10000, transformer__vect_reviewText__ngram_range=(1, 2), transformer__vect_summary__max_features=32000, transformer__vect_summary__ngram_range=(1, 2);, score=0.789 total time=   8.8s
# [CV 3/5; 16/32] START classifier__estimator__C=1, classifier__estimator__penalty=l2, transformer__vect_reviewText__max_features=10000, transformer__vect_reviewText__ngram_range=(1, 2), transformer__vect_summary__max_features=32000, transformer__vect_summary__ngram_range=(1, 2)
# [CV 3/5; 16/32] END classifier__estimator__C=1, classifier__estimator__penalty=l2, transformer__vect_reviewText__max_features=10000, transformer__vect_reviewText__ngram_range=(1, 2), transformer__vect_summary__max_features=32000, transformer__vect_summary__ngram_range=(1, 2);, score=0.804 total time=   7.5s
# [CV 4/5; 16/32] START classifier__estimator__C=1, classifier__estimator__penalty=l2, transformer__vect_reviewText__max_features=10000, transformer__vect_reviewText__ngram_range=(1, 2), transformer__vect_summary__max_features=32000, transformer__vect_summary__ngram_range=(1, 2)
# [CV 4/5; 16/32] END classifier__estimator__C=1, classifier__estimator__penalty=l2, transformer__vect_reviewText__max_features=10000, transformer__vect_reviewText__ngram_range=(1, 2), transformer__vect_summary__max_features=32000, transformer__vect_summary__ngram_range=(1, 2);, score=0.812 total time=   8.3s
# [CV 5/5; 16/32] START classifier__estimator__C=1, classifier__estimator__penalty=l2, transformer__vect_reviewText__max_features=10000, transformer__vect_reviewText__ngram_range=(1, 2), transformer__vect_summary__max_features=32000, transformer__vect_summary__ngram_range=(1, 2)
# [CV 5/5; 16/32] END classifier__estimator__C=1, classifier__estimator__penalty=l2, transformer__vect_reviewText__max_features=10000, transformer__vect_reviewText__ngram_range=(1, 2), transformer__vect_summary__max_features=32000, transformer__vect_summary__ngram_range=(1, 2);, score=0.789 total time=   8.1s
# [CV 1/5; 17/32] START classifier__estimator__C=0.1, classifier__estimator__penalty=l1, transformer__vect_reviewText__max_features=5000, transformer__vect_reviewText__ngram_range=(1, 2), transformer__vect_summary__max_features=10000, transformer__vect_summary__ngram_range=(1, 2)
# [CV 1/5; 17/32] END classifier__estimator__C=0.1, classifier__estimator__penalty=l1, transformer__vect_reviewText__max_features=5000, transformer__vect_reviewText__ngram_range=(1, 2), transformer__vect_summary__max_features=10000, transformer__vect_summary__ngram_range=(1, 2);, score=nan total time=   2.3s
# [CV 2/5; 17/32] START classifier__estimator__C=0.1, classifier__estimator__penalty=l1, transformer__vect_reviewText__max_features=5000, transformer__vect_reviewText__ngram_range=(1, 2), transformer__vect_summary__max_features=10000, transformer__vect_summary__ngram_range=(1, 2)
# ...
# [CV 2/5; 29/32] END classifier__estimator__C=0.01, classifier__estimator__penalty=l2, transformer__vect_reviewText__max_features=5000, transformer__vect_reviewText__ngram_range=(1, 2), transformer__vect_summary__max_features=10000, transformer__vect_summary__ngram_range=(1, 2);, score=0.781 total time=   2.6s
# [CV 3/5; 29/32] START classifier__estimator__C=0.01, classifier__estimator__penalty=l2, transformer__vect_reviewText__max_features=5000, transformer__vect_reviewText__ngram_range=(1, 2), transformer__vect_summary__max_features=10000, transformer__vect_summary__ngram_range=(1, 2)
# [CV 3/5; 29/32] END classifier__estimator__C=0.01, classifier__estimator__penalty=l2, transformer__vect_reviewText__max_features=5000, transformer__vect_reviewText__ngram_range=(1, 2), transformer__vect_summary__max_features=10000, transformer__vect_summary__ngram_range=(1, 2);, score=0.790 total time=   2.7s
# [CV 4/5; 29/32] START classifier__estimator__C=0.01, classifier__estimator__penalty=l2, transformer__vect_reviewText__max_features=5000, transformer__vect_reviewText__ngram_range=(1, 2), transformer__vect_summary__max_features=10000, transformer__vect_summary__ngram_range=(1, 2)
# [CV 4/5; 29/32] END classifier__estimator__C=0.01, classifier__estimator__penalty=l2, transformer__vect_reviewText__max_features=5000, transformer__vect_reviewText__ngram_range=(1, 2), transformer__vect_summary__max_features=10000, transformer__vect_summary__ngram_range=(1, 2);, score=0.807 total time=   2.7s
# [CV 5/5; 29/32] START classifier__estimator__C=0.01, classifier__estimator__penalty=l2, transformer__vect_reviewText__max_features=5000, transformer__vect_reviewText__ngram_range=(1, 2), transformer__vect_summary__max_features=10000, transformer__vect_summary__ngram_range=(1, 2)
# [CV 5/5; 29/32] END classifier__estimator__C=0.01, classifier__estimator__penalty=l2, transformer__vect_reviewText__max_features=5000, transformer__vect_reviewText__ngram_range=(1, 2), transformer__vect_summary__max_features=10000, transformer__vect_summary__ngram_range=(1, 2);, score=0.784 total time=   2.5s
# [CV 1/5; 30/32] START classifier__estimator__C=0.01, classifier__estimator__penalty=l2, transformer__vect_reviewText__max_features=5000, transformer__vect_reviewText__ngram_range=(1, 2), transformer__vect_summary__max_features=32000, transformer__vect_summary__ngram_range=(1, 2)
# [CV 1/5; 30/32] END classifier__estimator__C=0.01, classifier__estimator__penalty=l2, transformer__vect_reviewText__max_features=5000, transformer__vect_reviewText__ngram_range=(1, 2), transformer__vect_summary__max_features=32000, transformer__vect_summary__ngram_range=(1, 2);, score=0.791 total time=   2.6s
# [CV 2/5; 30/32] START classifier__estimator__C=0.01, classifier__estimator__penalty=l2, transformer__vect_reviewText__max_features=5000, transformer__vect_reviewText__ngram_range=(1, 2), transformer__vect_summary__max_features=32000, transformer__vect_summary__ngram_range=(1, 2)
# [CV 2/5; 30/32] END classifier__estimator__C=0.01, classifier__estimator__penalty=l2, transformer__vect_reviewText__max_features=5000, transformer__vect_reviewText__ngram_range=(1, 2), transformer__vect_summary__max_features=32000, transformer__vect_summary__ngram_range=(1, 2);, score=0.786 total time=   2.8s
# [CV 3/5; 30/32] START classifier__estimator__C=0.01, classifier__estimator__penalty=l2, transformer__vect_reviewText__max_features=5000, transformer__vect_reviewText__ngram_range=(1, 2), transformer__vect_summary__max_features=32000, transformer__vect_summary__ngram_range=(1, 2)
# [CV 3/5; 30/32] END classifier__estimator__C=0.01, classifier__estimator__penalty=l2, transformer__vect_reviewText__max_features=5000, transformer__vect_reviewText__ngram_range=(1, 2), transformer__vect_summary__max_features=32000, transformer__vect_summary__ngram_range=(1, 2);, score=0.790 total time=   2.5s
# [CV 4/5; 30/32] START classifier__estimator__C=0.01, classifier__estimator__penalty=l2, transformer__vect_reviewText__max_features=5000, transformer__vect_reviewText__ngram_range=(1, 2), transformer__vect_summary__max_features=32000, transformer__vect_summary__ngram_range=(1, 2)
# [CV 4/5; 30/32] END classifier__estimator__C=0.01, classifier__estimator__penalty=l2, transformer__vect_reviewText__max_features=5000, transformer__vect_reviewText__ngram_range=(1, 2), transformer__vect_summary__max_features=32000, transformer__vect_summary__ngram_range=(1, 2);, score=0.808 total time=   2.6s
# [CV 5/5; 30/32] START classifier__estimator__C=0.01, classifier__estimator__penalty=l2, transformer__vect_reviewText__max_features=5000, transformer__vect_reviewText__ngram_range=(1, 2), transformer__vect_summary__max_features=32000, transformer__vect_summary__ngram_range=(1, 2)
# [CV 5/5; 30/32] END classifier__estimator__C=0.01, classifier__estimator__penalty=l2, transformer__vect_reviewText__max_features=5000, transformer__vect_reviewText__ngram_range=(1, 2), transformer__vect_summary__max_features=32000, transformer__vect_summary__ngram_range=(1, 2);, score=0.782 total time=   2.5s
# [CV 1/5; 31/32] START classifier__estimator__C=0.01, classifier__estimator__penalty=l2, transformer__vect_reviewText__max_features=10000, transformer__vect_reviewText__ngram_range=(1, 2), transformer__vect_summary__max_features=10000, transformer__vect_summary__ngram_range=(1, 2)
# [CV 1/5; 31/32] END classifier__estimator__C=0.01, classifier__estimator__penalty=l2, transformer__vect_reviewText__max_features=10000, transformer__vect_reviewText__ngram_range=(1, 2), transformer__vect_summary__max_features=10000, transformer__vect_summary__ngram_range=(1, 2);, score=0.786 total time=   2.6s
# [CV 2/5; 31/32] START classifier__estimator__C=0.01, classifier__estimator__penalty=l2, transformer__vect_reviewText__max_features=10000, transformer__vect_reviewText__ngram_range=(1, 2), transformer__vect_summary__max_features=10000, transformer__vect_summary__ngram_range=(1, 2)
# [CV 2/5; 31/32] END classifier__estimator__C=0.01, classifier__estimator__penalty=l2, transformer__vect_reviewText__max_features=10000, transformer__vect_reviewText__ngram_range=(1, 2), transformer__vect_summary__max_features=10000, transformer__vect_summary__ngram_range=(1, 2);, score=0.779 total time=   2.6s
# [CV 3/5; 31/32] START classifier__estimator__C=0.01, classifier__estimator__penalty=l2, transformer__vect_reviewText__max_features=10000, transformer__vect_reviewText__ngram_range=(1, 2), transformer__vect_summary__max_features=10000, transformer__vect_summary__ngram_range=(1, 2)
# [CV 3/5; 31/32] END classifier__estimator__C=0.01, classifier__estimator__penalty=l2, transformer__vect_reviewText__max_features=10000, transformer__vect_reviewText__ngram_range=(1, 2), transformer__vect_summary__max_features=10000, transformer__vect_summary__ngram_range=(1, 2);, score=0.787 total time=   3.0s
# [CV 4/5; 31/32] START classifier__estimator__C=0.01, classifier__estimator__penalty=l2, transformer__vect_reviewText__max_features=10000, transformer__vect_reviewText__ngram_range=(1, 2), transformer__vect_summary__max_features=10000, transformer__vect_summary__ngram_range=(1, 2)
# [CV 4/5; 31/32] END classifier__estimator__C=0.01, classifier__estimator__penalty=l2, transformer__vect_reviewText__max_features=10000, transformer__vect_reviewText__ngram_range=(1, 2), transformer__vect_summary__max_features=10000, transformer__vect_summary__ngram_range=(1, 2);, score=0.804 total time=   3.6s
# [CV 5/5; 31/32] START classifier__estimator__C=0.01, classifier__estimator__penalty=l2, transformer__vect_reviewText__max_features=10000, transformer__vect_reviewText__ngram_range=(1, 2), transformer__vect_summary__max_features=10000, transformer__vect_summary__ngram_range=(1, 2)
# [CV 5/5; 31/32] END classifier__estimator__C=0.01, classifier__estimator__penalty=l2, transformer__vect_reviewText__max_features=10000, transformer__vect_reviewText__ngram_range=(1, 2), transformer__vect_summary__max_features=10000, transformer__vect_summary__ngram_range=(1, 2);, score=0.780 total time=   5.3s
# [CV 1/5; 32/32] START classifier__estimator__C=0.01, classifier__estimator__penalty=l2, transformer__vect_reviewText__max_features=10000, transformer__vect_reviewText__ngram_range=(1, 2), transformer__vect_summary__max_features=32000, transformer__vect_summary__ngram_range=(1, 2)
# [CV 1/5; 32/32] END classifier__estimator__C=0.01, classifier__estimator__penalty=l2, transformer__vect_reviewText__max_features=10000, transformer__vect_reviewText__ngram_range=(1, 2), transformer__vect_summary__max_features=32000, transformer__vect_summary__ngram_range=(1, 2);, score=0.789 total time=   4.7s
# [CV 2/5; 32/32] START classifier__estimator__C=0.01, classifier__estimator__penalty=l2, transformer__vect_reviewText__max_features=10000, transformer__vect_reviewText__ngram_range=(1, 2), transformer__vect_summary__max_features=32000, transformer__vect_summary__ngram_range=(1, 2)
# [CV 2/5; 32/32] END classifier__estimator__C=0.01, classifier__estimator__penalty=l2, transformer__vect_reviewText__max_features=10000, transformer__vect_reviewText__ngram_range=(1, 2), transformer__vect_summary__max_features=32000, transformer__vect_summary__ngram_range=(1, 2);, score=0.783 total time=   4.0s
# [CV 3/5; 32/32] START classifier__estimator__C=0.01, classifier__estimator__penalty=l2, transformer__vect_reviewText__max_features=10000, transformer__vect_reviewText__ngram_range=(1, 2), transformer__vect_summary__max_features=32000, transformer__vect_summary__ngram_range=(1, 2)
# [CV 3/5; 32/32] END classifier__estimator__C=0.01, classifier__estimator__penalty=l2, transformer__vect_reviewText__max_features=10000, transformer__vect_reviewText__ngram_range=(1, 2), transformer__vect_summary__max_features=32000, transformer__vect_summary__ngram_range=(1, 2);, score=0.789 total time=   3.1s
# [CV 4/5; 32/32] START classifier__estimator__C=0.01, classifier__estimator__penalty=l2, transformer__vect_reviewText__max_features=10000, transformer__vect_reviewText__ngram_range=(1, 2), transformer__vect_summary__max_features=32000, transformer__vect_summary__ngram_range=(1, 2)
# [CV 4/5; 32/32] END classifier__estimator__C=0.01, classifier__estimator__penalty=l2, transformer__vect_reviewText__max_features=10000, transformer__vect_reviewText__ngram_range=(1, 2), transformer__vect_summary__max_features=32000, transformer__vect_summary__ngram_range=(1, 2);, score=0.804 total time=   3.0s
# [CV 5/5; 32/32] START classifier__estimator__C=0.01, classifier__estimator__penalty=l2, transformer__vect_reviewText__max_features=10000, transformer__vect_reviewText__ngram_range=(1, 2), transformer__vect_summary__max_features=32000, transformer__vect_summary__ngram_range=(1, 2)
# [CV 5/5; 32/32] END classifier__estimator__C=0.01, classifier__estimator__penalty=l2, transformer__vect_reviewText__max_features=10000, transformer__vect_reviewText__ngram_range=(1, 2), transformer__vect_summary__max_features=32000, transformer__vect_summary__ngram_range=(1, 2);, score=0.780 total time=   2.7s
# /Users/shyamreddy/.pyenv/versions/3.9.2/envs/mlenv/lib/python3.9/site-packages/sklearn/model_selection/_validation.py:378: FitFailedWarning:
# 80 fits failed out of a total of 160.
# The score on these train-test partitions for these parameters will be set to nan.
# If these failures are not expected, you can try to debug them by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 80 fits failed with the following error:
# Traceback (most recent call last):
#   File "/Users/shyamreddy/.pyenv/versions/3.9.2/envs/mlenv/lib/python3.9/site-packages/sklearn/model_selection/_validation.py", line 686, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/Users/shyamreddy/.pyenv/versions/3.9.2/envs/mlenv/lib/python3.9/site-packages/sklearn/pipeline.py", line 405, in fit
#     self._final_estimator.fit(Xt, y, **fit_params_last_step)
#   File "/Users/shyamreddy/.pyenv/versions/3.9.2/envs/mlenv/lib/python3.9/site-packages/sklearn/calibration.py", line 395, in fit
#     self.calibrated_classifiers_ = parallel(
#   File "/Users/shyamreddy/.pyenv/versions/3.9.2/envs/mlenv/lib/python3.9/site-packages/sklearn/utils/parallel.py", line 63, in __call__
#     return super().__call__(iterable_with_config)
#   File "/Users/shyamreddy/.pyenv/versions/3.9.2/envs/mlenv/lib/python3.9/site-packages/joblib/parallel.py", line 1085, in __call__
#     if self.dispatch_one_batch(iterator):
#   File "/Users/shyamreddy/.pyenv/versions/3.9.2/envs/mlenv/lib/python3.9/site-packages/joblib/parallel.py", line 901, in dispatch_one_batch
#     self._dispatch(tasks)
#   File "/Users/shyamreddy/.pyenv/versions/3.9.2/envs/mlenv/lib/python3.9/site-packages/joblib/parallel.py", line 819, in _dispatch
#     job = self._backend.apply_async(batch, callback=cb)
#   File "/Users/shyamreddy/.pyenv/versions/3.9.2/envs/mlenv/lib/python3.9/site-packages/joblib/_parallel_backends.py", line 208, in apply_async
#     result = ImmediateResult(func)
#   File "/Users/shyamreddy/.pyenv/versions/3.9.2/envs/mlenv/lib/python3.9/site-packages/joblib/_parallel_backends.py", line 597, in __init__
#     self.results = batch()
#   File "/Users/shyamreddy/.pyenv/versions/3.9.2/envs/mlenv/lib/python3.9/site-packages/joblib/parallel.py", line 288, in __call__
#     return [func(*args, **kwargs)
#   File "/Users/shyamreddy/.pyenv/versions/3.9.2/envs/mlenv/lib/python3.9/site-packages/joblib/parallel.py", line 288, in <listcomp>
#     return [func(*args, **kwargs)
#   File "/Users/shyamreddy/.pyenv/versions/3.9.2/envs/mlenv/lib/python3.9/site-packages/sklearn/utils/parallel.py", line 123, in __call__
#     return self.function(*args, **kwargs)
#   File "/Users/shyamreddy/.pyenv/versions/3.9.2/envs/mlenv/lib/python3.9/site-packages/sklearn/calibration.py", line 577, in _fit_classifier_calibrator_pair
#     estimator.fit(X_train, y_train, **fit_params_train)
#   File "/Users/shyamreddy/.pyenv/versions/3.9.2/envs/mlenv/lib/python3.9/site-packages/sklearn/svm/_classes.py", line 274, in fit
#     self.coef_, self.intercept_, n_iter_ = _fit_liblinear(
#   File "/Users/shyamreddy/.pyenv/versions/3.9.2/envs/mlenv/lib/python3.9/site-packages/sklearn/svm/_base.py", line 1223, in _fit_liblinear
#     solver_type = _get_liblinear_solver_type(multi_class, penalty, loss, dual)
#   File "/Users/shyamreddy/.pyenv/versions/3.9.2/envs/mlenv/lib/python3.9/site-packages/sklearn/svm/_base.py", line 1062, in _get_liblinear_solver_type
#     raise ValueError(
# ValueError: Unsupported set of arguments: The combination of penalty='l1' and loss='squared_hinge' are not supported when dual=True, Parameters: penalty='l1', loss='squared_hinge', dual=True
#
#   warnings.warn(some_fits_failed_message, FitFailedWarning)
# /Users/shyamreddy/.pyenv/versions/3.9.2/envs/mlenv/lib/python3.9/site-packages/sklearn/model_selection/_search.py:952: UserWarning: One or more of the test scores are non-finite: [       nan        nan        nan        nan 0.7729519  0.78321129
#  0.77729853 0.78489979        nan        nan        nan        nan
#  0.79443138 0.79874286 0.79523805 0.80037105        nan        nan
#         nan        nan 0.81020155 0.81316082 0.80777574 0.81203205
#         nan        nan        nan        nan 0.78982468 0.79122516
#  0.78729283 0.78878806]
#   warnings.warn(
# -----------------------------------------------------------------------------------------------------------------------------------
# Best: 0.813161 using {'classifier__estimator__C': 0.1, 'classifier__estimator__penalty': 'l2', 'transformer__vect_reviewText__max_features': 5000, 'transformer__vect_reviewText__ngram_range': (1, 2), 'transformer__vect_summary__max_features': 32000, 'transformer__vect_summary__ngram_range': (1, 2)}
# f1_score:  0.821174767865851
# accuracy:  0.894998287084618
# auc score:  0.7994578501222113

# %% [markdown]
# # SGD Classifier

# %%
from sklearn.linear_model import SGDClassifier
from sklearn.calibration import CalibratedClassifierCV

pipe = Pipeline([
    ("transformer", ct),
    ("classifier", CalibratedClassifierCV(estimator = SGDClassifier()))
])

sgd_params = {
    "transformer__vect_summary__ngram_range": [(1, 2)],
    "transformer__vect_reviewText__ngram_range": [(1, 2)],
    "transformer__vect_summary__max_features": [10000, 32000],
    "transformer__vect_reviewText__max_features": [5000, 10000],
    "classifier__estimator__alpha": [0.001, 0.01, 0.1, 1],
    "classifier__estimator__loss": ['hinge', 'perceptron'],
}


# perform grid search cross-validation to find the best hyperparameters
grid_sgd = GridSearchCV(pipe, sgd_params, cv=5, scoring='f1_macro', verbose=10)

grid_sgd.fit(X_train, y_train)
print("-----------------------------------------------------------------------------------------------------------------------------------")
print("Best: %f using %s" % (grid_sgd.best_score_, grid_sgd.best_params_))

# predict
y_pred_sgd = grid_sgd.best_estimator_.predict(X_test)

# f1 score
fscore = f1_score(y_test, y_pred_sgd, average='macro')
print("f1_score: ", fscore)
f1_arr.append(fscore)

# accuracy
accur = accuracy_score(y_test, y_pred_sgd)
accuracy_arr.append(accur)
print("accuracy: ", accur)

# auc score
aucscore = roc_auc_score(y_test, y_pred_sgd)
print("auc score: ", aucscore)
auc_arr.append(aucscore)

# confusion matrix
cm = confusion_matrix(y_test, y_pred_sgd)
tn, fp, fn, tp = cm.ravel()
fpr = fp / (fp + tn)
tpr = tp / (tp + fn)
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues',
            xticklabels=['Predicted Negative', 'Predicted Positive'],
            yticklabels=['Actual Negative\nFPR={:.2f}'.format(fpr), 'Actual Positive\nTPR={:.2f}'.format(tpr)])
plt.title("Confusion Matrix")
plt.show()

# ROC curve
y_pred_prob_sgd = grid_sgd.best_estimator_.predict_proba(X_test)
fpr, tpr, threshold = roc_curve(y_test, y_pred_prob_sgd[:,1])
sns.lineplot(x=fpr, y=tpr,label="AUC="+str(aucscore))
plt.plot([0, 1], [0, 1], color='navy', lw=2, linestyle='--')
plt.xlabel("FPR")
plt.ylabel("TPR")
plt.title("ROC Curve")
plt.show()

model_arr.append("Stochastic Gradient classifier")
# Out:
# Fitting 5 folds for each of 32 candidates, totalling 160 fits
# [CV 1/5; 1/32] START classifier__estimator__alpha=0.001, classifier__estimator__loss=hinge, transformer__vect_reviewText__max_features=5000, transformer__vect_reviewText__ngram_range=(1, 2), transformer__vect_summary__max_features=10000, transformer__vect_summary__ngram_range=(1, 2)
# [CV 1/5; 1/32] END classifier__estimator__alpha=0.001, classifier__estimator__loss=hinge, transformer__vect_reviewText__max_features=5000, transformer__vect_reviewText__ngram_range=(1, 2), transformer__vect_summary__max_features=10000, transformer__vect_summary__ngram_range=(1, 2);, score=0.786 total time=   2.9s
# [CV 2/5; 1/32] START classifier__estimator__alpha=0.001, classifier__estimator__loss=hinge, transformer__vect_reviewText__max_features=5000, transformer__vect_reviewText__ngram_range=(1, 2), transformer__vect_summary__max_features=10000, transformer__vect_summary__ngram_range=(1, 2)
# [CV 2/5; 1/32] END classifier__estimator__alpha=0.001, classifier__estimator__loss=hinge, transformer__vect_reviewText__max_features=5000, transformer__vect_reviewText__ngram_range=(1, 2), transformer__vect_summary__max_features=10000, transformer__vect_summary__ngram_range=(1, 2);, score=0.776 total time=   2.6s
# [CV 3/5; 1/32] START classifier__estimator__alpha=0.001, classifier__estimator__loss=hinge, transformer__vect_reviewText__max_features=5000, transformer__vect_reviewText__ngram_range=(1, 2), transformer__vect_summary__max_features=10000, transformer__vect_summary__ngram_range=(1, 2)
# [CV 3/5; 1/32] END classifier__estimator__alpha=0.001, classifier__estimator__loss=hinge, transformer__vect_reviewText__max_features=5000, transformer__vect_reviewText__ngram_range=(1, 2), transformer__vect_summary__max_features=10000, transformer__vect_summary__ngram_range=(1, 2);, score=0.791 total time=   2.7s
# [CV 4/5; 1/32] START classifier__estimator__alpha=0.001, classifier__estimator__loss=hinge, transformer__vect_reviewText__max_features=5000, transformer__vect_reviewText__ngram_range=(1, 2), transformer__vect_summary__max_features=10000, transformer__vect_summary__ngram_range=(1, 2)
# [CV 4/5; 1/32] END classifier__estimator__alpha=0.001, classifier__estimator__loss=hinge, transformer__vect_reviewText__max_features=5000, transformer__vect_reviewText__ngram_range=(1, 2), transformer__vect_summary__max_features=10000, transformer__vect_summary__ngram_range=(1, 2);, score=0.806 total time=   2.7s
# [CV 5/5; 1/32] START classifier__estimator__alpha=0.001, classifier__estimator__loss=hinge, transformer__vect_reviewText__max_features=5000, transformer__vect_reviewText__ngram_range=(1, 2), transformer__vect_summary__max_features=10000, transformer__vect_summary__ngram_range=(1, 2)
# [CV 5/5; 1/32] END classifier__estimator__alpha=0.001, classifier__estimator__loss=hinge, transformer__vect_reviewText__max_features=5000, transformer__vect_reviewText__ngram_range=(1, 2), transformer__vect_summary__max_features=10000, transformer__vect_summary__ngram_range=(1, 2);, score=0.779 total time=   2.6s
# [CV 1/5; 2/32] START classifier__estimator__alpha=0.001, classifier__estimator__loss=hinge, transformer__vect_reviewText__max_features=5000, transformer__vect_reviewText__ngram_range=(1, 2), transformer__vect_summary__max_features=32000, transformer__vect_summary__ngram_range=(1, 2)
# [CV 1/5; 2/32] END classifier__estimator__alpha=0.001, classifier__estimator__loss=hinge, transformer__vect_reviewText__max_features=5000, transformer__vect_reviewText__ngram_range=(1, 2), transformer__vect_summary__max_features=32000, transformer__vect_summary__ngram_range=(1, 2);, score=0.787 total time=   2.7s
# [CV 2/5; 2/32] START classifier__estimator__alpha=0.001, classifier__estimator__loss=hinge, transformer__vect_reviewText__max_features=5000, transformer__vect_reviewText__ngram_range=(1, 2), transformer__vect_summary__max_features=32000, transformer__vect_summary__ngram_range=(1, 2)
# [CV 2/5; 2/32] END classifier__estimator__alpha=0.001, classifier__estimator__loss=hinge, transformer__vect_reviewText__max_features=5000, transformer__vect_reviewText__ngram_range=(1, 2), transformer__vect_summary__max_features=32000, transformer__vect_summary__ngram_range=(1, 2);, score=0.780 total time=   2.6s
# [CV 3/5; 2/32] START classifier__estimator__alpha=0.001, classifier__estimator__loss=hinge, transformer__vect_reviewText__max_features=5000, transformer__vect_reviewText__ngram_range=(1, 2), transformer__vect_summary__max_features=32000, transformer__vect_summary__ngram_range=(1, 2)
# [CV 3/5; 2/32] END classifier__estimator__alpha=0.001, classifier__estimator__loss=hinge, transformer__vect_reviewText__max_features=5000, transformer__vect_reviewText__ngram_range=(1, 2), transformer__vect_summary__max_features=32000, transformer__vect_summary__ngram_range=(1, 2);, score=0.793 total time=   2.7s
# [CV 4/5; 2/32] START classifier__estimator__alpha=0.001, classifier__estimator__loss=hinge, transformer__vect_reviewText__max_features=5000, transformer__vect_reviewText__ngram_range=(1, 2), transformer__vect_summary__max_features=32000, transformer__vect_summary__ngram_range=(1, 2)
# [CV 4/5; 2/32] END classifier__estimator__alpha=0.001, classifier__estimator__loss=hinge, transformer__vect_reviewText__max_features=5000, transformer__vect_reviewText__ngram_range=(1, 2), transformer__vect_summary__max_features=32000, transformer__vect_summary__ngram_range=(1, 2);, score=0.805 total time=   2.6s
# [CV 5/5; 2/32] START classifier__estimator__alpha=0.001, classifier__estimator__loss=hinge, transformer__vect_reviewText__max_features=5000, transformer__vect_reviewText__ngram_range=(1, 2), transformer__vect_summary__max_features=32000, transformer__vect_summary__ngram_range=(1, 2)
# [CV 5/5; 2/32] END classifier__estimator__alpha=0.001, classifier__estimator__loss=hinge, transformer__vect_reviewText__max_features=5000, transformer__vect_reviewText__ngram_range=(1, 2), transformer__vect_summary__max_features=32000, transformer__vect_summary__ngram_range=(1, 2);, score=0.779 total time=   2.6s
# [CV 1/5; 3/32] START classifier__estimator__alpha=0.001, classifier__estimator__loss=hinge, transformer__vect_reviewText__max_features=10000, transformer__vect_reviewText__ngram_range=(1, 2), transformer__vect_summary__max_features=10000, transformer__vect_summary__ngram_range=(1, 2)
# [CV 1/5; 3/32] END classifier__estimator__alpha=0.001, classifier__estimator__loss=hinge, transformer__vect_reviewText__max_features=10000, transformer__vect_reviewText__ngram_range=(1, 2), transformer__vect_summary__max_features=10000, transformer__vect_summary__ngram_range=(1, 2);, score=0.783 total time=   2.6s
# [CV 2/5; 3/32] START classifier__estimator__alpha=0.001, classifier__estimator__loss=hinge, transformer__vect_reviewText__max_features=10000, transformer__vect_reviewText__ngram_range=(1, 2), transformer__vect_summary__max_features=10000, transformer__vect_summary__ngram_range=(1, 2)
# [CV 2/5; 3/32] END classifier__estimator__alpha=0.001, classifier__estimator__loss=hinge, transformer__vect_reviewText__max_features=10000, transformer__vect_reviewText__ngram_range=(1, 2), transformer__vect_summary__max_features=10000, transformer__vect_summary__ngram_range=(1, 2);, score=0.772 total time=   2.7s
# [CV 3/5; 3/32] START classifier__estimator__alpha=0.001, classifier__estimator__loss=hinge, transformer__vect_reviewText__max_features=10000, transformer__vect_reviewText__ngram_range=(1, 2), transformer__vect_summary__max_features=10000, transformer__vect_summary__ngram_range=(1, 2)
# [CV 3/5; 3/32] END classifier__estimator__alpha=0.001, classifier__estimator__loss=hinge, transformer__vect_reviewText__max_features=10000, transformer__vect_reviewText__ngram_range=(1, 2), transformer__vect_summary__max_features=10000, transformer__vect_summary__ngram_range=(1, 2);, score=0.787 total time=   2.6s
# [CV 4/5; 3/32] START classifier__estimator__alpha=0.001, classifier__estimator__loss=hinge, transformer__vect_reviewText__max_features=10000, transformer__vect_reviewText__ngram_range=(1, 2), transformer__vect_summary__max_features=10000, transformer__vect_summary__ngram_range=(1, 2)
# [CV 4/5; 3/32] END classifier__estimator__alpha=0.001, classifier__estimator__loss=hinge, transformer__vect_reviewText__max_features=10000, transformer__vect_reviewText__ngram_range=(1, 2), transformer__vect_summary__max_features=10000, transformer__vect_summary__ngram_range=(1, 2);, score=0.800 total time=   3.3s
# [CV 5/5; 3/32] START classifier__estimator__alpha=0.001, classifier__estimator__loss=hinge, transformer__vect_reviewText__max_features=10000, transformer__vect_reviewText__ngram_range=(1, 2), transformer__vect_summary__max_features=10000, transformer__vect_summary__ngram_range=(1, 2)
# [CV 5/5; 3/32] END classifier__estimator__alpha=0.001, classifier__estimator__loss=hinge, transformer__vect_reviewText__max_features=10000, transformer__vect_reviewText__ngram_range=(1, 2), transformer__vect_summary__max_features=10000, transformer__vect_summary__ngram_range=(1, 2);, score=0.769 total time=   3.0s
# [CV 1/5; 4/32] START classifier__estimator__alpha=0.001, classifier__estimator__loss=hinge, transformer__vect_reviewText__max_features=10000, transformer__vect_reviewText__ngram_range=(1, 2), transformer__vect_summary__max_features=32000, transformer__vect_summary__ngram_range=(1, 2)
# [CV 1/5; 4/32] END classifier__estimator__alpha=0.001, classifier__estimator__loss=hinge, transformer__vect_reviewText__max_features=10000, transformer__vect_reviewText__ngram_range=(1, 2), transformer__vect_summary__max_features=32000, transformer__vect_summary__ngram_range=(1, 2);, score=0.785 total time=   3.5s
# [CV 2/5; 4/32] START classifier__estimator__alpha=0.001, classifier__estimator__loss=hinge, transformer__vect_reviewText__max_features=10000, transformer__vect_reviewText__ngram_range=(1, 2), transformer__vect_summary__max_features=32000, transformer__vect_summary__ngram_range=(1, 2)
# [CV 2/5; 4/32] END classifier__estimator__alpha=0.001, classifier__estimator__loss=hinge, transformer__vect_reviewText__max_features=10000, transformer__vect_reviewText__ngram_range=(1, 2), transformer__vect_summary__max_features=32000, transformer__vect_summary__ngram_range=(1, 2);, score=0.777 total time=   3.4s
# [CV 3/5; 4/32] START classifier__estimator__alpha=0.001, classifier__estimator__loss=hinge, transformer__vect_reviewText__max_features=10000, transformer__vect_reviewText__ngram_range=(1, 2), transformer__vect_summary__max_features=32000, transformer__vect_summary__ngram_range=(1, 2)
# [CV 3/5; 4/32] END classifier__estimator__alpha=0.001, classifier__estimator__loss=hinge, transformer__vect_reviewText__max_features=10000, transformer__vect_reviewText__ngram_range=(1, 2), transformer__vect_summary__max_features=32000, transformer__vect_summary__ngram_range=(1, 2);, score=0.793 total time=   3.5s
# [CV 4/5; 4/32] START classifier__estimator__alpha=0.001, classifier__estimator__loss=hinge, transformer__vect_reviewText__max_features=10000, transformer__vect_reviewText__ngram_range=(1, 2), transformer__vect_summary__max_features=32000, transformer__vect_summary__ngram_range=(1, 2)
# [CV 4/5; 4/32] END classifier__estimator__alpha=0.001, classifier__estimator__loss=hinge, transformer__vect_reviewText__max_features=10000, transformer__vect_reviewText__ngram_range=(1, 2), transformer__vect_summary__max_features=32000, transformer__vect_summary__ngram_range=(1, 2);, score=0.801 total time=   3.0s
# [CV 5/5; 4/32] START classifier__estimator__alpha=0.001, classifier__estimator__loss=hinge, transformer__vect_reviewText__max_features=10000, transformer__vect_reviewText__ngram_range=(1, 2), transformer__vect_summary__max_features=32000, transformer__vect_summary__ngram_range=(1, 2)
# [CV 5/5; 4/32] END classifier__estimator__alpha=0.001, classifier__estimator__loss=hinge, transformer__vect_reviewText__max_features=10000, transformer__vect_reviewText__ngram_range=(1, 2), transformer__vect_summary__max_features=32000, transformer__vect_summary__ngram_range=(1, 2);, score=0.777 total time=   2.7s
# [CV 1/5; 5/32] START classifier__estimator__alpha=0.001, classifier__estimator__loss=perceptron, transformer__vect_reviewText__max_features=5000, transformer__vect_reviewText__ngram_range=(1, 2), transformer__vect_summary__max_features=10000, transformer__vect_summary__ngram_range=(1, 2)
# [CV 1/5; 5/32] END classifier__estimator__alpha=0.001, classifier__estimator__loss=perceptron, transformer__vect_reviewText__max_features=5000, transformer__vect_reviewText__ngram_range=(1, 2), transformer__vect_summary__max_features=10000, transformer__vect_summary__ngram_range=(1, 2);, score=0.801 total time=   2.9s
# [CV 2/5; 5/32] START classifier__estimator__alpha=0.001, classifier__estimator__loss=perceptron, transformer__vect_reviewText__max_features=5000, transformer__vect_reviewText__ngram_range=(1, 2), transformer__vect_summary__max_features=10000, transformer__vect_summary__ngram_range=(1, 2)
# [CV 2/5; 5/32] END classifier__estimator__alpha=0.001, classifier__estimator__loss=perceptron, transformer__vect_reviewText__max_features=5000, transformer__vect_reviewText__ngram_range=(1, 2), transformer__vect_summary__max_features=10000, transformer__vect_summary__ngram_range=(1, 2);, score=0.783 total time=   2.9s
# [CV 3/5; 5/32] START classifier__estimator__alpha=0.001, classifier__estimator__loss=perceptron, transformer__vect_reviewText__max_features=5000, transformer__vect_reviewText__ngram_range=(1, 2), transformer__vect_summary__max_features=10000, transformer__vect_summary__ngram_range=(1, 2)
# [CV 3/5; 5/32] END classifier__estimator__alpha=0.001, classifier__estimator__loss=perceptron, transformer__vect_reviewText__max_features=5000, transformer__vect_reviewText__ngram_range=(1, 2), transformer__vect_summary__max_features=10000, transformer__vect_summary__ngram_range=(1, 2);, score=0.802 total time=   2.6s
# [CV 4/5; 5/32] START classifier__estimator__alpha=0.001, classifier__estimator__loss=perceptron, transformer__vect_reviewText__max_features=5000, transformer__vect_reviewText__ngram_range=(1, 2), transformer__vect_summary__max_features=10000, transformer__vect_summary__ngram_range=(1, 2)
# [CV 4/5; 5/32] END classifier__estimator__alpha=0.001, classifier__estimator__loss=perceptron, transformer__vect_reviewText__max_features=5000, transformer__vect_reviewText__ngram_range=(1, 2), transformer__vect_summary__max_features=10000, transformer__vect_summary__ngram_range=(1, 2);, score=0.810 total time=   2.6s
# [CV 5/5; 5/32] START classifier__estimator__alpha=0.001, classifier__estimator__loss=perceptron, transformer__vect_reviewText__max_features=5000, transformer__vect_reviewText__ngram_range=(1, 2), transformer__vect_summary__max_features=10000, transformer__vect_summary__ngram_range=(1, 2)
# [CV 5/5; 5/32] END classifier__estimator__alpha=0.001, classifier__estimator__loss=perceptron, transformer__vect_reviewText__max_features=5000, transformer__vect_reviewText__ngram_range=(1, 2), transformer__vect_summary__max_features=10000, transformer__vect_summary__ngram_range=(1, 2);, score=0.782 total time=   2.8s
# [CV 1/5; 6/32] START classifier__estimator__alpha=0.001, classifier__estimator__loss=perceptron, transformer__vect_reviewText__max_features=5000, transformer__vect_reviewText__ngram_range=(1, 2), transformer__vect_summary__max_features=32000, transformer__vect_summary__ngram_range=(1, 2)
# [CV 1/5; 6/32] END classifier__estimator__alpha=0.001, classifier__estimator__loss=perceptron, transformer__vect_reviewText__max_features=5000, transformer__vect_reviewText__ngram_range=(1, 2), transformer__vect_summary__max_features=32000, transformer__vect_summary__ngram_range=(1, 2);, score=0.804 total time=   2.9s
# [CV 2/5; 6/32] START classifier__estimator__alpha=0.001, classifier__estimator__loss=perceptron, transformer__vect_reviewText__max_features=5000, transformer__vect_reviewText__ngram_range=(1, 2), transformer__vect_summary__max_features=32000, transformer__vect_summary__ngram_range=(1, 2)
# [CV 2/5; 6/32] END classifier__estimator__alpha=0.001, classifier__estimator__loss=perceptron, transformer__vect_reviewText__max_features=5000, transformer__vect_reviewText__ngram_range=(1, 2), transformer__vect_summary__max_features=32000, transformer__vect_summary__ngram_range=(1, 2);, score=0.793 total time=   2.7s
# [CV 3/5; 6/32] START classifier__estimator__alpha=0.001, classifier__estimator__loss=perceptron, transformer__vect_reviewText__max_features=5000, transformer__vect_reviewText__ngram_range=(1, 2), transformer__vect_summary__max_features=32000, transformer__vect_summary__ngram_range=(1, 2)
# [CV 3/5; 6/32] END classifier__estimator__alpha=0.001, classifier__estimator__loss=perceptron, transformer__vect_reviewText__max_features=5000, transformer__vect_reviewText__ngram_range=(1, 2), transformer__vect_summary__max_features=32000, transformer__vect_summary__ngram_range=(1, 2);, score=0.782 total time=   2.9s
# [CV 4/5; 6/32] START classifier__estimator__alpha=0.001, classifier__estimator__loss=perceptron, transformer__vect_reviewText__max_features=5000, transformer__vect_reviewText__ngram_range=(1, 2), transformer__vect_summary__max_features=32000, transformer__vect_summary__ngram_range=(1, 2)
# [CV 4/5; 6/32] END classifier__estimator__alpha=0.001, classifier__estimator__loss=perceptron, transformer__vect_reviewText__max_features=5000, transformer__vect_reviewText__ngram_range=(1, 2), transformer__vect_summary__max_features=32000, transformer__vect_summary__ngram_range=(1, 2);, score=0.817 total time=   2.9s
# [CV 5/5; 6/32] START classifier__estimator__alpha=0.001, classifier__estimator__loss=perceptron, transformer__vect_reviewText__max_features=5000, transformer__vect_reviewText__ngram_range=(1, 2), transformer__vect_summary__max_features=32000, transformer__vect_summary__ngram_range=(1, 2)
# [CV 5/5; 6/32] END classifier__estimator__alpha=0.001, classifier__estimator__loss=perceptron, transformer__vect_reviewText__max_features=5000, transformer__vect_reviewText__ngram_range=(1, 2), transformer__vect_summary__max_features=32000, transformer__vect_summary__ngram_range=(1, 2);, score=0.790 total time=   3.6s
# [CV 1/5; 7/32] START classifier__estimator__alpha=0.001, classifier__estimator__loss=perceptron, transformer__vect_reviewText__max_features=10000, transformer__vect_reviewText__ngram_range=(1, 2), transformer__vect_summary__max_features=10000, transformer__vect_summary__ngram_range=(1, 2)
# [CV 1/5; 7/32] END classifier__estimator__alpha=0.001, classifier__estimator__loss=perceptron, transformer__vect_reviewText__max_features=10000, transformer__vect_reviewText__ngram_range=(1, 2), transformer__vect_summary__max_features=10000, transformer__vect_summary__ngram_range=(1, 2);, score=0.797 total time=   2.8s
# [CV 2/5; 7/32] START classifier__estimator__alpha=0.001, classifier__estimator__loss=perceptron, transformer__vect_reviewText__max_features=10000, transformer__vect_reviewText__ngram_range=(1, 2), transformer__vect_summary__max_features=10000, transformer__vect_summary__ngram_range=(1, 2)
# [CV 2/5; 7/32] END classifier__estimator__alpha=0.001, classifier__estimator__loss=perceptron, transformer__vect_reviewText__max_features=10000, transformer__vect_reviewText__ngram_range=(1, 2), transformer__vect_summary__max_features=10000, transformer__vect_summary__ngram_range=(1, 2);, score=0.795 total time=   2.7s
# [CV 3/5; 7/32] START classifier__estimator__alpha=0.001, classifier__estimator__loss=perceptron, transformer__vect_reviewText__max_features=10000, transformer__vect_reviewText__ngram_range=(1, 2), transformer__vect_summary__max_features=10000, transformer__vect_summary__ngram_range=(1, 2)
# [CV 3/5; 7/32] END classifier__estimator__alpha=0.001, classifier__estimator__loss=perceptron, transformer__vect_reviewText__max_features=10000, transformer__vect_reviewText__ngram_range=(1, 2), transformer__vect_summary__max_features=10000, transformer__vect_summary__ngram_range=(1, 2);, score=0.798 total time=   2.6s
# [CV 4/5; 7/32] START classifier__estimator__alpha=0.001, classifier__estimator__loss=perceptron, transformer__vect_reviewText__max_features=10000, transformer__vect_reviewText__ngram_range=(1, 2), transformer__vect_summary__max_features=10000, transformer__vect_summary__ngram_range=(1, 2)
# [CV 4/5; 7/32] END classifier__estimator__alpha=0.001, classifier__estimator__loss=perceptron, transformer__vect_reviewText__max_features=10000, transformer__vect_reviewText__ngram_range=(1, 2), transformer__vect_summary__max_features=10000, transformer__vect_summary__ngram_range=(1, 2);, score=0.809 total time=   2.6s
# [CV 5/5; 7/32] START classifier__estimator__alpha=0.001, classifier__estimator__loss=perceptron, transformer__vect_reviewText__max_features=10000, transformer__vect_reviewText__ngram_range=(1, 2), transformer__vect_summary__max_features=10000, transformer__vect_summary__ngram_range=(1, 2)
# [CV 5/5; 7/32] END classifier__estimator__alpha=0.001, classifier__estimator__loss=perceptron, transformer__vect_reviewText__max_features=10000, transformer__vect_reviewText__ngram_range=(1, 2), transformer__vect_summary__max_features=10000, transformer__vect_summary__ngram_range=(1, 2);, score=0.789 total time=   2.5s
# [CV 1/5; 8/32] START classifier__estimator__alpha=0.001, classifier__estimator__loss=perceptron, transformer__vect_reviewText__max_features=10000, transformer__vect_reviewText__ngram_range=(1, 2), transformer__vect_summary__max_features=32000, transformer__vect_summary__ngram_range=(1, 2)
# [CV 1/5; 8/32] END classifier__estimator__alpha=0.001, classifier__estimator__loss=perceptron, transformer__vect_reviewText__max_features=10000, transformer__vect_reviewText__ngram_range=(1, 2), transformer__vect_summary__max_features=32000, transformer__vect_summary__ngram_range=(1, 2);, score=0.802 total time=   2.5s
# [CV 2/5; 8/32] START classifier__estimator__alpha=0.001, classifier__estimator__loss=perceptron, transformer__vect_reviewText__max_features=10000, transformer__vect_reviewText__ngram_range=(1, 2), transformer__vect_summary__max_features=32000, transformer__vect_summary__ngram_range=(1, 2)
# [CV 2/5; 8/32] END classifier__estimator__alpha=0.001, classifier__estimator__loss=perceptron, transformer__vect_reviewText__max_features=10000, transformer__vect_reviewText__ngram_range=(1, 2), transformer__vect_summary__max_features=32000, transformer__vect_summary__ngram_range=(1, 2);, score=0.789 total time=   2.5s
# [CV 3/5; 8/32] START classifier__estimator__alpha=0.001, classifier__estimator__loss=perceptron, transformer__vect_reviewText__max_features=10000, transformer__vect_reviewText__ngram_range=(1, 2), transformer__vect_summary__max_features=32000, transformer__vect_summary__ngram_range=(1, 2)
# [CV 3/5; 8/32] END classifier__estimator__alpha=0.001, classifier__estimator__loss=perceptron, transformer__vect_reviewText__max_features=10000, transformer__vect_reviewText__ngram_range=(1, 2), transformer__vect_summary__max_features=32000, transformer__vect_summary__ngram_range=(1, 2);, score=0.791 total time=   2.6s
# [CV 4/5; 8/32] START classifier__estimator__alpha=0.001, classifier__estimator__loss=perceptron, transformer__vect_reviewText__max_features=10000, transformer__vect_reviewText__ngram_range=(1, 2), transformer__vect_summary__max_features=32000, transformer__vect_summary__ngram_range=(1, 2)
# [CV 4/5; 8/32] END classifier__estimator__alpha=0.001, classifier__estimator__loss=perceptron, transformer__vect_reviewText__max_features=10000, transformer__vect_reviewText__ngram_range=(1, 2), transformer__vect_summary__max_features=32000, transformer__vect_summary__ngram_range=(1, 2);, score=0.817 total time=   2.5s
# [CV 5/5; 8/32] START classifier__estimator__alpha=0.001, classifier__estimator__loss=perceptron, transformer__vect_reviewText__max_features=10000, transformer__vect_reviewText__ngram_range=(1, 2), transformer__vect_summary__max_features=32000, transformer__vect_summary__ngram_range=(1, 2)
# [CV 5/5; 8/32] END classifier__estimator__alpha=0.001, classifier__estimator__loss=perceptron, transformer__vect_reviewText__max_features=10000, transformer__vect_reviewText__ngram_range=(1, 2), transformer__vect_summary__max_features=32000, transformer__vect_summary__ngram_range=(1, 2);, score=0.791 total time=   2.5s
# [CV 1/5; 9/32] START classifier__estimator__alpha=0.01, classifier__estimator__loss=hinge, transformer__vect_reviewText__max_features=5000, transformer__vect_reviewText__ngram_range=(1, 2), transformer__vect_summary__max_features=10000, transformer__vect_summary__ngram_range=(1, 2)
# [CV 1/5; 9/32] END classifier__estimator__alpha=0.01, classifier__estimator__loss=hinge, transformer__vect_reviewText__max_features=5000, transformer__vect_reviewText__ngram_range=(1, 2), transformer__vect_summary__max_features=10000, transformer__vect_summary__ngram_range=(1, 2);, score=0.654 total time=   2.4s
# [CV 2/5; 9/32] START classifier__estimator__alpha=0.01, classifier__estimator__loss=hinge, transformer__vect_reviewText__max_features=5000, transformer__vect_reviewText__ngram_range=(1, 2), transformer__vect_summary__max_features=10000, transformer__vect_summary__ngram_range=(1, 2)
# [CV 2/5; 9/32] END classifier__estimator__alpha=0.01, classifier__estimator__loss=hinge, transformer__vect_reviewText__max_features=5000, transformer__vect_reviewText__ngram_range=(1, 2), transformer__vect_summary__max_features=10000, transformer__vect_summary__ngram_range=(1, 2);, score=0.640 total time=   2.5s
# [CV 3/5; 9/32] START classifier__estimator__alpha=0.01, classifier__estimator__loss=hinge, transformer__vect_reviewText__max_features=5000, transformer__vect_reviewText__ngram_range=(1, 2), transformer__vect_summary__max_features=10000, transformer__vect_summary__ngram_range=(1, 2)
# [CV 3/5; 9/32] END classifier__estimator__alpha=0.01, classifier__estimator__loss=hinge, transformer__vect_reviewText__max_features=5000, transformer__vect_reviewText__ngram_range=(1, 2), transformer__vect_summary__max_features=10000, transformer__vect_summary__ngram_range=(1, 2);, score=0.660 total time=   2.5s
# [CV 4/5; 9/32] START classifier__estimator__alpha=0.01, classifier__estimator__loss=hinge, transformer__vect_reviewText__max_features=5000, transformer__vect_reviewText__ngram_range=(1, 2), transformer__vect_summary__max_features=10000, transformer__vect_summary__ngram_range=(1, 2)
# [CV 4/5; 9/32] END classifier__estimator__alpha=0.01, classifier__estimator__loss=hinge, transformer__vect_reviewText__max_features=5000, transformer__vect_reviewText__ngram_range=(1, 2), transformer__vect_summary__max_features=10000, transformer__vect_summary__ngram_range=(1, 2);, score=0.656 total time=   2.5s
# [CV 5/5; 9/32] START classifier__estimator__alpha=0.01, classifier__estimator__loss=hinge, transformer__vect_reviewText__max_features=5000, transformer__vect_reviewText__ngram_range=(1, 2), transformer__vect_summary__max_features=10000, transformer__vect_summary__ngram_range=(1, 2)
# [CV 5/5; 9/32] END classifier__estimator__alpha=0.01, classifier__estimator__loss=hinge, transformer__vect_reviewText__max_features=5000, transformer__vect_reviewText__ngram_range=(1, 2), transformer__vect_summary__max_features=10000, transformer__vect_summary__ngram_range=(1, 2);, score=0.647 total time=   2.5s
# [CV 1/5; 10/32] START classifier__estimator__alpha=0.01, classifier__estimator__loss=hinge, transformer__vect_reviewText__max_features=5000, transformer__vect_reviewText__ngram_range=(1, 2), transformer__vect_summary__max_features=32000, transformer__vect_summary__ngram_range=(1, 2)
# [CV 1/5; 10/32] END classifier__estimator__alpha=0.01, classifier__estimator__loss=hinge, transformer__vect_reviewText__max_features=5000, transformer__vect_reviewText__ngram_range=(1, 2), transformer__vect_summary__max_features=32000, transformer__vect_summary__ngram_range=(1, 2);, score=0.655 total time=   2.6s
# [CV 2/5; 10/32] START classifier__estimator__alpha=0.01, classifier__estimator__loss=hinge, transformer__vect_reviewText__max_features=5000, transformer__vect_reviewText__ngram_range=(1, 2), transformer__vect_summary__max_features=32000, transformer__vect_summary__ngram_range=(1, 2)
# [CV 2/5; 10/32] END classifier__estimator__alpha=0.01, classifier__estimator__loss=hinge, transformer__vect_reviewText__max_features=5000, transformer__vect_reviewText__ngram_range=(1, 2), transformer__vect_summary__max_features=32000, transformer__vect_summary__ngram_range=(1, 2);, score=0.640 total time=   2.6s
# [CV 3/5; 10/32] START classifier__estimator__alpha=0.01, classifier__estimator__loss=hinge, transformer__vect_reviewText__max_features=5000, transformer__vect_reviewText__ngram_range=(1, 2), transformer__vect_summary__max_features=32000, transformer__vect_summary__ngram_range=(1, 2)
# [CV 3/5; 10/32] END classifier__estimator__alpha=0.01, classifier__estimator__loss=hinge, transformer__vect_reviewText__max_features=5000, transformer__vect_reviewText__ngram_range=(1, 2), transformer__vect_summary__max_features=32000, transformer__vect_summary__ngram_range=(1, 2);, score=0.662 total time=   2.5s
# [CV 4/5; 10/32] START classifier__estimator__alpha=0.01, classifier__estimator__loss=hinge, transformer__vect_reviewText__max_features=5000, transformer__vect_reviewText__ngram_range=(1, 2), transformer__vect_summary__max_features=32000, transformer__vect_summary__ngram_range=(1, 2)
# [CV 4/5; 10/32] END classifier__estimator__alpha=0.01, classifier__estimator__loss=hinge, transformer__vect_reviewText__max_features=5000, transformer__vect_reviewText__ngram_range=(1, 2), transformer__vect_summary__max_features=32000, transformer__vect_summary__ngram_range=(1, 2);, score=0.655 total time=   2.5s
# [CV 5/5; 10/32] START classifier__estimator__alpha=0.01, classifier__estimator__loss=hinge, transformer__vect_reviewText__max_features=5000, transformer__vect_reviewText__ngram_range=(1, 2), transformer__vect_summary__max_features=32000, transformer__vect_summary__ngram_range=(1, 2)
# [CV 5/5; 10/32] END classifier__estimator__alpha=0.01, classifier__estimator__loss=hinge, transformer__vect_reviewText__max_features=5000, transformer__vect_reviewText__ngram_range=(1, 2), transformer__vect_summary__max_features=32000, transformer__vect_summary__ngram_range=(1, 2);, score=0.648 total time=   2.5s
# [CV 1/5; 11/32] START classifier__estimator__alpha=0.01, classifier__estimator__loss=hinge, transformer__vect_reviewText__max_features=10000, transformer__vect_reviewText__ngram_range=(1, 2), transformer__vect_summary__max_features=10000, transformer__vect_summary__ngram_range=(1, 2)
# [CV 1/5; 11/32] END classifier__estimator__alpha=0.01, classifier__estimator__loss=hinge, transformer__vect_reviewText__max_features=10000, transformer__vect_reviewText__ngram_range=(1, 2), transformer__vect_summary__max_features=10000, transformer__vect_summary__ngram_range=(1, 2);, score=0.654 total time=   2.5s
# [CV 2/5; 11/32] START classifier__estimator__alpha=0.01, classifier__estimator__loss=hinge, transformer__vect_reviewText__max_features=10000, transformer__vect_reviewText__ngram_range=(1, 2), transformer__vect_summary__max_features=10000, transformer__vect_summary__ngram_range=(1, 2)
# [CV 2/5; 11/32] END classifier__estimator__alpha=0.01, classifier__estimator__loss=hinge, transformer__vect_reviewText__max_features=10000, transformer__vect_reviewText__ngram_range=(1, 2), transformer__vect_summary__max_features=10000, transformer__vect_summary__ngram_range=(1, 2);, score=0.641 total time=   2.5s
# [CV 3/5; 11/32] START classifier__estimator__alpha=0.01, classifier__estimator__loss=hinge, transformer__vect_reviewText__max_features=10000, transformer__vect_reviewText__ngram_range=(1, 2), transformer__vect_summary__max_features=10000, transformer__vect_summary__ngram_range=(1, 2)
# [CV 3/5; 11/32] END classifier__estimator__alpha=0.01, classifier__estimator__loss=hinge, transformer__vect_reviewText__max_features=10000, transformer__vect_reviewText__ngram_range=(1, 2), transformer__vect_summary__max_features=10000, transformer__vect_summary__ngram_range=(1, 2);, score=0.662 total time=   2.5s
# [CV 4/5; 11/32] START classifier__estimator__alpha=0.01, classifier__estimator__loss=hinge, transformer__vect_reviewText__max_features=10000, transformer__vect_reviewText__ngram_range=(1, 2), transformer__vect_summary__max_features=10000, transformer__vect_summary__ngram_range=(1, 2)
# [CV 4/5; 11/32] END classifier__estimator__alpha=0.01, classifier__estimator__loss=hinge, transformer__vect_reviewText__max_features=10000, transformer__vect_reviewText__ngram_range=(1, 2), transformer__vect_summary__max_features=10000, transformer__vect_summary__ngram_range=(1, 2);, score=0.657 total time=   2.5s
# [CV 5/5; 11/32] START classifier__estimator__alpha=0.01, classifier__estimator__loss=hinge, transformer__vect_reviewText__max_features=10000, transformer__vect_reviewText__ngram_range=(1, 2), transformer__vect_summary__max_features=10000, transformer__vect_summary__ngram_range=(1, 2)
# [CV 5/5; 11/32] END classifier__estimator__alpha=0.01, classifier__estimator__loss=hinge, transformer__vect_reviewText__max_features=10000, transformer__vect_reviewText__ngram_range=(1, 2), transformer__vect_summary__max_features=10000, transformer__vect_summary__ngram_range=(1, 2);, score=0.649 total time=   2.6s
# [CV 1/5; 12/32] START classifier__estimator__alpha=0.01, classifier__estimator__loss=hinge, transformer__vect_reviewText__max_features=10000, transformer__vect_reviewText__ngram_range=(1, 2), transformer__vect_summary__max_features=32000, transformer__vect_summary__ngram_range=(1, 2)
# [CV 1/5; 12/32] END classifier__estimator__alpha=0.01, classifier__estimator__loss=hinge, transformer__vect_reviewText__max_features=10000, transformer__vect_reviewText__ngram_range=(1, 2), transformer__vect_summary__max_features=32000, transformer__vect_summary__ngram_range=(1, 2);, score=0.657 total time=   2.7s
# [CV 2/5; 12/32] START classifier__estimator__alpha=0.01, classifier__estimator__loss=hinge, transformer__vect_reviewText__max_features=10000, transformer__vect_reviewText__ngram_range=(1, 2), transformer__vect_summary__max_features=32000, transformer__vect_summary__ngram_range=(1, 2)
# [CV 2/5; 12/32] END classifier__estimator__alpha=0.01, classifier__estimator__loss=hinge, transformer__vect_reviewText__max_features=10000, transformer__vect_reviewText__ngram_range=(1, 2), transformer__vect_summary__max_features=32000, transformer__vect_summary__ngram_range=(1, 2);, score=0.640 total time=   3.2s
# [CV 3/5; 12/32] START classifier__estimator__alpha=0.01, classifier__estimator__loss=hinge, transformer__vect_reviewText__max_features=10000, transformer__vect_reviewText__ngram_range=(1, 2), transformer__vect_summary__max_features=32000, transformer__vect_summary__ngram_range=(1, 2)
# [CV 3/5; 12/32] END classifier__estimator__alpha=0.01, classifier__estimator__loss=hinge, transformer__vect_reviewText__max_features=10000, transformer__vect_reviewText__ngram_range=(1, 2), transformer__vect_summary__max_features=32000, transformer__vect_summary__ngram_range=(1, 2);, score=0.664 total time=   3.4s
# [CV 4/5; 12/32] START classifier__estimator__alpha=0.01, classifier__estimator__loss=hinge, transformer__vect_reviewText__max_features=10000, transformer__vect_reviewText__ngram_range=(1, 2), transformer__vect_summary__max_features=32000, transformer__vect_summary__ngram_range=(1, 2)
# [CV 4/5; 12/32] END classifier__estimator__alpha=0.01, classifier__estimator__loss=hinge, transformer__vect_reviewText__max_features=10000, transformer__vect_reviewText__ngram_range=(1, 2), transformer__vect_summary__max_features=32000, transformer__vect_summary__ngram_range=(1, 2);, score=0.657 total time=   3.0s
# [CV 5/5; 12/32] START classifier__estimator__alpha=0.01, classifier__estimator__loss=hinge, transformer__vect_reviewText__max_features=10000, transformer__vect_reviewText__ngram_range=(1, 2), transformer__vect_summary__max_features=32000, transformer__vect_summary__ngram_range=(1, 2)
# [CV 5/5; 12/32] END classifier__estimator__alpha=0.01, classifier__estimator__loss=hinge, transformer__vect_reviewText__max_features=10000, transformer__vect_reviewText__ngram_range=(1, 2), transformer__vect_summary__max_features=32000, transformer__vect_summary__ngram_range=(1, 2);, score=0.650 total time=   2.8s
# [CV 1/5; 13/32] START classifier__estimator__alpha=0.01, classifier__estimator__loss=perceptron, transformer__vect_reviewText__max_features=5000, transformer__vect_reviewText__ngram_range=(1, 2), transformer__vect_summary__max_features=10000, transformer__vect_summary__ngram_range=(1, 2)
# [CV 1/5; 13/32] END classifier__estimator__alpha=0.01, classifier__estimator__loss=perceptron, transformer__vect_reviewText__max_features=5000, transformer__vect_reviewText__ngram_range=(1, 2), transformer__vect_summary__max_features=10000, transformer__vect_summary__ngram_range=(1, 2);, score=0.796 total time=   2.6s
# [CV 2/5; 13/32] START classifier__estimator__alpha=0.01, classifier__estimator__loss=perceptron, transformer__vect_reviewText__max_features=5000, transformer__vect_reviewText__ngram_range=(1, 2), transformer__vect_summary__max_features=10000, transformer__vect_summary__ngram_range=(1, 2)
# [CV 2/5; 13/32] END classifier__estimator__alpha=0.01, classifier__estimator__loss=perceptron, transformer__vect_reviewText__max_features=5000, transformer__vect_reviewText__ngram_range=(1, 2), transformer__vect_summary__max_features=10000, transformer__vect_summary__ngram_range=(1, 2);, score=0.776 total time=   2.6s
# [CV 3/5; 13/32] START classifier__estimator__alpha=0.01, classifier__estimator__loss=perceptron, transformer__vect_reviewText__max_features=5000, transformer__vect_reviewText__ngram_range=(1, 2), transformer__vect_summary__max_features=10000, transformer__vect_summary__ngram_range=(1, 2)
# [CV 3/5; 13/32] END classifier__estimator__alpha=0.01, classifier__estimator__loss=perceptron, transformer__vect_reviewText__max_features=5000, transformer__vect_reviewText__ngram_range=(1, 2), transformer__vect_summary__max_features=10000, transformer__vect_summary__ngram_range=(1, 2);, score=0.787 total time=   2.6s
# [CV 4/5; 13/32] START classifier__estimator__alpha=0.01, classifier__estimator__loss=perceptron, transformer__vect_reviewText__max_features=5000, transformer__vect_reviewText__ngram_range=(1, 2), transformer__vect_summary__max_features=10000, transformer__vect_summary__ngram_range=(1, 2)
# [CV 4/5; 13/32] END classifier__estimator__alpha=0.01, classifier__estimator__loss=perceptron, transformer__vect_reviewText__max_features=5000, transformer__vect_reviewText__ngram_range=(1, 2), transformer__vect_summary__max_features=10000, transformer__vect_summary__ngram_range=(1, 2);, score=0.812 total time=   2.6s
# [CV 5/5; 13/32] START classifier__estimator__alpha=0.01, classifier__estimator__loss=perceptron, transformer__vect_reviewText__max_features=5000, transformer__vect_reviewText__ngram_range=(1, 2), transformer__vect_summary__max_features=10000, transformer__vect_summary__ngram_range=(1, 2)
# [CV 5/5; 13/32] END classifier__estimator__alpha=0.01, classifier__estimator__loss=perceptron, transformer__vect_reviewText__max_features=5000, transformer__vect_reviewText__ngram_range=(1, 2), transformer__vect_summary__max_features=10000, transformer__vect_summary__ngram_range=(1, 2);, score=0.772 total time=   2.6s
# [CV 1/5; 14/32] START classifier__estimator__alpha=0.01, classifier__estimator__loss=perceptron, transformer__vect_reviewText__max_features=5000, transformer__vect_reviewText__ngram_range=(1, 2), transformer__vect_summary__max_features=32000, transformer__vect_summary__ngram_range=(1, 2)
# [CV 1/5; 14/32] END classifier__estimator__alpha=0.01, classifier__estimator__loss=perceptron, transformer__vect_reviewText__max_features=5000, transformer__vect_reviewText__ngram_range=(1, 2), transformer__vect_summary__max_features=32000, transformer__vect_summary__ngram_range=(1, 2);, score=0.787 total time=   2.6s
# [CV 2/5; 14/32] START classifier__estimator__alpha=0.01, classifier__estimator__loss=perceptron, transformer__vect_reviewText__max_features=5000, transformer__vect_reviewText__ngram_range=(1, 2), transformer__vect_summary__max_features=32000, transformer__vect_summary__ngram_range=(1, 2)
# [CV 2/5; 14/32] END classifier__estimator__alpha=0.01, classifier__estimator__loss=perceptron, transformer__vect_reviewText__max_features=5000, transformer__vect_reviewText__ngram_range=(1, 2), transformer__vect_summary__max_features=32000, transformer__vect_summary__ngram_range=(1, 2);, score=0.782 total time=   2.5s
# [CV 3/5; 14/32] START classifier__estimator__alpha=0.01, classifier__estimator__loss=perceptron, transformer__vect_reviewText__max_features=5000, transformer__vect_reviewText__ngram_range=(1, 2), transformer__vect_summary__max_features=32000, transformer__vect_summary__ngram_range=(1, 2)
# [CV 3/5; 14/32] END classifier__estimator__alpha=0.01, classifier__estimator__loss=perceptron, transformer__vect_reviewText__max_features=5000, transformer__vect_reviewText__ngram_range=(1, 2), transformer__vect_summary__max_features=32000, transformer__vect_summary__ngram_range=(1, 2);, score=0.792 total time=   2.6s
# [CV 4/5; 14/32] START classifier__estimator__alpha=0.01, classifier__estimator__loss=perceptron, transformer__vect_reviewText__max_features=5000, transformer__vect_reviewText__ngram_range=(1, 2), transformer__vect_summary__max_features=32000, transformer__vect_summary__ngram_range=(1, 2)
# [CV 4/5; 14/32] END classifier__estimator__alpha=0.01, classifier__estimator__loss=perceptron, transformer__vect_reviewText__max_features=5000, transformer__vect_reviewText__ngram_range=(1, 2), transformer__vect_summary__max_features=32000, transformer__vect_summary__ngram_range=(1, 2);, score=0.807 total time=   2.7s
# [CV 5/5; 14/32] START classifier__estimator__alpha=0.01, classifier__estimator__loss=perceptron, transformer__vect_reviewText__max_features=5000, transformer__vect_reviewText__ngram_range=(1, 2), transformer__vect_summary__max_features=32000, transformer__vect_summary__ngram_range=(1, 2)
# [CV 5/5; 14/32] END classifier__estimator__alpha=0.01, classifier__estimator__loss=perceptron, transformer__vect_reviewText__max_features=5000, transformer__vect_reviewText__ngram_range=(1, 2), transformer__vect_summary__max_features=32000, transformer__vect_summary__ngram_range=(1, 2);, score=0.790 total time=   2.5s
# [CV 1/5; 15/32] START classifier__estimator__alpha=0.01, classifier__estimator__loss=perceptron, transformer__vect_reviewText__max_features=10000, transformer__vect_reviewText__ngram_range=(1, 2), transformer__vect_summary__max_features=10000, transformer__vect_summary__ngram_range=(1, 2)
# [CV 1/5; 15/32] END classifier__estimator__alpha=0.01, classifier__estimator__loss=perceptron, transformer__vect_reviewText__max_features=10000, transformer__vect_reviewText__ngram_range=(1, 2), transformer__vect_summary__max_features=10000, transformer__vect_summary__ngram_range=(1, 2);, score=0.802 total time=   2.5s
# [CV 2/5; 15/32] START classifier__estimator__alpha=0.01, classifier__estimator__loss=perceptron, transformer__vect_reviewText__max_features=10000, transformer__vect_reviewText__ngram_range=(1, 2), transformer__vect_summary__max_features=10000, transformer__vect_summary__ngram_range=(1, 2)
# [CV 2/5; 15/32] END classifier__estimator__alpha=0.01, classifier__estimator__loss=perceptron, transformer__vect_reviewText__max_features=10000, transformer__vect_reviewText__ngram_range=(1, 2), transformer__vect_summary__max_features=10000, transformer__vect_summary__ngram_range=(1, 2);, score=0.784 total time=   2.5s
# [CV 3/5; 15/32] START classifier__estimator__alpha=0.01, classifier__estimator__loss=perceptron, transformer__vect_reviewText__max_features=10000, transformer__vect_reviewText__ngram_range=(1, 2), transformer__vect_summary__max_features=10000, transformer__vect_summary__ngram_range=(1, 2)
# [CV 3/5; 15/32] END classifier__estimator__alpha=0.01, classifier__estimator__loss=perceptron, transformer__vect_reviewText__max_features=10000, transformer__vect_reviewText__ngram_range=(1, 2), transformer__vect_summary__max_features=10000, transformer__vect_summary__ngram_range=(1, 2);, score=0.799 total time=   2.4s
# [CV 4/5; 15/32] START classifier__estimator__alpha=0.01, classifier__estimator__loss=perceptron, transformer__vect_reviewText__max_features=10000, transformer__vect_reviewText__ngram_range=(1, 2), transformer__vect_summary__max_features=10000, transformer__vect_summary__ngram_range=(1, 2)
# [CV 4/5; 15/32] END classifier__estimator__alpha=0.01, classifier__estimator__loss=perceptron, transformer__vect_reviewText__max_features=10000, transformer__vect_reviewText__ngram_range=(1, 2), transformer__vect_summary__max_features=10000, transformer__vect_summary__ngram_range=(1, 2);, score=0.811 total time=   2.5s
# [CV 5/5; 15/32] START classifier__estimator__alpha=0.01, classifier__estimator__loss=perceptron, transformer__vect_reviewText__max_features=10000, transformer__vect_reviewText__ngram_range=(1, 2), transformer__vect_summary__max_features=10000, transformer__vect_summary__ngram_range=(1, 2)
# [CV 5/5; 15/32] END classifier__estimator__alpha=0.01, classifier__estimator__loss=perceptron, transformer__vect_reviewText__max_features=10000, transformer__vect_reviewText__ngram_range=(1, 2), transformer__vect_summary__max_features=10000, transformer__vect_summary__ngram_range=(1, 2);, score=0.793 total time=   2.5s
# [CV 1/5; 16/32] START classifier__estimator__alpha=0.01, classifier__estimator__loss=perceptron, transformer__vect_reviewText__max_features=10000, transformer__vect_reviewText__ngram_range=(1, 2), transformer__vect_summary__max_features=32000, transformer__vect_summary__ngram_range=(1, 2)
# [CV 1/5; 16/32] END classifier__estimator__alpha=0.01, classifier__estimator__loss=perceptron, transformer__vect_reviewText__max_features=10000, transformer__vect_reviewText__ngram_range=(1, 2), transformer__vect_summary__max_features=32000, transformer__vect_summary__ngram_range=(1, 2);, score=0.784 total time=   2.4s
# [CV 2/5; 16/32] START classifier__estimator__alpha=0.01, classifier__estimator__loss=perceptron, transformer__vect_reviewText__max_features=10000, transformer__vect_reviewText__ngram_range=(1, 2), transformer__vect_summary__max_features=32000, transformer__vect_summary__ngram_range=(1, 2)
# [CV 2/5; 16/32] END classifier__estimator__alpha=0.01, classifier__estimator__loss=perceptron, transformer__vect_reviewText__max_features=10000, transformer__vect_reviewText__ngram_range=(1, 2), transformer__vect_summary__max_features=32000, transformer__vect_summary__ngram_range=(1, 2);, score=0.770 total time=   2.5s
# [CV 3/5; 16/32] START classifier__estimator__alpha=0.01, classifier__estimator__loss=perceptron, transformer__vect_reviewText__max_features=10000, transformer__vect_reviewText__ngram_range=(1, 2), transformer__vect_summary__max_features=32000, transformer__vect_summary__ngram_range=(1, 2)
# [CV 3/5; 16/32] END classifier__estimator__alpha=0.01, classifier__estimator__loss=perceptron, transformer__vect_reviewText__max_features=10000, transformer__vect_reviewText__ngram_range=(1, 2), transformer__vect_summary__max_features=32000, transformer__vect_summary__ngram_range=(1, 2);, score=0.788 total time=   2.5s
# [CV 4/5; 16/32] START classifier__estimator__alpha=0.01, classifier__estimator__loss=perceptron, transformer__vect_reviewText__max_features=10000, transformer__vect_reviewText__ngram_range=(1, 2), transformer__vect_summary__max_features=32000, transformer__vect_summary__ngram_range=(1, 2)
# [CV 4/5; 16/32] END classifier__estimator__alpha=0.01, classifier__estimator__loss=perceptron, transformer__vect_reviewText__max_features=10000, transformer__vect_reviewText__ngram_range=(1, 2), transformer__vect_summary__max_features=32000, transformer__vect_summary__ngram_range=(1, 2);, score=0.817 total time=   2.3s
# ...
# [CV 5/5; 27/32] END classifier__estimator__alpha=1, classifier__estimator__loss=hinge, transformer__vect_reviewText__max_features=10000, transformer__vect_reviewText__ngram_range=(1, 2), transformer__vect_summary__max_features=10000, transformer__vect_summary__ngram_range=(1, 2);, score=0.447 total time=   2.2s
# [CV 1/5; 28/32] START classifier__estimator__alpha=1, classifier__estimator__loss=hinge, transformer__vect_reviewText__max_features=10000, transformer__vect_reviewText__ngram_range=(1, 2), transformer__vect_summary__max_features=32000, transformer__vect_summary__ngram_range=(1, 2)
# [CV 1/5; 28/32] END classifier__estimator__alpha=1, classifier__estimator__loss=hinge, transformer__vect_reviewText__max_features=10000, transformer__vect_reviewText__ngram_range=(1, 2), transformer__vect_summary__max_features=32000, transformer__vect_summary__ngram_range=(1, 2);, score=0.447 total time=   2.3s
# [CV 2/5; 28/32] START classifier__estimator__alpha=1, classifier__estimator__loss=hinge, transformer__vect_reviewText__max_features=10000, transformer__vect_reviewText__ngram_range=(1, 2), transformer__vect_summary__max_features=32000, transformer__vect_summary__ngram_range=(1, 2)
# [CV 2/5; 28/32] END classifier__estimator__alpha=1, classifier__estimator__loss=hinge, transformer__vect_reviewText__max_features=10000, transformer__vect_reviewText__ngram_range=(1, 2), transformer__vect_summary__max_features=32000, transformer__vect_summary__ngram_range=(1, 2);, score=0.447 total time=   2.3s
# [CV 3/5; 28/32] START classifier__estimator__alpha=1, classifier__estimator__loss=hinge, transformer__vect_reviewText__max_features=10000, transformer__vect_reviewText__ngram_range=(1, 2), transformer__vect_summary__max_features=32000, transformer__vect_summary__ngram_range=(1, 2)
# [CV 3/5; 28/32] END classifier__estimator__alpha=1, classifier__estimator__loss=hinge, transformer__vect_reviewText__max_features=10000, transformer__vect_reviewText__ngram_range=(1, 2), transformer__vect_summary__max_features=32000, transformer__vect_summary__ngram_range=(1, 2);, score=0.447 total time=   2.3s
# [CV 4/5; 28/32] START classifier__estimator__alpha=1, classifier__estimator__loss=hinge, transformer__vect_reviewText__max_features=10000, transformer__vect_reviewText__ngram_range=(1, 2), transformer__vect_summary__max_features=32000, transformer__vect_summary__ngram_range=(1, 2)
# [CV 4/5; 28/32] END classifier__estimator__alpha=1, classifier__estimator__loss=hinge, transformer__vect_reviewText__max_features=10000, transformer__vect_reviewText__ngram_range=(1, 2), transformer__vect_summary__max_features=32000, transformer__vect_summary__ngram_range=(1, 2);, score=0.447 total time=   2.4s
# [CV 5/5; 28/32] START classifier__estimator__alpha=1, classifier__estimator__loss=hinge, transformer__vect_reviewText__max_features=10000, transformer__vect_reviewText__ngram_range=(1, 2), transformer__vect_summary__max_features=32000, transformer__vect_summary__ngram_range=(1, 2)
# [CV 5/5; 28/32] END classifier__estimator__alpha=1, classifier__estimator__loss=hinge, transformer__vect_reviewText__max_features=10000, transformer__vect_reviewText__ngram_range=(1, 2), transformer__vect_summary__max_features=32000, transformer__vect_summary__ngram_range=(1, 2);, score=0.447 total time=   2.3s
# [CV 1/5; 29/32] START classifier__estimator__alpha=1, classifier__estimator__loss=perceptron, transformer__vect_reviewText__max_features=5000, transformer__vect_reviewText__ngram_range=(1, 2), transformer__vect_summary__max_features=10000, transformer__vect_summary__ngram_range=(1, 2)
# [CV 1/5; 29/32] END classifier__estimator__alpha=1, classifier__estimator__loss=perceptron, transformer__vect_reviewText__max_features=5000, transformer__vect_reviewText__ngram_range=(1, 2), transformer__vect_summary__max_features=10000, transformer__vect_summary__ngram_range=(1, 2);, score=0.481 total time=   2.3s
# [CV 2/5; 29/32] START classifier__estimator__alpha=1, classifier__estimator__loss=perceptron, transformer__vect_reviewText__max_features=5000, transformer__vect_reviewText__ngram_range=(1, 2), transformer__vect_summary__max_features=10000, transformer__vect_summary__ngram_range=(1, 2)
# [CV 2/5; 29/32] END classifier__estimator__alpha=1, classifier__estimator__loss=perceptron, transformer__vect_reviewText__max_features=5000, transformer__vect_reviewText__ngram_range=(1, 2), transformer__vect_summary__max_features=10000, transformer__vect_summary__ngram_range=(1, 2);, score=0.578 total time=   2.2s
# [CV 3/5; 29/32] START classifier__estimator__alpha=1, classifier__estimator__loss=perceptron, transformer__vect_reviewText__max_features=5000, transformer__vect_reviewText__ngram_range=(1, 2), transformer__vect_summary__max_features=10000, transformer__vect_summary__ngram_range=(1, 2)
# [CV 3/5; 29/32] END classifier__estimator__alpha=1, classifier__estimator__loss=perceptron, transformer__vect_reviewText__max_features=5000, transformer__vect_reviewText__ngram_range=(1, 2), transformer__vect_summary__max_features=10000, transformer__vect_summary__ngram_range=(1, 2);, score=0.585 total time=   2.2s
# [CV 4/5; 29/32] START classifier__estimator__alpha=1, classifier__estimator__loss=perceptron, transformer__vect_reviewText__max_features=5000, transformer__vect_reviewText__ngram_range=(1, 2), transformer__vect_summary__max_features=10000, transformer__vect_summary__ngram_range=(1, 2)
# [CV 4/5; 29/32] END classifier__estimator__alpha=1, classifier__estimator__loss=perceptron, transformer__vect_reviewText__max_features=5000, transformer__vect_reviewText__ngram_range=(1, 2), transformer__vect_summary__max_features=10000, transformer__vect_summary__ngram_range=(1, 2);, score=0.621 total time=   2.3s
# [CV 5/5; 29/32] START classifier__estimator__alpha=1, classifier__estimator__loss=perceptron, transformer__vect_reviewText__max_features=5000, transformer__vect_reviewText__ngram_range=(1, 2), transformer__vect_summary__max_features=10000, transformer__vect_summary__ngram_range=(1, 2)
# [CV 5/5; 29/32] END classifier__estimator__alpha=1, classifier__estimator__loss=perceptron, transformer__vect_reviewText__max_features=5000, transformer__vect_reviewText__ngram_range=(1, 2), transformer__vect_summary__max_features=10000, transformer__vect_summary__ngram_range=(1, 2);, score=0.610 total time=   2.2s
# [CV 1/5; 30/32] START classifier__estimator__alpha=1, classifier__estimator__loss=perceptron, transformer__vect_reviewText__max_features=5000, transformer__vect_reviewText__ngram_range=(1, 2), transformer__vect_summary__max_features=32000, transformer__vect_summary__ngram_range=(1, 2)
# [CV 1/5; 30/32] END classifier__estimator__alpha=1, classifier__estimator__loss=perceptron, transformer__vect_reviewText__max_features=5000, transformer__vect_reviewText__ngram_range=(1, 2), transformer__vect_summary__max_features=32000, transformer__vect_summary__ngram_range=(1, 2);, score=0.547 total time=   2.2s
# [CV 2/5; 30/32] START classifier__estimator__alpha=1, classifier__estimator__loss=perceptron, transformer__vect_reviewText__max_features=5000, transformer__vect_reviewText__ngram_range=(1, 2), transformer__vect_summary__max_features=32000, transformer__vect_summary__ngram_range=(1, 2)
# [CV 2/5; 30/32] END classifier__estimator__alpha=1, classifier__estimator__loss=perceptron, transformer__vect_reviewText__max_features=5000, transformer__vect_reviewText__ngram_range=(1, 2), transformer__vect_summary__max_features=32000, transformer__vect_summary__ngram_range=(1, 2);, score=0.537 total time=   2.3s
# [CV 3/5; 30/32] START classifier__estimator__alpha=1, classifier__estimator__loss=perceptron, transformer__vect_reviewText__max_features=5000, transformer__vect_reviewText__ngram_range=(1, 2), transformer__vect_summary__max_features=32000, transformer__vect_summary__ngram_range=(1, 2)
# [CV 3/5; 30/32] END classifier__estimator__alpha=1, classifier__estimator__loss=perceptron, transformer__vect_reviewText__max_features=5000, transformer__vect_reviewText__ngram_range=(1, 2), transformer__vect_summary__max_features=32000, transformer__vect_summary__ngram_range=(1, 2);, score=0.615 total time=   2.3s
# [CV 4/5; 30/32] START classifier__estimator__alpha=1, classifier__estimator__loss=perceptron, transformer__vect_reviewText__max_features=5000, transformer__vect_reviewText__ngram_range=(1, 2), transformer__vect_summary__max_features=32000, transformer__vect_summary__ngram_range=(1, 2)
# [CV 4/5; 30/32] END classifier__estimator__alpha=1, classifier__estimator__loss=perceptron, transformer__vect_reviewText__max_features=5000, transformer__vect_reviewText__ngram_range=(1, 2), transformer__vect_summary__max_features=32000, transformer__vect_summary__ngram_range=(1, 2);, score=0.629 total time=   2.3s
# [CV 5/5; 30/32] START classifier__estimator__alpha=1, classifier__estimator__loss=perceptron, transformer__vect_reviewText__max_features=5000, transformer__vect_reviewText__ngram_range=(1, 2), transformer__vect_summary__max_features=32000, transformer__vect_summary__ngram_range=(1, 2)
# [CV 5/5; 30/32] END classifier__estimator__alpha=1, classifier__estimator__loss=perceptron, transformer__vect_reviewText__max_features=5000, transformer__vect_reviewText__ngram_range=(1, 2), transformer__vect_summary__max_features=32000, transformer__vect_summary__ngram_range=(1, 2);, score=0.608 total time=   2.3s
# [CV 1/5; 31/32] START classifier__estimator__alpha=1, classifier__estimator__loss=perceptron, transformer__vect_reviewText__max_features=10000, transformer__vect_reviewText__ngram_range=(1, 2), transformer__vect_summary__max_features=10000, transformer__vect_summary__ngram_range=(1, 2)
# [CV 1/5; 31/32] END classifier__estimator__alpha=1, classifier__estimator__loss=perceptron, transformer__vect_reviewText__max_features=10000, transformer__vect_reviewText__ngram_range=(1, 2), transformer__vect_summary__max_features=10000, transformer__vect_summary__ngram_range=(1, 2);, score=0.551 total time=   2.3s
# [CV 2/5; 31/32] START classifier__estimator__alpha=1, classifier__estimator__loss=perceptron, transformer__vect_reviewText__max_features=10000, transformer__vect_reviewText__ngram_range=(1, 2), transformer__vect_summary__max_features=10000, transformer__vect_summary__ngram_range=(1, 2)
# [CV 2/5; 31/32] END classifier__estimator__alpha=1, classifier__estimator__loss=perceptron, transformer__vect_reviewText__max_features=10000, transformer__vect_reviewText__ngram_range=(1, 2), transformer__vect_summary__max_features=10000, transformer__vect_summary__ngram_range=(1, 2);, score=0.479 total time=   2.5s
# [CV 3/5; 31/32] START classifier__estimator__alpha=1, classifier__estimator__loss=perceptron, transformer__vect_reviewText__max_features=10000, transformer__vect_reviewText__ngram_range=(1, 2), transformer__vect_summary__max_features=10000, transformer__vect_summary__ngram_range=(1, 2)
# [CV 3/5; 31/32] END classifier__estimator__alpha=1, classifier__estimator__loss=perceptron, transformer__vect_reviewText__max_features=10000, transformer__vect_reviewText__ngram_range=(1, 2), transformer__vect_summary__max_features=10000, transformer__vect_summary__ngram_range=(1, 2);, score=0.637 total time=   2.3s
# [CV 4/5; 31/32] START classifier__estimator__alpha=1, classifier__estimator__loss=perceptron, transformer__vect_reviewText__max_features=10000, transformer__vect_reviewText__ngram_range=(1, 2), transformer__vect_summary__max_features=10000, transformer__vect_summary__ngram_range=(1, 2)
# [CV 4/5; 31/32] END classifier__estimator__alpha=1, classifier__estimator__loss=perceptron, transformer__vect_reviewText__max_features=10000, transformer__vect_reviewText__ngram_range=(1, 2), transformer__vect_summary__max_features=10000, transformer__vect_summary__ngram_range=(1, 2);, score=0.448 total time=   2.3s
# [CV 5/5; 31/32] START classifier__estimator__alpha=1, classifier__estimator__loss=perceptron, transformer__vect_reviewText__max_features=10000, transformer__vect_reviewText__ngram_range=(1, 2), transformer__vect_summary__max_features=10000, transformer__vect_summary__ngram_range=(1, 2)
# [CV 5/5; 31/32] END classifier__estimator__alpha=1, classifier__estimator__loss=perceptron, transformer__vect_reviewText__max_features=10000, transformer__vect_reviewText__ngram_range=(1, 2), transformer__vect_summary__max_features=10000, transformer__vect_summary__ngram_range=(1, 2);, score=0.602 total time=   2.3s
# [CV 1/5; 32/32] START classifier__estimator__alpha=1, classifier__estimator__loss=perceptron, transformer__vect_reviewText__max_features=10000, transformer__vect_reviewText__ngram_range=(1, 2), transformer__vect_summary__max_features=32000, transformer__vect_summary__ngram_range=(1, 2)
# [CV 1/5; 32/32] END classifier__estimator__alpha=1, classifier__estimator__loss=perceptron, transformer__vect_reviewText__max_features=10000, transformer__vect_reviewText__ngram_range=(1, 2), transformer__vect_summary__max_features=32000, transformer__vect_summary__ngram_range=(1, 2);, score=0.580 total time=   2.3s
# [CV 2/5; 32/32] START classifier__estimator__alpha=1, classifier__estimator__loss=perceptron, transformer__vect_reviewText__max_features=10000, transformer__vect_reviewText__ngram_range=(1, 2), transformer__vect_summary__max_features=32000, transformer__vect_summary__ngram_range=(1, 2)
# [CV 2/5; 32/32] END classifier__estimator__alpha=1, classifier__estimator__loss=perceptron, transformer__vect_reviewText__max_features=10000, transformer__vect_reviewText__ngram_range=(1, 2), transformer__vect_summary__max_features=32000, transformer__vect_summary__ngram_range=(1, 2);, score=0.669 total time=   2.4s
# [CV 3/5; 32/32] START classifier__estimator__alpha=1, classifier__estimator__loss=perceptron, transformer__vect_reviewText__max_features=10000, transformer__vect_reviewText__ngram_range=(1, 2), transformer__vect_summary__max_features=32000, transformer__vect_summary__ngram_range=(1, 2)
# [CV 3/5; 32/32] END classifier__estimator__alpha=1, classifier__estimator__loss=perceptron, transformer__vect_reviewText__max_features=10000, transformer__vect_reviewText__ngram_range=(1, 2), transformer__vect_summary__max_features=32000, transformer__vect_summary__ngram_range=(1, 2);, score=0.507 total time=   2.3s
# [CV 4/5; 32/32] START classifier__estimator__alpha=1, classifier__estimator__loss=perceptron, transformer__vect_reviewText__max_features=10000, transformer__vect_reviewText__ngram_range=(1, 2), transformer__vect_summary__max_features=32000, transformer__vect_summary__ngram_range=(1, 2)
# [CV 4/5; 32/32] END classifier__estimator__alpha=1, classifier__estimator__loss=perceptron, transformer__vect_reviewText__max_features=10000, transformer__vect_reviewText__ngram_range=(1, 2), transformer__vect_summary__max_features=32000, transformer__vect_summary__ngram_range=(1, 2);, score=0.560 total time=   2.4s
# [CV 5/5; 32/32] START classifier__estimator__alpha=1, classifier__estimator__loss=perceptron, transformer__vect_reviewText__max_features=10000, transformer__vect_reviewText__ngram_range=(1, 2), transformer__vect_summary__max_features=32000, transformer__vect_summary__ngram_range=(1, 2)
# [CV 5/5; 32/32] END classifier__estimator__alpha=1, classifier__estimator__loss=perceptron, transformer__vect_reviewText__max_features=10000, transformer__vect_reviewText__ngram_range=(1, 2), transformer__vect_summary__max_features=32000, transformer__vect_summary__ngram_range=(1, 2);, score=0.667 total time=   2.7s
# -----------------------------------------------------------------------------------------------------------------------------------
# Best: 0.798111 using {'classifier__estimator__alpha': 0.01, 'classifier__estimator__loss': 'perceptron', 'transformer__vect_reviewText__max_features': 10000, 'transformer__vect_reviewText__ngram_range': (1, 2), 'transformer__vect_summary__max_features': 10000, 'transformer__vect_summary__ngram_range': (1, 2)}
# f1_score:  0.8013125715299603
# accuracy:  0.8876327509421035
# auc score:  0.7718485100629258

# %%
pd.DataFrame({"Model": model_arr, "auc": auc_arr,
      "f1 score": f1_arr, "Accuracy": accuracy_arr, }).head()
# Out:
#                             Model       auc  f1 score  Accuracy
# 0             Logistic Regression  0.795931  0.814364  0.889860
# 1                   MultinomialNB  0.839291  0.821096  0.880781
# 2                       LinearSVC  0.799458  0.821175  0.894998
# 3  Stochastic Gradient classifier  0.771849  0.801313  0.887633
